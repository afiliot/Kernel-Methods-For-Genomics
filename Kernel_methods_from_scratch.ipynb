# %% [markdown]
# # Kernel methods : Data Challenge (TF)

# %% [markdown]
# Meilleures accuracy :
# - Mismatch (k=6, m=1)
# - Weight Degree (d=6)
# - Local Alignment (e=11, d=2)

# %% [markdown]
# ## Packages import

# %%
import os
import datetime
import utils  
import kernels
import SVM
import SVM2
import numpy as np
from itertools import product

# %% [markdown]
# ## C-SVM

# %% [markdown]
# ### Accuracies obtained so far for each methods

# %%
utils.sort_accuracies()
# Out:
#    Kernel Method - k=1  Val accuracy - k=1  Constant C - k=1  \
# 0             SVM_MM61            0.648000             1.500
# 1              SVM_SP6            0.637000             0.700
# 2             SVM_WD10            0.636500             0.030
# 3              SVM_SP5            0.633500             0.500
# 4        SVM_LA_e11_d2            0.628500             0.700
# 5             SVM_MM62            0.627000             9.000
# 6         SVM_LA_e8_d1            0.624000             0.600
# 7             SVM_MM51            0.620000             2.000
# 8              SVM_SP4            0.619500             0.400
# 9             SVM_MM41            0.611000             2.000
# 10             SVM_SP3            0.608000             0.600
# 11            SVM_MM31            0.593000             9.000
# 12             SVM_WD5            0.590000             0.005
# 13             SVM_WD3            0.575408             0.010
#
#    Kernel Method - k=2  Val accuracy - k=2  Constant C - k=2  \
# 0             SVM_MM61            0.732000              4.50
# 1              SVM_SP6            0.730000              0.60
# 2             SVM_MM62            0.728000              8.00
# 3        SVM_LA_e11_d2            0.714500              0.50
# 4             SVM_MM51            0.703000              6.00
# 5              SVM_SP5            0.703000              0.30
# 6              SVM_WD5            0.677000              0.02
# 7             SVM_WD10            0.677000              0.02
# 8              SVM_SP4            0.674500              0.50
# 9             SVM_MM41            0.660000              5.00
# 10             SVM_SP3            0.647500              0.90
# 11            SVM_MM31            0.631500              6.00
# 12             SVM_WD3            0.582403              5.00
# 13                 NaN                 NaN               NaN
#
#    Kernel Method - k=3  Val accuracy - k=3  Constant C - k=3
# 0             SVM_MM61            0.656000             0.690
# 1              SVM_SP6            0.650000             5.000
# 2              SVM_SP5            0.647500             2.000
# 3             SVM_MM62            0.646500             8.000
# 4              SVM_SP4            0.644500             4.000
# 5             SVM_MM51            0.641000             5.000
# 6             SVM_MM41            0.635500             2.000
# 7              SVM_SP3            0.631000             5.000
# 8        SVM_LA_e11_d2            0.620000             0.500
# 9             SVM_MM31            0.618500             1.000
# 10             SVM_WD5            0.594500             0.007
# 11            SVM_WD10            0.594500             0.007
# 12             SVM_WD3            0.555468             0.005
# 13                 NaN                 NaN               NaN

# %% [markdown]
# ### Cross validation on constant C

# %%
methods = ['MM61']
Cs = np.concatenate((np.linspace(0.1, 1, 91), np.linspace(1, 10, 19)))
utils.run_expe(methods, Cs_1=Cs, Cs_2=Cs, Cs_3=Cs)
# Out:
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# Fold 1
# C=0.1, best accuracy on train (0.6031) and val (0.5475)
# C=0.11, best accuracy on train (0.6425) and val (0.5700)
# C=0.12000000000000001, best accuracy on train (0.6269) and val (0.5550)
# C=0.13, best accuracy on train (0.6894) and val (0.5775)
# C=0.14, best accuracy on train (0.6944) and val (0.6100)
# C=0.15000000000000002, best accuracy on train (0.6475) and val (0.5900)
# C=0.16, best accuracy on train (0.7025) and val (0.6000)
# C=0.17, best accuracy on train (0.6937) and val (0.6150)
# C=0.18, best accuracy on train (0.6931) and val (0.6125)
# C=0.19, best accuracy on train (0.6987) and val (0.6100)
# C=0.2, best accuracy on train (0.6875) and val (0.6075)
# C=0.21000000000000002, best accuracy on train (0.7000) and val (0.6075)
# C=0.22, best accuracy on train (0.6975) and val (0.6100)
# C=0.23, best accuracy on train (0.6975) and val (0.6150)
# C=0.24000000000000002, best accuracy on train (0.6981) and val (0.6100)
# C=0.25, best accuracy on train (0.6906) and val (0.6125)
# C=0.26, best accuracy on train (0.6944) and val (0.6150)
# C=0.27, best accuracy on train (0.6819) and val (0.6125)
# C=0.28, best accuracy on train (0.7094) and val (0.6150)
# C=0.29000000000000004, best accuracy on train (0.7231) and val (0.6150)
# C=0.30000000000000004, best accuracy on train (0.7200) and val (0.6200)
# C=0.31, best accuracy on train (0.7238) and val (0.6150)
# C=0.32, best accuracy on train (0.7238) and val (0.6200)
# C=0.33, best accuracy on train (0.7175) and val (0.6200)
# C=0.33999999999999997, best accuracy on train (0.7206) and val (0.6175)
# C=0.35, best accuracy on train (0.7231) and val (0.6175)
# C=0.36, best accuracy on train (0.6937) and val (0.6100)
# C=0.37, best accuracy on train (0.7275) and val (0.6100)
# C=0.38, best accuracy on train (0.7362) and val (0.6150)
# C=0.39, best accuracy on train (0.7194) and val (0.6175)
# C=0.4, best accuracy on train (0.7388) and val (0.6100)
# C=0.41000000000000003, best accuracy on train (0.7412) and val (0.6175)
# C=0.42000000000000004, best accuracy on train (0.7431) and val (0.6150)
# C=0.43000000000000005, best accuracy on train (0.7388) and val (0.6100)
# C=0.44000000000000006, best accuracy on train (0.7469) and val (0.6100)
# C=0.45000000000000007, best accuracy on train (0.7456) and val (0.6125)
# C=0.45999999999999996, best accuracy on train (0.7375) and val (0.6150)
# C=0.47, best accuracy on train (0.7344) and val (0.6175)
# C=0.48, best accuracy on train (0.7275) and val (0.6150)
# C=0.49, best accuracy on train (0.7450) and val (0.6150)
# C=0.5, best accuracy on train (0.7238) and val (0.6225)
# C=0.51, best accuracy on train (0.7194) and val (0.6125)
# C=0.52, best accuracy on train (0.6981) and val (0.6200)
# C=0.53, best accuracy on train (0.7519) and val (0.6100)
# C=0.54, best accuracy on train (0.7469) and val (0.6100)
# C=0.55, best accuracy on train (0.7381) and val (0.6125)
# C=0.56, best accuracy on train (0.7462) and val (0.6125)
# C=0.5700000000000001, best accuracy on train (0.7550) and val (0.6175)
# C=0.58, best accuracy on train (0.7312) and val (0.6375)
# C=0.59, best accuracy on train (0.7638) and val (0.6175)
# C=0.6, best accuracy on train (0.7575) and val (0.6125)
# C=0.61, best accuracy on train (0.7444) and val (0.6150)
# C=0.62, best accuracy on train (0.7562) and val (0.6175)
# C=0.63, best accuracy on train (0.7544) and val (0.6175)
# C=0.64, best accuracy on train (0.7669) and val (0.6200)
# C=0.65, best accuracy on train (0.7762) and val (0.6125)
# C=0.66, best accuracy on train (0.7662) and val (0.6200)
# C=0.67, best accuracy on train (0.7600) and val (0.6175)
# C=0.6799999999999999, best accuracy on train (0.7788) and val (0.6300)
# C=0.69, best accuracy on train (0.7769) and val (0.6200)
# C=0.7, best accuracy on train (0.7769) and val (0.6200)
# C=0.71, best accuracy on train (0.7756) and val (0.6225)
# C=0.72, best accuracy on train (0.7675) and val (0.6250)
# C=0.73, best accuracy on train (0.7219) and val (0.6200)
# C=0.74, best accuracy on train (0.7725) and val (0.6300)
# C=0.75, best accuracy on train (0.7700) and val (0.6200)
# C=0.76, best accuracy on train (0.7388) and val (0.6250)
# C=0.77, best accuracy on train (0.7812) and val (0.6300)
# C=0.78, best accuracy on train (0.7369) and val (0.6275)
# C=0.79, best accuracy on train (0.7756) and val (0.6275)
# C=0.8, best accuracy on train (0.7769) and val (0.6350)
# C=0.8099999999999999, best accuracy on train (0.7475) and val (0.6325)
# C=0.82, best accuracy on train (0.7931) and val (0.6375)
# C=0.83, best accuracy on train (0.7788) and val (0.6350)
# C=0.84, best accuracy on train (0.7769) and val (0.6350)
# C=0.85, best accuracy on train (0.7800) and val (0.6250)
# C=0.86, best accuracy on train (0.7875) and val (0.6225)
# C=0.87, best accuracy on train (0.7887) and val (0.6350)
# C=0.88, best accuracy on train (0.7881) and val (0.6300)
# C=0.89, best accuracy on train (0.7894) and val (0.6275)
# C=0.9, best accuracy on train (0.7812) and val (0.6250)
# C=0.91, best accuracy on train (0.7944) and val (0.6300)
# C=0.92, best accuracy on train (0.7831) and val (0.6300)
# C=0.93, best accuracy on train (0.7856) and val (0.6350)
# C=0.94, best accuracy on train (0.7844) and val (0.6250)
# C=0.95, best accuracy on train (0.7906) and val (0.6275)
# C=0.96, best accuracy on train (0.7781) and val (0.6275)
# C=0.97, best accuracy on train (0.7937) and val (0.6300)
# C=0.98, best accuracy on train (0.8087) and val (0.6275)
# C=0.99, best accuracy on train (0.7975) and val (0.6325)
# C=1.0, best accuracy on train (0.8025) and val (0.6250)
# C=1.0, best accuracy on train (0.8025) and val (0.6250)
# C=1.5, best accuracy on train (0.8219) and val (0.6450)
# C=2.0, best accuracy on train (0.8394) and val (0.6450)
# C=2.5, best accuracy on train (0.8462) and val (0.6400)
# C=3.0, best accuracy on train (0.8594) and val (0.6350)
# C=3.5, best accuracy on train (0.8600) and val (0.6350)
# C=4.0, best accuracy on train (0.8794) and val (0.6375)
# C=4.5, best accuracy on train (0.8944) and val (0.6325)
# C=5.0, best accuracy on train (0.8988) and val (0.6275)
# C=5.5, best accuracy on train (0.9094) and val (0.6350)
# C=6.0, best accuracy on train (0.8994) and val (0.6275)
# C=6.5, best accuracy on train (0.9169) and val (0.6275)
# C=7.0, best accuracy on train (0.9150) and val (0.6325)
# C=7.5, best accuracy on train (0.9250) and val (0.6300)
# C=8.0, best accuracy on train (0.9137) and val (0.6325)
# C=8.5, best accuracy on train (0.9281) and val (0.6225)
# C=9.0, best accuracy on train (0.9325) and val (0.6225)
# C=9.5, best accuracy on train (0.9369) and val (0.6200)
# C=10.0, best accuracy on train (0.9256) and val (0.6225)
# Fold 2
# C=0.1, best accuracy on train (0.5756) and val (0.5275)
# C=0.11, best accuracy on train (0.6288) and val (0.5475)
# C=0.12000000000000001, best accuracy on train (0.6744) and val (0.5675)
# C=0.13, best accuracy on train (0.6831) and val (0.5900)
# C=0.14, best accuracy on train (0.6919) and val (0.6075)
# C=0.15000000000000002, best accuracy on train (0.6913) and val (0.6175)
# C=0.16, best accuracy on train (0.6775) and val (0.6025)
# C=0.17, best accuracy on train (0.6881) and val (0.6125)
# C=0.18, best accuracy on train (0.6763) and val (0.6075)
# C=0.19, best accuracy on train (0.6981) and val (0.6025)
# C=0.2, best accuracy on train (0.6894) and val (0.6125)
# C=0.21000000000000002, best accuracy on train (0.6919) and val (0.6125)
# C=0.22, best accuracy on train (0.6950) and val (0.6075)
# C=0.23, best accuracy on train (0.6644) and val (0.6175)
# C=0.24000000000000002, best accuracy on train (0.6600) and val (0.6175)
# C=0.25, best accuracy on train (0.7256) and val (0.6225)
# C=0.26, best accuracy on train (0.7075) and val (0.6150)
# C=0.27, best accuracy on train (0.7106) and val (0.6150)
# C=0.28, best accuracy on train (0.7169) and val (0.6200)
# C=0.29000000000000004, best accuracy on train (0.7275) and val (0.6275)
# C=0.30000000000000004, best accuracy on train (0.6750) and val (0.6150)
# C=0.31, best accuracy on train (0.7225) and val (0.6150)
# C=0.32, best accuracy on train (0.7262) and val (0.6175)
# C=0.33, best accuracy on train (0.7319) and val (0.6175)
# C=0.33999999999999997, best accuracy on train (0.7225) and val (0.6225)
# C=0.35, best accuracy on train (0.7331) and val (0.6175)
# C=0.36, best accuracy on train (0.7344) and val (0.6175)
# C=0.37, best accuracy on train (0.7306) and val (0.6200)
# C=0.38, best accuracy on train (0.7319) and val (0.6275)
# C=0.39, best accuracy on train (0.7438) and val (0.6275)
# C=0.4, best accuracy on train (0.7456) and val (0.6175)
# C=0.41000000000000003, best accuracy on train (0.7412) and val (0.6225)
# C=0.42000000000000004, best accuracy on train (0.7356) and val (0.6275)
# C=0.43000000000000005, best accuracy on train (0.7619) and val (0.6250)
# C=0.44000000000000006, best accuracy on train (0.7494) and val (0.6225)
# C=0.45000000000000007, best accuracy on train (0.7512) and val (0.6250)
# C=0.45999999999999996, best accuracy on train (0.7531) and val (0.6275)
# C=0.47, best accuracy on train (0.7750) and val (0.6425)
# C=0.48, best accuracy on train (0.7738) and val (0.6325)
# C=0.49, best accuracy on train (0.7781) and val (0.6300)
# C=0.5, best accuracy on train (0.7762) and val (0.6425)
# C=0.51, best accuracy on train (0.7694) and val (0.6350)
# C=0.52, best accuracy on train (0.7638) and val (0.6425)
# C=0.53, best accuracy on train (0.7681) and val (0.6375)
# C=0.54, best accuracy on train (0.7788) and val (0.6300)
# C=0.55, best accuracy on train (0.7825) and val (0.6475)
# C=0.56, best accuracy on train (0.7706) and val (0.6250)
# C=0.5700000000000001, best accuracy on train (0.7856) and val (0.6275)
# C=0.58, best accuracy on train (0.7863) and val (0.6250)
# C=0.59, best accuracy on train (0.7869) and val (0.6250)
# C=0.6, best accuracy on train (0.7806) and val (0.6275)
# C=0.61, best accuracy on train (0.7831) and val (0.6325)
# C=0.62, best accuracy on train (0.7894) and val (0.6275)
# C=0.63, best accuracy on train (0.7819) and val (0.6275)
# C=0.64, best accuracy on train (0.7900) and val (0.6350)
# C=0.65, best accuracy on train (0.7863) and val (0.6350)
# C=0.66, best accuracy on train (0.7694) and val (0.6300)
# C=0.67, best accuracy on train (0.7688) and val (0.6250)
# C=0.6799999999999999, best accuracy on train (0.7831) and val (0.6250)
# C=0.69, best accuracy on train (0.7625) and val (0.6375)
# C=0.7, best accuracy on train (0.7675) and val (0.6250)
# C=0.71, best accuracy on train (0.7837) and val (0.6400)
# C=0.72, best accuracy on train (0.7987) and val (0.6400)
# C=0.73, best accuracy on train (0.7781) and val (0.6325)
# C=0.74, best accuracy on train (0.7969) and val (0.6250)
# C=0.75, best accuracy on train (0.7650) and val (0.6400)
# C=0.76, best accuracy on train (0.7913) and val (0.6325)
# C=0.77, best accuracy on train (0.7569) and val (0.6350)
# C=0.78, best accuracy on train (0.7781) and val (0.6325)
# C=0.79, best accuracy on train (0.7694) and val (0.6375)
# C=0.8, best accuracy on train (0.7931) and val (0.6350)
# C=0.8099999999999999, best accuracy on train (0.7900) and val (0.6325)
# C=0.82, best accuracy on train (0.7919) and val (0.6275)
# C=0.83, best accuracy on train (0.8063) and val (0.6350)
# C=0.84, best accuracy on train (0.7950) and val (0.6350)
# C=0.85, best accuracy on train (0.8013) and val (0.6275)
# C=0.86, best accuracy on train (0.7956) and val (0.6375)
# C=0.87, best accuracy on train (0.7906) and val (0.6375)
# C=0.88, best accuracy on train (0.8013) and val (0.6375)
# C=0.89, best accuracy on train (0.8037) and val (0.6350)
# C=0.9, best accuracy on train (0.7981) and val (0.6350)
# C=0.91, best accuracy on train (0.7738) and val (0.6375)
# C=0.92, best accuracy on train (0.7800) and val (0.6350)
# C=0.93, best accuracy on train (0.8119) and val (0.6400)
# C=0.94, best accuracy on train (0.8000) and val (0.6400)
# C=0.95, best accuracy on train (0.7975) and val (0.6400)
# C=0.96, best accuracy on train (0.8056) and val (0.6350)
# C=0.97, best accuracy on train (0.8044) and val (0.6425)
# C=0.98, best accuracy on train (0.8137) and val (0.6400)
# C=0.99, best accuracy on train (0.8113) and val (0.6375)
# C=1.0, best accuracy on train (0.8063) and val (0.6350)
# C=1.0, best accuracy on train (0.8063) and val (0.6350)
# C=1.5, best accuracy on train (0.8244) and val (0.6400)
# C=2.0, best accuracy on train (0.8475) and val (0.6425)
# C=2.5, best accuracy on train (0.8631) and val (0.6375)
# C=3.0, best accuracy on train (0.8706) and val (0.6450)
# C=3.5, best accuracy on train (0.8812) and val (0.6375)
# C=4.0, best accuracy on train (0.8925) and val (0.6450)
# C=4.5, best accuracy on train (0.8988) and val (0.6425)
# C=5.0, best accuracy on train (0.9038) and val (0.6400)
# C=5.5, best accuracy on train (0.7987) and val (0.6375)
# C=6.0, best accuracy on train (0.9175) and val (0.6300)
# C=6.5, best accuracy on train (0.9075) and val (0.6325)
# C=7.0, best accuracy on train (0.9200) and val (0.6275)
# C=7.5, best accuracy on train (0.8594) and val (0.6325)
# C=8.0, best accuracy on train (0.9081) and val (0.6275)
# C=8.5, best accuracy on train (0.9231) and val (0.6300)
# C=9.0, best accuracy on train (0.9350) and val (0.6150)
# C=9.5, best accuracy on train (0.8631) and val (0.6200)
# C=10.0, best accuracy on train (0.9375) and val (0.6200)
# Fold 3
# C=0.1, best accuracy on train (0.6725) and val (0.6225)
# C=0.11, best accuracy on train (0.6719) and val (0.6275)
# C=0.12000000000000001, best accuracy on train (0.6713) and val (0.6325)
# C=0.13, best accuracy on train (0.6713) and val (0.6225)
# C=0.14, best accuracy on train (0.6750) and val (0.6250)
# C=0.15000000000000002, best accuracy on train (0.6731) and val (0.6275)
# C=0.16, best accuracy on train (0.6787) and val (0.6000)
# C=0.17, best accuracy on train (0.6763) and val (0.6000)
# C=0.18, best accuracy on train (0.6944) and val (0.6250)
# C=0.19, best accuracy on train (0.6969) and val (0.6225)
# C=0.2, best accuracy on train (0.6963) and val (0.6225)
# C=0.21000000000000002, best accuracy on train (0.7044) and val (0.6325)
# C=0.22, best accuracy on train (0.7037) and val (0.6250)
# C=0.23, best accuracy on train (0.7050) and val (0.6300)
# C=0.24000000000000002, best accuracy on train (0.7056) and val (0.6250)
# C=0.25, best accuracy on train (0.7125) and val (0.6275)
# C=0.26, best accuracy on train (0.7169) and val (0.6400)
# C=0.27, best accuracy on train (0.7163) and val (0.6325)
# C=0.28, best accuracy on train (0.7175) and val (0.6325)
# C=0.29000000000000004, best accuracy on train (0.7131) and val (0.6275)
# C=0.30000000000000004, best accuracy on train (0.7175) and val (0.6300)
# C=0.31, best accuracy on train (0.7219) and val (0.6375)
# C=0.32, best accuracy on train (0.7225) and val (0.6475)
# C=0.33, best accuracy on train (0.7250) and val (0.6450)
# C=0.33999999999999997, best accuracy on train (0.7262) and val (0.6325)
# C=0.35, best accuracy on train (0.7250) and val (0.6350)
# C=0.36, best accuracy on train (0.7344) and val (0.6325)
# C=0.37, best accuracy on train (0.7338) and val (0.6425)
# C=0.38, best accuracy on train (0.7338) and val (0.6475)
# C=0.39, best accuracy on train (0.7344) and val (0.6375)
# C=0.4, best accuracy on train (0.7431) and val (0.6350)
# C=0.41000000000000003, best accuracy on train (0.7475) and val (0.6350)
# C=0.42000000000000004, best accuracy on train (0.7494) and val (0.6375)
# C=0.43000000000000005, best accuracy on train (0.7512) and val (0.6375)
# C=0.44000000000000006, best accuracy on train (0.7525) and val (0.6350)
# C=0.45000000000000007, best accuracy on train (0.7538) and val (0.6400)
# C=0.45999999999999996, best accuracy on train (0.7531) and val (0.6375)
# C=0.47, best accuracy on train (0.7562) and val (0.6375)
# C=0.48, best accuracy on train (0.7562) and val (0.6375)
# C=0.49, best accuracy on train (0.7594) and val (0.6400)
# C=0.5, best accuracy on train (0.7594) and val (0.6425)
# C=0.51, best accuracy on train (0.7556) and val (0.6375)
# C=0.52, best accuracy on train (0.7656) and val (0.6350)
# C=0.53, best accuracy on train (0.7569) and val (0.6375)
# C=0.54, best accuracy on train (0.7612) and val (0.6375)
# C=0.55, best accuracy on train (0.7662) and val (0.6375)
# C=0.56, best accuracy on train (0.7631) and val (0.6450)
# C=0.5700000000000001, best accuracy on train (0.7619) and val (0.6400)
# C=0.58, best accuracy on train (0.7625) and val (0.6375)
# C=0.59, best accuracy on train (0.7631) and val (0.6450)
# C=0.6, best accuracy on train (0.7719) and val (0.6375)
# C=0.61, best accuracy on train (0.7656) and val (0.6475)
# C=0.62, best accuracy on train (0.7688) and val (0.6425)
# C=0.63, best accuracy on train (0.7681) and val (0.6425)
# C=0.64, best accuracy on train (0.7712) and val (0.6450)
# C=0.65, best accuracy on train (0.7844) and val (0.6475)
# C=0.66, best accuracy on train (0.7750) and val (0.6375)
# C=0.67, best accuracy on train (0.7756) and val (0.6475)
# C=0.6799999999999999, best accuracy on train (0.7606) and val (0.6400)
# C=0.69, best accuracy on train (0.7775) and val (0.6450)
# C=0.7, best accuracy on train (0.7800) and val (0.6425)
# C=0.71, best accuracy on train (0.7825) and val (0.6425)
# C=0.72, best accuracy on train (0.7825) and val (0.6425)
# C=0.73, best accuracy on train (0.7794) and val (0.6375)
# C=0.74, best accuracy on train (0.7837) and val (0.6450)
# C=0.75, best accuracy on train (0.7837) and val (0.6400)
# C=0.76, best accuracy on train (0.7831) and val (0.6400)
# C=0.77, best accuracy on train (0.7894) and val (0.6375)
# C=0.78, best accuracy on train (0.7825) and val (0.6450)
# C=0.79, best accuracy on train (0.7919) and val (0.6425)
# C=0.8, best accuracy on train (0.7956) and val (0.6425)
# C=0.8099999999999999, best accuracy on train (0.7906) and val (0.6475)
# C=0.82, best accuracy on train (0.7887) and val (0.6450)
# C=0.83, best accuracy on train (0.7887) and val (0.6425)
# C=0.84, best accuracy on train (0.7950) and val (0.6500)
# C=0.85, best accuracy on train (0.7931) and val (0.6500)
# C=0.86, best accuracy on train (0.8006) and val (0.6500)
# C=0.87, best accuracy on train (0.7994) and val (0.6500)
# C=0.88, best accuracy on train (0.8006) and val (0.6500)
# C=0.89, best accuracy on train (0.7987) and val (0.6500)
# C=0.9, best accuracy on train (0.8000) and val (0.6525)
# C=0.91, best accuracy on train (0.8075) and val (0.6500)
# C=0.92, best accuracy on train (0.8081) and val (0.6475)
# C=0.93, best accuracy on train (0.8050) and val (0.6425)
# C=0.94, best accuracy on train (0.7963) and val (0.6400)
# C=0.95, best accuracy on train (0.8119) and val (0.6475)
# C=0.96, best accuracy on train (0.7987) and val (0.6450)
# C=0.97, best accuracy on train (0.8037) and val (0.6450)
# C=0.98, best accuracy on train (0.8069) and val (0.6400)
# C=0.99, best accuracy on train (0.8025) and val (0.6400)
# C=1.0, best accuracy on train (0.7806) and val (0.6350)
# C=1.0, best accuracy on train (0.7806) and val (0.6350)
# C=1.5, best accuracy on train (0.8087) and val (0.6625)
# C=2.0, best accuracy on train (0.8413) and val (0.6400)
# C=2.5, best accuracy on train (0.8525) and val (0.6350)
# C=3.0, best accuracy on train (0.8650) and val (0.6325)
# C=3.5, best accuracy on train (0.8812) and val (0.6325)
# C=4.0, best accuracy on train (0.8962) and val (0.6225)
# C=4.5, best accuracy on train (0.8481) and val (0.6200)
# C=5.0, best accuracy on train (0.9038) and val (0.6200)
# C=5.5, best accuracy on train (0.9025) and val (0.6250)
# C=6.0, best accuracy on train (0.9069) and val (0.6200)
# C=6.5, best accuracy on train (0.9237) and val (0.6175)
# C=7.0, best accuracy on train (0.9237) and val (0.6125)
# C=7.5, best accuracy on train (0.7206) and val (0.6050)
# C=8.0, best accuracy on train (0.9269) and val (0.6100)
# C=8.5, best accuracy on train (0.9275) and val (0.6175)
# C=9.0, best accuracy on train (0.9437) and val (0.6075)
# C=9.5, best accuracy on train (0.7206) and val (0.6050)
# C=10.0, best accuracy on train (0.7206) and val (0.6050)
# Fold 4
# C=0.1, best accuracy on train (0.6625) and val (0.5825)
# C=0.11, best accuracy on train (0.6769) and val (0.6050)
# C=0.12000000000000001, best accuracy on train (0.6763) and val (0.6025)
# C=0.13, best accuracy on train (0.6781) and val (0.6025)
# C=0.14, best accuracy on train (0.6644) and val (0.6075)
# C=0.15000000000000002, best accuracy on train (0.6531) and val (0.6150)
# C=0.16, best accuracy on train (0.6625) and val (0.6150)
# C=0.17, best accuracy on train (0.6681) and val (0.6225)
# C=0.18, best accuracy on train (0.6725) and val (0.6225)
# C=0.19, best accuracy on train (0.6544) and val (0.6200)
# C=0.2, best accuracy on train (0.7013) and val (0.6200)
# C=0.21000000000000002, best accuracy on train (0.7031) and val (0.6200)
# C=0.22, best accuracy on train (0.7006) and val (0.6200)
# C=0.23, best accuracy on train (0.6925) and val (0.6200)
# C=0.24000000000000002, best accuracy on train (0.7144) and val (0.6225)
# C=0.25, best accuracy on train (0.6887) and val (0.6250)
# C=0.26, best accuracy on train (0.7250) and val (0.6225)
# C=0.27, best accuracy on train (0.6987) and val (0.6275)
# C=0.28, best accuracy on train (0.7075) and val (0.6300)
# C=0.29000000000000004, best accuracy on train (0.6869) and val (0.6225)
# C=0.30000000000000004, best accuracy on train (0.6987) and val (0.6275)
# C=0.31, best accuracy on train (0.7294) and val (0.6250)
# C=0.32, best accuracy on train (0.7113) and val (0.6325)
# C=0.33, best accuracy on train (0.7181) and val (0.6300)
# C=0.33999999999999997, best accuracy on train (0.7219) and val (0.6275)
# C=0.35, best accuracy on train (0.7250) and val (0.6325)
# C=0.36, best accuracy on train (0.6937) and val (0.6350)
# C=0.37, best accuracy on train (0.7006) and val (0.6275)
# C=0.38, best accuracy on train (0.7069) and val (0.6325)
# C=0.39, best accuracy on train (0.7412) and val (0.6325)
# C=0.4, best accuracy on train (0.7438) and val (0.6375)
# C=0.41000000000000003, best accuracy on train (0.7469) and val (0.6350)
# C=0.42000000000000004, best accuracy on train (0.7212) and val (0.6275)
# C=0.43000000000000005, best accuracy on train (0.7450) and val (0.6325)
# C=0.44000000000000006, best accuracy on train (0.7325) and val (0.6400)
# C=0.45000000000000007, best accuracy on train (0.7500) and val (0.6425)
# C=0.45999999999999996, best accuracy on train (0.7519) and val (0.6425)
# C=0.47, best accuracy on train (0.7544) and val (0.6425)
# C=0.48, best accuracy on train (0.7569) and val (0.6400)
# C=0.49, best accuracy on train (0.7581) and val (0.6375)
# C=0.5, best accuracy on train (0.7594) and val (0.6350)
# C=0.51, best accuracy on train (0.7600) and val (0.6350)
# C=0.52, best accuracy on train (0.7725) and val (0.6375)
# C=0.53, best accuracy on train (0.7756) and val (0.6450)
# C=0.54, best accuracy on train (0.7775) and val (0.6400)
# C=0.55, best accuracy on train (0.7681) and val (0.6400)
# C=0.56, best accuracy on train (0.7681) and val (0.6375)
# C=0.5700000000000001, best accuracy on train (0.7812) and val (0.6375)
# C=0.58, best accuracy on train (0.7631) and val (0.6325)
# C=0.59, best accuracy on train (0.7656) and val (0.6350)
# C=0.6, best accuracy on train (0.7662) and val (0.6375)
# C=0.61, best accuracy on train (0.7662) and val (0.6375)
# C=0.62, best accuracy on train (0.7650) and val (0.6425)
# C=0.63, best accuracy on train (0.7506) and val (0.6450)
# C=0.64, best accuracy on train (0.7512) and val (0.6450)
# C=0.65, best accuracy on train (0.7531) and val (0.6425)
# C=0.66, best accuracy on train (0.7519) and val (0.6400)
# C=0.67, best accuracy on train (0.7556) and val (0.6400)
# C=0.6799999999999999, best accuracy on train (0.7700) and val (0.6425)
# C=0.69, best accuracy on train (0.7569) and val (0.6400)
# C=0.7, best accuracy on train (0.7725) and val (0.6450)
# C=0.71, best accuracy on train (0.7706) and val (0.6525)
# C=0.72, best accuracy on train (0.7750) and val (0.6500)
# C=0.73, best accuracy on train (0.7762) and val (0.6500)
# C=0.74, best accuracy on train (0.7775) and val (0.6525)
# C=0.75, best accuracy on train (0.7769) and val (0.6500)
# C=0.76, best accuracy on train (0.7794) and val (0.6475)
# C=0.77, best accuracy on train (0.7781) and val (0.6475)
# C=0.78, best accuracy on train (0.7875) and val (0.6500)
# C=0.79, best accuracy on train (0.7875) and val (0.6525)
# C=0.8, best accuracy on train (0.7887) and val (0.6475)
# C=0.8099999999999999, best accuracy on train (0.7825) and val (0.6575)
# C=0.82, best accuracy on train (0.7825) and val (0.6500)
# C=0.83, best accuracy on train (0.7856) and val (0.6500)
# C=0.84, best accuracy on train (0.7831) and val (0.6500)
# C=0.85, best accuracy on train (0.7819) and val (0.6550)
# C=0.86, best accuracy on train (0.7869) and val (0.6600)
# C=0.87, best accuracy on train (0.7875) and val (0.6575)
# C=0.88, best accuracy on train (0.7819) and val (0.6525)
# C=0.89, best accuracy on train (0.7825) and val (0.6475)
# C=0.9, best accuracy on train (0.7894) and val (0.6550)
# C=0.91, best accuracy on train (0.7887) and val (0.6500)
# C=0.92, best accuracy on train (0.7875) and val (0.6475)
# C=0.93, best accuracy on train (0.7906) and val (0.6500)
# C=0.94, best accuracy on train (0.7856) and val (0.6525)
# C=0.95, best accuracy on train (0.7906) and val (0.6675)
# C=0.96, best accuracy on train (0.7812) and val (0.6525)
# C=0.97, best accuracy on train (0.7981) and val (0.6575)
# C=0.98, best accuracy on train (0.7931) and val (0.6500)
# C=0.99, best accuracy on train (0.7887) and val (0.6525)
# C=1.0, best accuracy on train (0.7937) and val (0.6550)
# C=1.0, best accuracy on train (0.7937) and val (0.6550)
# C=1.5, best accuracy on train (0.8256) and val (0.6600)
# C=2.0, best accuracy on train (0.8494) and val (0.6650)
# C=2.5, best accuracy on train (0.8556) and val (0.6600)
# C=3.0, best accuracy on train (0.8762) and val (0.6550)
# C=3.5, best accuracy on train (0.8731) and val (0.6550)
# C=4.0, best accuracy on train (0.8931) and val (0.6475)
# C=4.5, best accuracy on train (0.8869) and val (0.6500)
# C=5.0, best accuracy on train (0.8900) and val (0.6525)
# C=5.5, best accuracy on train (0.9000) and val (0.6425)
# C=6.0, best accuracy on train (0.9100) and val (0.6375)
# C=6.5, best accuracy on train (0.9106) and val (0.6425)
# C=7.0, best accuracy on train (0.9131) and val (0.6450)
# C=7.5, best accuracy on train (0.9187) and val (0.6400)
# C=8.0, best accuracy on train (0.8906) and val (0.6400)
# C=8.5, best accuracy on train (0.8962) and val (0.6400)
# C=9.0, best accuracy on train (0.9081) and val (0.6300)
# C=9.5, best accuracy on train (0.9331) and val (0.6400)
# C=10.0, best accuracy on train (0.9169) and val (0.6275)
# Fold 5
# C=0.1, best accuracy on train (0.6625) and val (0.5575)
# C=0.11, best accuracy on train (0.6831) and val (0.6000)
# C=0.12000000000000001, best accuracy on train (0.6856) and val (0.5775)
# C=0.13, best accuracy on train (0.6906) and val (0.6025)
# C=0.14, best accuracy on train (0.6844) and val (0.6050)
# C=0.15000000000000002, best accuracy on train (0.6737) and val (0.6075)
# C=0.16, best accuracy on train (0.6950) and val (0.6150)
# C=0.17, best accuracy on train (0.6956) and val (0.6175)
# C=0.18, best accuracy on train (0.6925) and val (0.6175)
# C=0.19, best accuracy on train (0.6900) and val (0.6200)
# C=0.2, best accuracy on train (0.7044) and val (0.6225)
# C=0.21000000000000002, best accuracy on train (0.7094) and val (0.6200)
# C=0.22, best accuracy on train (0.6950) and val (0.6150)
# C=0.23, best accuracy on train (0.6931) and val (0.6100)
# C=0.24000000000000002, best accuracy on train (0.7156) and val (0.6175)
# C=0.25, best accuracy on train (0.7094) and val (0.6175)
# C=0.26, best accuracy on train (0.7125) and val (0.6175)
# C=0.27, best accuracy on train (0.7163) and val (0.6175)
# C=0.28, best accuracy on train (0.7194) and val (0.6275)
# C=0.29000000000000004, best accuracy on train (0.7219) and val (0.6250)
# C=0.30000000000000004, best accuracy on train (0.7219) and val (0.6175)
# C=0.31, best accuracy on train (0.7275) and val (0.6225)
# C=0.32, best accuracy on train (0.7388) and val (0.6200)
# C=0.33, best accuracy on train (0.7325) and val (0.6250)
# C=0.33999999999999997, best accuracy on train (0.7325) and val (0.6250)
# C=0.35, best accuracy on train (0.7394) and val (0.6225)
# C=0.36, best accuracy on train (0.7356) and val (0.6225)
# C=0.37, best accuracy on train (0.7412) and val (0.6250)
# C=0.38, best accuracy on train (0.7425) and val (0.6250)
# C=0.39, best accuracy on train (0.7462) and val (0.6225)
# C=0.4, best accuracy on train (0.7231) and val (0.6200)
# C=0.41000000000000003, best accuracy on train (0.7275) and val (0.6175)
# C=0.42000000000000004, best accuracy on train (0.7056) and val (0.6175)
# C=0.43000000000000005, best accuracy on train (0.7106) and val (0.6200)
# C=0.44000000000000006, best accuracy on train (0.7519) and val (0.6200)
# C=0.45000000000000007, best accuracy on train (0.7144) and val (0.6125)
# C=0.45999999999999996, best accuracy on train (0.7150) and val (0.6225)
# C=0.47, best accuracy on train (0.7181) and val (0.6225)
# C=0.48, best accuracy on train (0.7200) and val (0.6275)
# C=0.49, best accuracy on train (0.7262) and val (0.6175)
# C=0.5, best accuracy on train (0.7275) and val (0.6175)
# C=0.51, best accuracy on train (0.7300) and val (0.6150)
# C=0.52, best accuracy on train (0.7338) and val (0.6100)
# C=0.53, best accuracy on train (0.7700) and val (0.6225)
# C=0.54, best accuracy on train (0.7638) and val (0.6200)
# C=0.55, best accuracy on train (0.7338) and val (0.6075)
# C=0.56, best accuracy on train (0.7656) and val (0.6150)
# C=0.5700000000000001, best accuracy on train (0.7712) and val (0.6250)
# C=0.58, best accuracy on train (0.7719) and val (0.6075)
# C=0.59, best accuracy on train (0.7612) and val (0.6175)
# C=0.6, best accuracy on train (0.7756) and val (0.6225)
# C=0.61, best accuracy on train (0.7756) and val (0.6225)
# C=0.62, best accuracy on train (0.7775) and val (0.6250)
# C=0.63, best accuracy on train (0.7725) and val (0.6225)
# C=0.64, best accuracy on train (0.7725) and val (0.6175)
# C=0.65, best accuracy on train (0.7788) and val (0.6175)
# C=0.66, best accuracy on train (0.7769) and val (0.6250)
# C=0.67, best accuracy on train (0.7781) and val (0.6225)
# C=0.6799999999999999, best accuracy on train (0.7788) and val (0.6200)
# C=0.69, best accuracy on train (0.7812) and val (0.6225)
# C=0.7, best accuracy on train (0.7812) and val (0.6150)
# C=0.71, best accuracy on train (0.7837) and val (0.6200)
# C=0.72, best accuracy on train (0.7688) and val (0.6175)
# C=0.73, best accuracy on train (0.7812) and val (0.6250)
# C=0.74, best accuracy on train (0.7887) and val (0.6125)
# C=0.75, best accuracy on train (0.7806) and val (0.6200)
# C=0.76, best accuracy on train (0.7744) and val (0.6300)
# C=0.77, best accuracy on train (0.7788) and val (0.6225)
# C=0.78, best accuracy on train (0.7794) and val (0.6250)
# C=0.79, best accuracy on train (0.7825) and val (0.6225)
# C=0.8, best accuracy on train (0.7794) and val (0.6250)
# C=0.8099999999999999, best accuracy on train (0.7869) and val (0.6125)
# C=0.82, best accuracy on train (0.7925) and val (0.6350)
# C=0.83, best accuracy on train (0.7881) and val (0.6250)
# C=0.84, best accuracy on train (0.7769) and val (0.6175)
# C=0.85, best accuracy on train (0.7856) and val (0.6175)
# C=0.86, best accuracy on train (0.7987) and val (0.6250)
# C=0.87, best accuracy on train (0.8025) and val (0.6250)
# C=0.88, best accuracy on train (0.7975) and val (0.6075)
# C=0.89, best accuracy on train (0.7781) and val (0.6200)
# C=0.9, best accuracy on train (0.7825) and val (0.6275)
# C=0.91, best accuracy on train (0.7956) and val (0.6175)
# C=0.92, best accuracy on train (0.7963) and val (0.6100)
# C=0.93, best accuracy on train (0.8006) and val (0.6225)
# C=0.94, best accuracy on train (0.7869) and val (0.6200)
# C=0.95, best accuracy on train (0.7850) and val (0.6225)
# C=0.96, best accuracy on train (0.8106) and val (0.6275)
# C=0.97, best accuracy on train (0.8006) and val (0.6175)
# C=0.98, best accuracy on train (0.8037) and val (0.6275)
# C=0.99, best accuracy on train (0.8063) and val (0.6150)
# C=1.0, best accuracy on train (0.7956) and val (0.6175)
# C=1.0, best accuracy on train (0.7956) and val (0.6175)
# C=1.5, best accuracy on train (0.8287) and val (0.6325)
# C=2.0, best accuracy on train (0.8387) and val (0.6325)
# C=2.5, best accuracy on train (0.8438) and val (0.6150)
# C=3.0, best accuracy on train (0.8387) and val (0.6000)
# C=3.5, best accuracy on train (0.8612) and val (0.5975)
# C=4.0, best accuracy on train (0.8844) and val (0.5900)
# C=4.5, best accuracy on train (0.8575) and val (0.5900)
# C=5.0, best accuracy on train (0.8894) and val (0.5925)
# C=5.5, best accuracy on train (0.8525) and val (0.6025)
# C=6.0, best accuracy on train (0.8575) and val (0.5875)
# C=6.5, best accuracy on train (0.8994) and val (0.5750)
# C=7.0, best accuracy on train (0.9194) and val (0.5750)
# C=7.5, best accuracy on train (0.9156) and val (0.5750)
# C=8.0, best accuracy on train (0.8387) and val (0.5800)
# C=8.5, best accuracy on train (0.9231) and val (0.5925)
# C=9.0, best accuracy on train (0.9169) and val (0.5825)
# C=9.5, best accuracy on train (0.8788) and val (0.5875)
# C=10.0, best accuracy on train (0.8431) and val (0.5775)
# Best constant C: 1.5, accuracy on val 0.6480
# /Users/bfiliot/Desktop/MVA/KERNEL/Kernel_methods_MVA/SVM.py:218: ResourceWarning: unclosed file <_io.BufferedWriter name='./Data/CrossVals/cv_C_SVM_MM61_k1_max_iter500_solver_BFGS_full.pkl'>
#   open(os.path.join('./Data/CrossVals/', pickleName), 'wb'))
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# Fold 1
# C=0.1, best accuracy on train (0.7269) and val (0.6475)
# C=0.11, best accuracy on train (0.7250) and val (0.6450)
# C=0.12000000000000001, best accuracy on train (0.7300) and val (0.6475)
# C=0.13, best accuracy on train (0.7356) and val (0.6525)
# C=0.14, best accuracy on train (0.7319) and val (0.6550)
# C=0.15000000000000002, best accuracy on train (0.7375) and val (0.6550)
# C=0.16, best accuracy on train (0.7225) and val (0.6550)
# C=0.17, best accuracy on train (0.7175) and val (0.6575)
# C=0.18, best accuracy on train (0.7144) and val (0.6550)
# C=0.19, best accuracy on train (0.7506) and val (0.6575)
# C=0.2, best accuracy on train (0.7525) and val (0.6550)
# C=0.21000000000000002, best accuracy on train (0.7531) and val (0.6550)
# C=0.22, best accuracy on train (0.7063) and val (0.6600)
# C=0.23, best accuracy on train (0.7087) and val (0.6600)
# C=0.24000000000000002, best accuracy on train (0.7050) and val (0.6575)
# C=0.25, best accuracy on train (0.7556) and val (0.6600)
# C=0.26, best accuracy on train (0.7562) and val (0.6625)
# C=0.27, best accuracy on train (0.7569) and val (0.6650)
# C=0.28, best accuracy on train (0.7581) and val (0.6625)
# C=0.29000000000000004, best accuracy on train (0.7625) and val (0.6675)
# C=0.30000000000000004, best accuracy on train (0.7612) and val (0.6675)
# C=0.31, best accuracy on train (0.7656) and val (0.6625)
# C=0.32, best accuracy on train (0.7688) and val (0.6650)
# C=0.33, best accuracy on train (0.7688) and val (0.6675)
# C=0.33999999999999997, best accuracy on train (0.7750) and val (0.6650)
# C=0.35, best accuracy on train (0.7762) and val (0.6675)
# C=0.36, best accuracy on train (0.7744) and val (0.6650)
# C=0.37, best accuracy on train (0.7800) and val (0.6625)
# C=0.38, best accuracy on train (0.7831) and val (0.6600)
# C=0.39, best accuracy on train (0.7850) and val (0.6675)
# C=0.4, best accuracy on train (0.7837) and val (0.6625)
# C=0.41000000000000003, best accuracy on train (0.7869) and val (0.6625)
# C=0.42000000000000004, best accuracy on train (0.7794) and val (0.6600)
# C=0.43000000000000005, best accuracy on train (0.7906) and val (0.6600)
# C=0.44000000000000006, best accuracy on train (0.7913) and val (0.6550)
# C=0.45000000000000007, best accuracy on train (0.7913) and val (0.6600)
# C=0.45999999999999996, best accuracy on train (0.7887) and val (0.6625)
# C=0.47, best accuracy on train (0.7825) and val (0.6625)
# C=0.48, best accuracy on train (0.7819) and val (0.6625)
# C=0.49, best accuracy on train (0.7956) and val (0.6650)
# C=0.5, best accuracy on train (0.7812) and val (0.6625)
# C=0.51, best accuracy on train (0.7819) and val (0.6650)
# C=0.52, best accuracy on train (0.7812) and val (0.6625)
# C=0.53, best accuracy on train (0.7794) and val (0.6625)
# C=0.54, best accuracy on train (0.8113) and val (0.6625)
# C=0.55, best accuracy on train (0.8044) and val (0.6600)
# C=0.56, best accuracy on train (0.8100) and val (0.6625)
# C=0.5700000000000001, best accuracy on train (0.7756) and val (0.6625)
# C=0.58, best accuracy on train (0.7744) and val (0.6650)
# C=0.59, best accuracy on train (0.7700) and val (0.6700)
# C=0.6, best accuracy on train (0.7731) and val (0.6675)
# C=0.61, best accuracy on train (0.7731) and val (0.6650)
# C=0.62, best accuracy on train (0.8163) and val (0.6625)
# C=0.63, best accuracy on train (0.7712) and val (0.6625)
# C=0.64, best accuracy on train (0.7738) and val (0.6675)
# C=0.65, best accuracy on train (0.7725) and val (0.6675)
# C=0.66, best accuracy on train (0.7725) and val (0.6675)
# C=0.67, best accuracy on train (0.7712) and val (0.6650)
# C=0.6799999999999999, best accuracy on train (0.8250) and val (0.6625)
# C=0.69, best accuracy on train (0.8263) and val (0.6600)
# C=0.7, best accuracy on train (0.8306) and val (0.6575)
# C=0.71, best accuracy on train (0.8244) and val (0.6650)
# C=0.72, best accuracy on train (0.8275) and val (0.6650)
# C=0.73, best accuracy on train (0.7331) and val (0.6650)
# C=0.74, best accuracy on train (0.8131) and val (0.6650)
# C=0.75, best accuracy on train (0.8331) and val (0.6700)
# C=0.76, best accuracy on train (0.8387) and val (0.6650)
# C=0.77, best accuracy on train (0.8356) and val (0.6625)
# C=0.78, best accuracy on train (0.8325) and val (0.6650)
# C=0.79, best accuracy on train (0.7469) and val (0.6725)
# C=0.8, best accuracy on train (0.8306) and val (0.6700)
# C=0.8099999999999999, best accuracy on train (0.8363) and val (0.6625)
# C=0.82, best accuracy on train (0.8381) and val (0.6675)
# C=0.83, best accuracy on train (0.8438) and val (0.6700)
# C=0.84, best accuracy on train (0.8469) and val (0.6650)
# C=0.85, best accuracy on train (0.8425) and val (0.6650)
# C=0.86, best accuracy on train (0.8450) and val (0.6650)
# C=0.87, best accuracy on train (0.8231) and val (0.6650)
# C=0.88, best accuracy on train (0.8225) and val (0.6675)
# C=0.89, best accuracy on train (0.8300) and val (0.6650)
# C=0.9, best accuracy on train (0.8494) and val (0.6750)
# C=0.91, best accuracy on train (0.8475) and val (0.6650)
# C=0.92, best accuracy on train (0.8469) and val (0.6700)
# C=0.93, best accuracy on train (0.8488) and val (0.6775)
# C=0.94, best accuracy on train (0.8488) and val (0.6700)
# C=0.95, best accuracy on train (0.8519) and val (0.6675)
# C=0.96, best accuracy on train (0.8481) and val (0.6725)
# C=0.97, best accuracy on train (0.8525) and val (0.6750)
# C=0.98, best accuracy on train (0.8519) and val (0.6775)
# C=0.99, best accuracy on train (0.8506) and val (0.6650)
# C=1.0, best accuracy on train (0.8494) and val (0.6650)
# C=1.0, best accuracy on train (0.8494) and val (0.6650)
# C=1.5, best accuracy on train (0.8656) and val (0.6825)
# C=2.0, best accuracy on train (0.8819) and val (0.6775)
# C=2.5, best accuracy on train (0.9062) and val (0.6825)
# C=3.0, best accuracy on train (0.9194) and val (0.6875)
# C=3.5, best accuracy on train (0.9181) and val (0.6925)
# C=4.0, best accuracy on train (0.9269) and val (0.7025)
# C=4.5, best accuracy on train (0.9413) and val (0.7025)
# C=5.0, best accuracy on train (0.9513) and val (0.7075)
# C=5.5, best accuracy on train (0.9500) and val (0.7050)
# C=6.0, best accuracy on train (0.9563) and val (0.7000)
# C=6.5, best accuracy on train (0.9575) and val (0.6950)
# C=7.0, best accuracy on train (0.9575) and val (0.6950)
# C=7.5, best accuracy on train (0.9656) and val (0.6900)
# C=8.0, best accuracy on train (0.9669) and val (0.6975)
# C=8.5, best accuracy on train (0.9706) and val (0.6875)
# C=9.0, best accuracy on train (0.9631) and val (0.6900)
# C=9.5, best accuracy on train (0.9738) and val (0.6875)
# C=10.0, best accuracy on train (0.9675) and val (0.6850)
# Fold 2
# C=0.1, best accuracy on train (0.7169) and val (0.6400)
# C=0.11, best accuracy on train (0.7175) and val (0.6500)
# C=0.12000000000000001, best accuracy on train (0.7231) and val (0.6575)
# C=0.13, best accuracy on train (0.7269) and val (0.6625)
# C=0.14, best accuracy on train (0.7306) and val (0.6600)
# C=0.15000000000000002, best accuracy on train (0.7306) and val (0.6725)
# C=0.16, best accuracy on train (0.7362) and val (0.6750)
# C=0.17, best accuracy on train (0.7400) and val (0.6825)
# C=0.18, best accuracy on train (0.7444) and val (0.6850)
# C=0.19, best accuracy on train (0.7494) and val (0.6850)
# C=0.2, best accuracy on train (0.7512) and val (0.6875)
# C=0.21000000000000002, best accuracy on train (0.7556) and val (0.6900)
# C=0.22, best accuracy on train (0.7594) and val (0.6900)
# C=0.23, best accuracy on train (0.7606) and val (0.6875)
# C=0.24000000000000002, best accuracy on train (0.7638) and val (0.6875)
# C=0.25, best accuracy on train (0.7638) and val (0.6850)
# C=0.26, best accuracy on train (0.7650) and val (0.6875)
# C=0.27, best accuracy on train (0.7700) and val (0.6900)
# C=0.28, best accuracy on train (0.7725) and val (0.6875)
# C=0.29000000000000004, best accuracy on train (0.7775) and val (0.6925)
# C=0.30000000000000004, best accuracy on train (0.7744) and val (0.6925)
# C=0.31, best accuracy on train (0.7781) and val (0.6925)
# C=0.32, best accuracy on train (0.7781) and val (0.6900)
# C=0.33, best accuracy on train (0.7725) and val (0.6875)
# C=0.33999999999999997, best accuracy on train (0.7819) and val (0.6875)
# C=0.35, best accuracy on train (0.7856) and val (0.6925)
# C=0.36, best accuracy on train (0.7781) and val (0.6900)
# C=0.37, best accuracy on train (0.7781) and val (0.6900)
# C=0.38, best accuracy on train (0.7925) and val (0.6925)
# C=0.39, best accuracy on train (0.7950) and val (0.6925)
# C=0.4, best accuracy on train (0.7919) and val (0.7000)
# C=0.41000000000000003, best accuracy on train (0.7950) and val (0.6975)
# C=0.42000000000000004, best accuracy on train (0.7987) and val (0.6975)
# C=0.43000000000000005, best accuracy on train (0.7975) and val (0.6950)
# C=0.44000000000000006, best accuracy on train (0.7869) and val (0.7000)
# C=0.45000000000000007, best accuracy on train (0.7994) and val (0.7000)
# C=0.45999999999999996, best accuracy on train (0.7681) and val (0.7025)
# C=0.47, best accuracy on train (0.7669) and val (0.7025)
# C=0.48, best accuracy on train (0.7688) and val (0.7025)
# C=0.49, best accuracy on train (0.8019) and val (0.6975)
# C=0.5, best accuracy on train (0.8081) and val (0.7050)
# C=0.51, best accuracy on train (0.7706) and val (0.7025)
# C=0.52, best accuracy on train (0.7681) and val (0.7100)
# C=0.53, best accuracy on train (0.7669) and val (0.7100)
# C=0.54, best accuracy on train (0.7662) and val (0.7100)
# C=0.55, best accuracy on train (0.7856) and val (0.7100)
# C=0.56, best accuracy on train (0.7675) and val (0.7100)
# C=0.5700000000000001, best accuracy on train (0.7656) and val (0.7075)
# C=0.58, best accuracy on train (0.8163) and val (0.7125)
# C=0.59, best accuracy on train (0.7650) and val (0.7125)
# C=0.6, best accuracy on train (0.7662) and val (0.7100)
# C=0.61, best accuracy on train (0.7675) and val (0.7100)
# C=0.62, best accuracy on train (0.7681) and val (0.7075)
# C=0.63, best accuracy on train (0.7681) and val (0.7075)
# C=0.64, best accuracy on train (0.8225) and val (0.7150)
# C=0.65, best accuracy on train (0.7688) and val (0.7175)
# C=0.66, best accuracy on train (0.7650) and val (0.7125)
# C=0.67, best accuracy on train (0.7656) and val (0.7075)
# C=0.6799999999999999, best accuracy on train (0.7662) and val (0.7075)
# C=0.69, best accuracy on train (0.8275) and val (0.7150)
# C=0.7, best accuracy on train (0.7662) and val (0.7150)
# C=0.71, best accuracy on train (0.7656) and val (0.7100)
# C=0.72, best accuracy on train (0.8250) and val (0.7125)
# C=0.73, best accuracy on train (0.7656) and val (0.7125)
# C=0.74, best accuracy on train (0.8263) and val (0.7125)
# C=0.75, best accuracy on train (0.8275) and val (0.7125)
# C=0.76, best accuracy on train (0.8213) and val (0.7150)
# C=0.77, best accuracy on train (0.8225) and val (0.7075)
# C=0.78, best accuracy on train (0.6281) and val (0.6250)
# C=0.79, best accuracy on train (0.6275) and val (0.6250)
# C=0.8, best accuracy on train (0.6281) and val (0.6250)
# C=0.8099999999999999, best accuracy on train (0.6306) and val (0.6225)
# C=0.82, best accuracy on train (0.6331) and val (0.6225)
# C=0.83, best accuracy on train (0.6331) and val (0.6225)
# C=0.84, best accuracy on train (0.6350) and val (0.6225)
# C=0.85, best accuracy on train (0.8031) and val (0.7175)
# C=0.86, best accuracy on train (0.8369) and val (0.7125)
# C=0.87, best accuracy on train (0.8294) and val (0.7250)
# C=0.88, best accuracy on train (0.8331) and val (0.7225)
# C=0.89, best accuracy on train (0.8187) and val (0.7275)
# C=0.9, best accuracy on train (0.8506) and val (0.7150)
# C=0.91, best accuracy on train (0.8387) and val (0.7350)
# C=0.92, best accuracy on train (0.8425) and val (0.7150)
# C=0.93, best accuracy on train (0.8337) and val (0.7250)
# C=0.94, best accuracy on train (0.7631) and val (0.7100)
# C=0.95, best accuracy on train (0.8450) and val (0.7200)
# C=0.96, best accuracy on train (0.8413) and val (0.7225)
# C=0.97, best accuracy on train (0.8400) and val (0.7325)
# C=0.98, best accuracy on train (0.8438) and val (0.7275)
# C=0.99, best accuracy on train (0.8406) and val (0.7200)
# C=1.0, best accuracy on train (0.8400) and val (0.7275)
# C=1.0, best accuracy on train (0.8400) and val (0.7275)
# C=1.5, best accuracy on train (0.8681) and val (0.7300)
# C=2.0, best accuracy on train (0.8794) and val (0.7550)
# C=2.5, best accuracy on train (0.8975) and val (0.7575)
# C=3.0, best accuracy on train (0.9056) and val (0.7600)
# C=3.5, best accuracy on train (0.9094) and val (0.7550)
# C=4.0, best accuracy on train (0.9269) and val (0.7625)
# C=4.5, best accuracy on train (0.9337) and val (0.7675)
# C=5.0, best accuracy on train (0.9356) and val (0.7575)
# C=5.5, best accuracy on train (0.9431) and val (0.7600)
# C=6.0, best accuracy on train (0.9319) and val (0.7600)
# C=6.5, best accuracy on train (0.9444) and val (0.7575)
# C=7.0, best accuracy on train (0.9581) and val (0.7550)
# C=7.5, best accuracy on train (0.9413) and val (0.7500)
# C=8.0, best accuracy on train (0.9644) and val (0.7525)
# C=8.5, best accuracy on train (0.9606) and val (0.7550)
# C=9.0, best accuracy on train (0.9581) and val (0.7675)
# C=9.5, best accuracy on train (0.9631) and val (0.7575)
# C=10.0, best accuracy on train (0.9725) and val (0.7525)
# Fold 3
# C=0.1, best accuracy on train (0.6969) and val (0.6650)
# C=0.11, best accuracy on train (0.7106) and val (0.6750)
# C=0.12000000000000001, best accuracy on train (0.7256) and val (0.6675)
# C=0.13, best accuracy on train (0.7269) and val (0.6800)
# C=0.14, best accuracy on train (0.7306) and val (0.6825)
# C=0.15000000000000002, best accuracy on train (0.7331) and val (0.6900)
# C=0.16, best accuracy on train (0.7325) and val (0.6900)
# C=0.17, best accuracy on train (0.7412) and val (0.6900)
# C=0.18, best accuracy on train (0.7356) and val (0.6950)
# C=0.19, best accuracy on train (0.7425) and val (0.6900)
# C=0.2, best accuracy on train (0.7475) and val (0.6950)
# C=0.21000000000000002, best accuracy on train (0.7450) and val (0.7000)
# C=0.22, best accuracy on train (0.7494) and val (0.7025)
# C=0.23, best accuracy on train (0.7512) and val (0.7025)
# C=0.24000000000000002, best accuracy on train (0.7550) and val (0.7100)
# C=0.25, best accuracy on train (0.7600) and val (0.7050)
# C=0.26, best accuracy on train (0.7300) and val (0.6975)
# C=0.27, best accuracy on train (0.7512) and val (0.7000)
# C=0.28, best accuracy on train (0.7506) and val (0.7100)
# C=0.29000000000000004, best accuracy on train (0.7600) and val (0.7100)
# C=0.30000000000000004, best accuracy on train (0.7681) and val (0.7000)
# C=0.31, best accuracy on train (0.7631) and val (0.7075)
# C=0.32, best accuracy on train (0.7631) and val (0.7075)
# C=0.33, best accuracy on train (0.7625) and val (0.7125)
# C=0.33999999999999997, best accuracy on train (0.7625) and val (0.7200)
# C=0.35, best accuracy on train (0.7625) and val (0.7175)
# C=0.36, best accuracy on train (0.7638) and val (0.7200)
# C=0.37, best accuracy on train (0.7638) and val (0.7250)
# C=0.38, best accuracy on train (0.7694) and val (0.7250)
# C=0.39, best accuracy on train (0.7706) and val (0.7225)
# C=0.4, best accuracy on train (0.7738) and val (0.7225)
# C=0.41000000000000003, best accuracy on train (0.7712) and val (0.7275)
# C=0.42000000000000004, best accuracy on train (0.7731) and val (0.7225)
# C=0.43000000000000005, best accuracy on train (0.7869) and val (0.7200)
# C=0.44000000000000006, best accuracy on train (0.7931) and val (0.7100)
# ...
# C=0.73, best accuracy on train (0.7581) and val (0.6600)
# C=0.74, best accuracy on train (0.7681) and val (0.6575)
# C=0.75, best accuracy on train (0.7600) and val (0.6625)
# C=0.76, best accuracy on train (0.7556) and val (0.6550)
# C=0.77, best accuracy on train (0.7550) and val (0.6750)
# C=0.78, best accuracy on train (0.7544) and val (0.6525)
# C=0.79, best accuracy on train (0.7525) and val (0.6650)
# C=0.8, best accuracy on train (0.7650) and val (0.6625)
# C=0.8099999999999999, best accuracy on train (0.7556) and val (0.6775)
# C=0.82, best accuracy on train (0.7769) and val (0.6675)
# C=0.83, best accuracy on train (0.7744) and val (0.6625)
# C=0.84, best accuracy on train (0.7419) and val (0.6700)
# C=0.85, best accuracy on train (0.7669) and val (0.6625)
# C=0.86, best accuracy on train (0.7494) and val (0.6650)
# C=0.87, best accuracy on train (0.7538) and val (0.6675)
# C=0.88, best accuracy on train (0.7506) and val (0.6625)
# C=0.89, best accuracy on train (0.7519) and val (0.6650)
# C=0.9, best accuracy on train (0.7512) and val (0.6675)
# C=0.91, best accuracy on train (0.7506) and val (0.6650)
# C=0.92, best accuracy on train (0.7669) and val (0.6750)
# C=0.93, best accuracy on train (0.7812) and val (0.6750)
# C=0.94, best accuracy on train (0.7725) and val (0.6700)
# C=0.95, best accuracy on train (0.7712) and val (0.6600)
# C=0.96, best accuracy on train (0.7844) and val (0.6550)
# C=0.97, best accuracy on train (0.7781) and val (0.6600)
# C=0.98, best accuracy on train (0.7863) and val (0.6625)
# C=0.99, best accuracy on train (0.7775) and val (0.6725)
# C=1.0, best accuracy on train (0.7837) and val (0.6750)
# C=1.0, best accuracy on train (0.7837) and val (0.6750)
# C=1.5, best accuracy on train (0.8231) and val (0.6575)
# C=2.0, best accuracy on train (0.8331) and val (0.6600)
# C=2.5, best accuracy on train (0.8500) and val (0.6475)
# C=3.0, best accuracy on train (0.8631) and val (0.6575)
# C=3.5, best accuracy on train (0.8650) and val (0.6475)
# C=4.0, best accuracy on train (0.8706) and val (0.6675)
# C=4.5, best accuracy on train (0.8969) and val (0.6475)
# C=5.0, best accuracy on train (0.9075) and val (0.6500)
# C=5.5, best accuracy on train (0.8638) and val (0.6550)
# C=6.0, best accuracy on train (0.9131) and val (0.6550)
# C=6.5, best accuracy on train (0.9219) and val (0.6550)
# C=7.0, best accuracy on train (0.9206) and val (0.6575)
# C=7.5, best accuracy on train (0.9269) and val (0.6600)
# C=8.0, best accuracy on train (0.9275) and val (0.6575)
# C=8.5, best accuracy on train (0.8525) and val (0.6700)
# C=9.0, best accuracy on train (0.9356) and val (0.6550)
# C=9.5, best accuracy on train (0.9394) and val (0.6700)
# C=10.0, best accuracy on train (0.9481) and val (0.6550)
# Fold 4
# C=0.1, best accuracy on train (0.6294) and val (0.6275)
# C=0.11, best accuracy on train (0.6462) and val (0.6300)
# C=0.12000000000000001, best accuracy on train (0.6406) and val (0.6350)
# C=0.13, best accuracy on train (0.6419) and val (0.6300)
# C=0.14, best accuracy on train (0.6338) and val (0.6275)
# C=0.15000000000000002, best accuracy on train (0.6275) and val (0.6225)
# C=0.16, best accuracy on train (0.6200) and val (0.6325)
# C=0.17, best accuracy on train (0.6319) and val (0.6275)
# C=0.18, best accuracy on train (0.6438) and val (0.6475)
# C=0.19, best accuracy on train (0.6438) and val (0.6450)
# C=0.2, best accuracy on train (0.6412) and val (0.6500)
# C=0.21000000000000002, best accuracy on train (0.6525) and val (0.6425)
# C=0.22, best accuracy on train (0.6569) and val (0.6400)
# C=0.23, best accuracy on train (0.6506) and val (0.6475)
# C=0.24000000000000002, best accuracy on train (0.6550) and val (0.6550)
# C=0.25, best accuracy on train (0.6587) and val (0.6575)
# C=0.26, best accuracy on train (0.6581) and val (0.6550)
# C=0.27, best accuracy on train (0.6538) and val (0.6575)
# C=0.28, best accuracy on train (0.6644) and val (0.6575)
# C=0.29000000000000004, best accuracy on train (0.6637) and val (0.6525)
# C=0.30000000000000004, best accuracy on train (0.6600) and val (0.6525)
# C=0.31, best accuracy on train (0.6756) and val (0.6575)
# C=0.32, best accuracy on train (0.6681) and val (0.6575)
# C=0.33, best accuracy on train (0.6750) and val (0.6625)
# C=0.33999999999999997, best accuracy on train (0.6850) and val (0.6575)
# C=0.35, best accuracy on train (0.6488) and val (0.6550)
# C=0.36, best accuracy on train (0.6837) and val (0.6525)
# C=0.37, best accuracy on train (0.7125) and val (0.6625)
# C=0.38, best accuracy on train (0.7256) and val (0.6600)
# C=0.39, best accuracy on train (0.7181) and val (0.6575)
# C=0.4, best accuracy on train (0.7100) and val (0.6650)
# C=0.41000000000000003, best accuracy on train (0.7031) and val (0.6575)
# C=0.42000000000000004, best accuracy on train (0.7362) and val (0.6575)
# C=0.43000000000000005, best accuracy on train (0.7075) and val (0.6600)
# C=0.44000000000000006, best accuracy on train (0.7113) and val (0.6625)
# C=0.45000000000000007, best accuracy on train (0.7244) and val (0.6675)
# C=0.45999999999999996, best accuracy on train (0.7212) and val (0.6625)
# C=0.47, best accuracy on train (0.7163) and val (0.6575)
# C=0.48, best accuracy on train (0.7262) and val (0.6600)
# C=0.49, best accuracy on train (0.7156) and val (0.6575)
# C=0.5, best accuracy on train (0.7431) and val (0.6675)
# C=0.51, best accuracy on train (0.7406) and val (0.6675)
# C=0.52, best accuracy on train (0.7338) and val (0.6675)
# C=0.53, best accuracy on train (0.7450) and val (0.6625)
# C=0.54, best accuracy on train (0.7300) and val (0.6625)
# C=0.55, best accuracy on train (0.7400) and val (0.6675)
# C=0.56, best accuracy on train (0.7381) and val (0.6650)
# C=0.5700000000000001, best accuracy on train (0.7556) and val (0.6650)
# C=0.58, best accuracy on train (0.7362) and val (0.6675)
# C=0.59, best accuracy on train (0.7381) and val (0.6650)
# C=0.6, best accuracy on train (0.7381) and val (0.6675)
# C=0.61, best accuracy on train (0.7400) and val (0.6700)
# C=0.62, best accuracy on train (0.6562) and val (0.6675)
# C=0.63, best accuracy on train (0.6562) and val (0.6650)
# C=0.64, best accuracy on train (0.6594) and val (0.6775)
# C=0.65, best accuracy on train (0.6637) and val (0.6800)
# C=0.66, best accuracy on train (0.6650) and val (0.6800)
# C=0.67, best accuracy on train (0.6587) and val (0.6650)
# C=0.6799999999999999, best accuracy on train (0.6613) and val (0.6800)
# C=0.69, best accuracy on train (0.6650) and val (0.6825)
# C=0.7, best accuracy on train (0.7731) and val (0.6725)
# C=0.71, best accuracy on train (0.7569) and val (0.6700)
# C=0.72, best accuracy on train (0.7875) and val (0.6700)
# C=0.73, best accuracy on train (0.7725) and val (0.6725)
# C=0.74, best accuracy on train (0.7694) and val (0.6675)
# C=0.75, best accuracy on train (0.7638) and val (0.6700)
# C=0.76, best accuracy on train (0.7762) and val (0.6725)
# C=0.77, best accuracy on train (0.7706) and val (0.6875)
# C=0.78, best accuracy on train (0.7769) and val (0.6850)
# C=0.79, best accuracy on train (0.7794) and val (0.6800)
# C=0.8, best accuracy on train (0.7788) and val (0.6825)
# C=0.8099999999999999, best accuracy on train (0.7825) and val (0.6725)
# C=0.82, best accuracy on train (0.7506) and val (0.6775)
# C=0.83, best accuracy on train (0.7963) and val (0.6700)
# C=0.84, best accuracy on train (0.7825) and val (0.6825)
# C=0.85, best accuracy on train (0.7812) and val (0.6625)
# C=0.86, best accuracy on train (0.7850) and val (0.6750)
# C=0.87, best accuracy on train (0.7731) and val (0.6775)
# C=0.88, best accuracy on train (0.7675) and val (0.6750)
# C=0.89, best accuracy on train (0.7456) and val (0.6675)
# C=0.9, best accuracy on train (0.7756) and val (0.6850)
# C=0.91, best accuracy on train (0.7706) and val (0.6725)
# C=0.92, best accuracy on train (0.7725) and val (0.6875)
# C=0.93, best accuracy on train (0.7850) and val (0.6700)
# C=0.94, best accuracy on train (0.7800) and val (0.6750)
# C=0.95, best accuracy on train (0.7894) and val (0.6750)
# C=0.96, best accuracy on train (0.7844) and val (0.6775)
# C=0.97, best accuracy on train (0.7812) and val (0.6800)
# C=0.98, best accuracy on train (0.7887) and val (0.6800)
# C=0.99, best accuracy on train (0.7512) and val (0.6725)
# C=1.0, best accuracy on train (0.7738) and val (0.6675)
# C=1.0, best accuracy on train (0.7738) and val (0.6675)
# C=1.5, best accuracy on train (0.8275) and val (0.6750)
# C=2.0, best accuracy on train (0.8544) and val (0.6875)
# C=2.5, best accuracy on train (0.8569) and val (0.6750)
# C=3.0, best accuracy on train (0.8281) and val (0.6775)
# C=3.5, best accuracy on train (0.8869) and val (0.6925)
# C=4.0, best accuracy on train (0.8588) and val (0.6700)
# C=4.5, best accuracy on train (0.8819) and val (0.6675)
# C=5.0, best accuracy on train (0.9050) and val (0.6700)
# C=5.5, best accuracy on train (0.9069) and val (0.6775)
# C=6.0, best accuracy on train (0.9069) and val (0.6625)
# C=6.5, best accuracy on train (0.9050) and val (0.6675)
# C=7.0, best accuracy on train (0.8888) and val (0.6650)
# C=7.5, best accuracy on train (0.9313) and val (0.6650)
# C=8.0, best accuracy on train (0.9319) and val (0.6625)
# C=8.5, best accuracy on train (0.9356) and val (0.6675)
# C=9.0, best accuracy on train (0.9419) and val (0.6600)
# C=9.5, best accuracy on train (0.9431) and val (0.6625)
# C=10.0, best accuracy on train (0.9450) and val (0.6600)
# Fold 5
# C=0.1, best accuracy on train (0.6356) and val (0.5900)
# C=0.11, best accuracy on train (0.6394) and val (0.5925)
# C=0.12000000000000001, best accuracy on train (0.6350) and val (0.5825)
# C=0.13, best accuracy on train (0.6300) and val (0.5925)
# C=0.14, best accuracy on train (0.6294) and val (0.5900)
# C=0.15000000000000002, best accuracy on train (0.6225) and val (0.5875)
# C=0.16, best accuracy on train (0.6300) and val (0.6000)
# C=0.17, best accuracy on train (0.6756) and val (0.5975)
# C=0.18, best accuracy on train (0.6763) and val (0.5975)
# C=0.19, best accuracy on train (0.6625) and val (0.5875)
# C=0.2, best accuracy on train (0.6763) and val (0.6050)
# C=0.21000000000000002, best accuracy on train (0.6787) and val (0.6050)
# C=0.22, best accuracy on train (0.6931) and val (0.6050)
# C=0.23, best accuracy on train (0.6856) and val (0.6125)
# C=0.24000000000000002, best accuracy on train (0.6844) and val (0.6100)
# C=0.25, best accuracy on train (0.6894) and val (0.6075)
# C=0.26, best accuracy on train (0.6894) and val (0.6075)
# C=0.27, best accuracy on train (0.6919) and val (0.6100)
# C=0.28, best accuracy on train (0.7063) and val (0.6150)
# C=0.29000000000000004, best accuracy on train (0.7238) and val (0.6175)
# C=0.30000000000000004, best accuracy on train (0.7150) and val (0.6100)
# C=0.31, best accuracy on train (0.7306) and val (0.6150)
# C=0.32, best accuracy on train (0.6994) and val (0.6125)
# C=0.33, best accuracy on train (0.7225) and val (0.6125)
# C=0.33999999999999997, best accuracy on train (0.7056) and val (0.6150)
# C=0.35, best accuracy on train (0.7013) and val (0.6175)
# C=0.36, best accuracy on train (0.7219) and val (0.6300)
# C=0.37, best accuracy on train (0.7444) and val (0.6175)
# C=0.38, best accuracy on train (0.7488) and val (0.6175)
# C=0.39, best accuracy on train (0.7512) and val (0.6200)
# C=0.4, best accuracy on train (0.7525) and val (0.6200)
# C=0.41000000000000003, best accuracy on train (0.7119) and val (0.6250)
# C=0.42000000000000004, best accuracy on train (0.7544) and val (0.6225)
# C=0.43000000000000005, best accuracy on train (0.7562) and val (0.6250)
# C=0.44000000000000006, best accuracy on train (0.7556) and val (0.6250)
# C=0.45000000000000007, best accuracy on train (0.7281) and val (0.6225)
# C=0.45999999999999996, best accuracy on train (0.7581) and val (0.6375)
# C=0.47, best accuracy on train (0.7331) and val (0.6225)
# C=0.48, best accuracy on train (0.7475) and val (0.6225)
# C=0.49, best accuracy on train (0.7619) and val (0.6375)
# C=0.5, best accuracy on train (0.7562) and val (0.6400)
# C=0.51, best accuracy on train (0.7488) and val (0.6350)
# C=0.52, best accuracy on train (0.7638) and val (0.6425)
# C=0.53, best accuracy on train (0.7450) and val (0.6225)
# C=0.54, best accuracy on train (0.7550) and val (0.6375)
# C=0.55, best accuracy on train (0.7631) and val (0.6425)
# C=0.56, best accuracy on train (0.7675) and val (0.6425)
# C=0.5700000000000001, best accuracy on train (0.7669) and val (0.6450)
# C=0.58, best accuracy on train (0.7675) and val (0.6375)
# C=0.59, best accuracy on train (0.7469) and val (0.6325)
# C=0.6, best accuracy on train (0.7588) and val (0.6375)
# C=0.61, best accuracy on train (0.7625) and val (0.6450)
# C=0.62, best accuracy on train (0.7669) and val (0.6375)
# C=0.63, best accuracy on train (0.7612) and val (0.6350)
# C=0.64, best accuracy on train (0.7600) and val (0.6300)
# C=0.65, best accuracy on train (0.7681) and val (0.6375)
# C=0.66, best accuracy on train (0.7631) and val (0.6300)
# C=0.67, best accuracy on train (0.7700) and val (0.6450)
# C=0.6799999999999999, best accuracy on train (0.7706) and val (0.6350)
# C=0.69, best accuracy on train (0.7788) and val (0.6425)
# C=0.7, best accuracy on train (0.7762) and val (0.6425)
# C=0.71, best accuracy on train (0.7794) and val (0.6475)
# C=0.72, best accuracy on train (0.7794) and val (0.6425)
# C=0.73, best accuracy on train (0.7800) and val (0.6425)
# C=0.74, best accuracy on train (0.7738) and val (0.6325)
# C=0.75, best accuracy on train (0.7788) and val (0.6300)
# C=0.76, best accuracy on train (0.7712) and val (0.6450)
# C=0.77, best accuracy on train (0.7875) and val (0.6475)
# C=0.78, best accuracy on train (0.7831) and val (0.6425)
# C=0.79, best accuracy on train (0.7825) and val (0.6375)
# C=0.8, best accuracy on train (0.7800) and val (0.6475)
# C=0.8099999999999999, best accuracy on train (0.7825) and val (0.6375)
# C=0.82, best accuracy on train (0.7887) and val (0.6350)
# C=0.83, best accuracy on train (0.7887) and val (0.6400)
# C=0.84, best accuracy on train (0.7644) and val (0.6300)
# C=0.85, best accuracy on train (0.7894) and val (0.6325)
# C=0.86, best accuracy on train (0.7919) and val (0.6300)
# C=0.87, best accuracy on train (0.7856) and val (0.6350)
# C=0.88, best accuracy on train (0.7956) and val (0.6450)
# C=0.89, best accuracy on train (0.7956) and val (0.6325)
# C=0.9, best accuracy on train (0.7944) and val (0.6325)
# C=0.91, best accuracy on train (0.7994) and val (0.6450)
# C=0.92, best accuracy on train (0.7919) and val (0.6325)
# C=0.93, best accuracy on train (0.7994) and val (0.6350)
# C=0.94, best accuracy on train (0.7963) and val (0.6400)
# C=0.95, best accuracy on train (0.7831) and val (0.6375)
# C=0.96, best accuracy on train (0.7831) and val (0.6300)
# C=0.97, best accuracy on train (0.8006) and val (0.6300)
# C=0.98, best accuracy on train (0.8000) and val (0.6325)
# C=0.99, best accuracy on train (0.7987) and val (0.6350)
# C=1.0, best accuracy on train (0.7919) and val (0.6275)
# C=1.0, best accuracy on train (0.7919) and val (0.6275)
# C=1.5, best accuracy on train (0.8300) and val (0.6275)
# C=2.0, best accuracy on train (0.8500) and val (0.6325)
# C=2.5, best accuracy on train (0.8662) and val (0.6275)
# C=3.0, best accuracy on train (0.8788) and val (0.6250)
# C=3.5, best accuracy on train (0.8781) and val (0.6350)
# C=4.0, best accuracy on train (0.8875) and val (0.6400)
# C=4.5, best accuracy on train (0.9000) and val (0.6200)
# C=5.0, best accuracy on train (0.8988) and val (0.6275)
# C=5.5, best accuracy on train (0.8856) and val (0.6300)
# C=6.0, best accuracy on train (0.9125) and val (0.6275)
# C=6.5, best accuracy on train (0.9169) and val (0.6325)
# C=7.0, best accuracy on train (0.8269) and val (0.6325)
# C=7.5, best accuracy on train (0.9331) and val (0.6225)
# C=8.0, best accuracy on train (0.9431) and val (0.6275)
# C=8.5, best accuracy on train (0.9425) and val (0.6200)
# C=9.0, best accuracy on train (0.9456) and val (0.6225)
# C=9.5, best accuracy on train (0.9356) and val (0.6275)
# C=10.0, best accuracy on train (0.8244) and val (0.6200)
# Best constant C: 0.69, accuracy on val 0.6560
# /Users/bfiliot/Desktop/MVA/KERNEL/Kernel_methods_MVA/SVM.py:218: ResourceWarning: unclosed file <_io.BufferedWriter name='./Data/CrossVals/cv_C_SVM_MM61_k3_max_iter500_solver_BFGS_full.pkl'>
#   open(os.path.join('./Data/CrossVals/', pickleName), 'wb'))

# %% [markdown]
# ### Predict with best constant C

# %%
# Actual best
C_opt_1 = 1.5  # SP5
C_opt_2 = 4.5  # SP5
C_opt_3 = 0.69 # Mismatch 6, 1

# %% [markdown]
# #### Load data

# %%
X_train, y_train, X_val, y_val, X_test, K, ID = utils.get_training_datas(method='MM61', all=True, replace=False)
for k in range(1, 4):
    exec("X_train_"+str(k)+", y_train_"+str(k)+", X_val_"+str(k)+", y_val_"+str(k)+", X_test_"+str(k)+", K_"+str(k)+", id_"+str(k)+" = utils.select_k(k, X_train, y_train, X_val, y_val, X_test, K, ID)")

# %% [markdown]
# #### Data set 1

# %%
svm_1 = SVM.C_SVM(K, ID, C=C_opt_1, maxiter=500, method='BFGS', print_callbacks=False)
res = svm_1.fit(X_train_1, y_train_1, X_val_1, y_val_1)
pred_tr_1 = svm_1.predict(X_train_1)
print('Accuracy on train set: {:0.4f}'.format(svm_1.score(pred_tr_1, y_train_1)))
pred_val_1 = svm_1.predict(X_val_1)
print('Accuracy on val set: {:0.4f}'.format(svm_1.score(pred_val_1, y_val_1)))
# Out:
# Accuracy on train set: 0.8312
# Accuracy on val set: 0.6307

# %% [markdown]
# #### Data set 2

# %%
svm_2 = SVM.C_SVM(K, ID, C=C_opt_2, maxiter=500, method='BFGS', print_callbacks=False)
res = svm_2.fit(X_train_2, y_train_2, X_val_2, y_val_2)
pred_tr_2 = svm_2.predict(X_train_2)
print('Accuracy on train set: {:0.4f}'.format(svm_2.score(pred_tr_2, y_train_2)))
pred_val_2 = svm_2.predict(X_val_2)
print('Accuracy on val set: {:0.4f}'.format(svm_2.score(pred_val_2, y_val_2)))
# Out:
# Accuracy on train set: 0.9453
# Accuracy on val set: 0.7166

# %% [markdown]
# #### Data set 3

# %%
svm_3 = SVM.C_SVM(K, ID, C=C_opt_3, maxiter=500, method='BFGS', print_callbacks=False)
res = svm_3.fit(X_train_3, y_train_3, X_val_3, y_val_3)
pred_tr_3 = svm_3.predict(X_train_3)
print('Accuracy on train set: {:0.4f}'.format(svm_3.score(pred_tr_3, y_train_3)))
pred_val_3 = svm_3.predict(X_val_3)
print('Accuracy on val set: {:0.4f}'.format(svm_3.score(pred_val_3, y_val_3)))
# Out:
# Accuracy on train set: 0.7625
# Accuracy on val set: 0.6248

# %% [markdown]
# ### Export predictions

# %%
y_pred_test = utils.export_predictions([svm_1, svm_2, svm_3], [X_test_1, X_test_2, X_test_3])

# %% [markdown]
# ## 2-SVM with Weighted Degree Kernel (WDK)

# %% [markdown]
# ### Cross validation on constant $\lambda$

# %% [markdown]
# #### Data set 1

# %%
Ls_1 = np.sort([i*10**j for (i,j) in product([1, 2, 5, 7], range(-5,2))])
data_1 = [X_train_1, y_train_1, X_val_1, y_val_1]
pickleName = 'cv_SVM2_MM61_k1_max_iter100_solver_BFGS_full.pkl'
kfolds = 5
l_opt_1, _, _, _, _ = SVM2.cv(Ls=Ls_1, data=data_1, kfolds=kfolds,
                             pickleName=pickleName, K=K, ID=ID, maxiter=100,
                             method='BFGS')
# Out:
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# Fold 1
# Lambda=1e-05, best accuracy on train (0.7650) and val (0.5850)
# Lambda=2e-05, best accuracy on train (0.9356) and val (0.5850)
# Lambda=5e-05, best accuracy on train (0.7344) and val (0.5900)
# Lambda=7.000000000000001e-05, best accuracy on train (0.6138) and val (0.5850)
# Lambda=0.0001, best accuracy on train (0.6338) and val (0.5950)
# Lambda=0.0002, best accuracy on train (0.8025) and val (0.5950)
# Lambda=0.0005, best accuracy on train (0.6837) and val (0.6050)
# Lambda=0.0007, best accuracy on train (0.7500) and val (0.6050)
# Lambda=0.001, best accuracy on train (0.9469) and val (0.6000)
# Lambda=0.002, best accuracy on train (0.7875) and val (0.6050)
# Lambda=0.005, best accuracy on train (0.7475) and val (0.5775)
# Lambda=0.007, best accuracy on train (0.7256) and val (0.5950)
# Lambda=0.01, best accuracy on train (0.6987) and val (0.5950)
# Lambda=0.02, best accuracy on train (0.7781) and val (0.5875)
# Lambda=0.05, best accuracy on train (0.6394) and val (0.5850)
# Lambda=0.07, best accuracy on train (0.6850) and val (0.5825)
# Lambda=0.1, best accuracy on train (0.7294) and val (0.5850)
# Lambda=0.2, best accuracy on train (0.6694) and val (0.5600)
# Lambda=0.5, best accuracy on train (0.6050) and val (0.5450)
# Lambda=0.7000000000000001, best accuracy on train (0.6062) and val (0.5550)
# Lambda=1.0, best accuracy on train (0.7238) and val (0.5800)
# Lambda=2.0, best accuracy on train (0.6269) and val (0.5775)
# Lambda=5.0, best accuracy on train (0.7000) and val (0.5825)
# Lambda=7.0, best accuracy on train (0.6175) and val (0.5800)
# Lambda=10.0, best accuracy on train (0.7125) and val (0.6000)
# Lambda=20.0, best accuracy on train (0.7619) and val (0.6200)
# Lambda=50.0, best accuracy on train (0.6644) and val (0.5575)
# Lambda=70.0, best accuracy on train (0.7312) and val (0.5950)
# Fold 2
# Lambda=1e-05, best accuracy on train (0.8219) and val (0.6075)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-10687692387e> in <module>
#       5 l_opt_1, _, _, _, _ = SVM2.cv(Ls=Ls_1, data=data_1, kfolds=kfolds,
#       6                              pickleName=pickleName, K=K, ID=ID, maxiter=100,
# ----> 7                              method='BFGS')
#
# ~/Desktop/MVA/KERNEL/Kernel_methods_MVA/SVM2.py in cv(Ls, data, kfolds, pickleName, **kwargs)
#     141         for l in Ls:
#     142             svm = SVM2(lbda=l, print_callbacks=False, **kwargs)
# --> 143             svm.fit(X_train, y_train, X_val, y_val)
#     144             pred_tr = svm.predict(X_train)
#     145             score_tr = svm.score(pred_tr, y_train)
#
# ~/Desktop/MVA/KERNEL/Kernel_methods_MVA/SVM2.py in fit(self, X, y, X_pred, y_pred)
#      89                            bounds=bounds, method='L-BFGS-B',
#      90                            callback=self.callbackF,
# ---> 91                            tol=self.tol, options={'maxiter': self.maxiter})
#      92         elif self.method == "Newton":
#      93             bounds = Bounds(np.array([0 if self.y_fit[i] >= 0 else float('-inf') for i in range(self.n)]),
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     601     elif meth == 'l-bfgs-b':
#     602         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 603                                 callback=callback, **options)
#     604     elif meth == 'tnc':
#     605         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     338             n_iterations += 1
#     339             if callback is not None:
# --> 340                 callback(np.copy(x))
#     341
#     342             if n_iterations >= maxiter:
#
# ~/Desktop/MVA/KERNEL/Kernel_methods_MVA/SVM2.py in callbackF(self, Xi, Yi)
#      45             val_acc = 0
#      46         else:
# ---> 47             val_acc = self.score(self.predict(self.X_pred), self.y_pred)
#      48             self.val_accuracies.append(val_acc)
#      49         self.svS.append(self.sv)
#
# ~/Desktop/MVA/KERNEL/Kernel_methods_MVA/SVM2.py in predict(self, X)
#     109         pred = []
#     110         for i in self.idx_pred:
# --> 111             pred.append(np.sign(np.dot(self.sv, self.K[self.idx_sv, i].squeeze())))
#     112         return np.array(pred)
#     113
#
# KeyboardInterrupt:

# %% [markdown]
# #### Data set 2

# %%
Ls_2 = Ls_1
data_2 = [X_train_2, y_train_2, X_val_2, y_val_2]
pickleName = 'cv_SVM2_WD5_k2_max_iter100_solver_BFGS_full.pkl'
kfolds = 5
l_opt_2, _, _, _, _ = SVM2.cv(Ls=Ls_2, data=data_2, kfolds=kfolds,
                             pickleName=pickleName, K=K, ID=ID, maxiter=100,
                             method='BFGS')
# Out:
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# Fold 1
# Lambda=1e-05, best accuracy on train (1.0000) and val (0.6525)
# Lambda=2e-05, best accuracy on train (1.0000) and val (0.6525)
# Lambda=5e-05, best accuracy on train (1.0000) and val (0.6550)
# Lambda=7.000000000000001e-05, best accuracy on train (1.0000) and val (0.6575)
# Lambda=0.0001, best accuracy on train (0.9994) and val (0.6550)
# Lambda=0.0002, best accuracy on train (0.9994) and val (0.6600)
# Lambda=0.0005, best accuracy on train (0.9500) and val (0.6475)
# Lambda=0.0007, best accuracy on train (1.0000) and val (0.6525)
# Lambda=0.001, best accuracy on train (0.9994) and val (0.6725)
# Lambda=0.002, best accuracy on train (0.9806) and val (0.6625)
# Lambda=0.005, best accuracy on train (0.9825) and val (0.6650)
# Lambda=0.007, best accuracy on train (0.9875) and val (0.6700)
# Lambda=0.01, best accuracy on train (1.0000) and val (0.6625)
# Lambda=0.02, best accuracy on train (0.9956) and val (0.6625)
# Lambda=0.05, best accuracy on train (0.9900) and val (0.6800)
# Lambda=0.07, best accuracy on train (0.9650) and val (0.6700)
# Lambda=0.1, best accuracy on train (0.9769) and val (0.6750)
# Lambda=0.2, best accuracy on train (0.9962) and val (0.6825)
# Lambda=0.5, best accuracy on train (0.9962) and val (0.6700)
# Lambda=0.7000000000000001, best accuracy on train (0.9919) and val (0.6750)
# Lambda=1.0, best accuracy on train (0.9944) and val (0.6700)
# Lambda=2.0, best accuracy on train (0.7856) and val (0.6325)
# Lambda=5.0, best accuracy on train (0.8738) and val (0.6350)
# Lambda=7.0, best accuracy on train (0.8650) and val (0.6350)
# Lambda=10.0, best accuracy on train (0.8712) and val (0.6375)
# Lambda=20.0, best accuracy on train (0.8788) and val (0.6425)
# Lambda=50.0, best accuracy on train (0.8694) and val (0.6450)
# Lambda=70.0, best accuracy on train (0.8681) and val (0.6450)
# Fold 2
# Lambda=1e-05, best accuracy on train (1.0000) and val (0.6550)
# Lambda=2e-05, best accuracy on train (1.0000) and val (0.6550)
# Lambda=5e-05, best accuracy on train (1.0000) and val (0.6600)
# Lambda=7.000000000000001e-05, best accuracy on train (1.0000) and val (0.6625)
# Lambda=0.0001, best accuracy on train (0.9981) and val (0.6650)
# Lambda=0.0002, best accuracy on train (1.0000) and val (0.6525)
# Lambda=0.0005, best accuracy on train (0.9994) and val (0.6600)
# Lambda=0.0007, best accuracy on train (1.0000) and val (0.6625)
# Lambda=0.001, best accuracy on train (0.9956) and val (0.6650)
# Lambda=0.002, best accuracy on train (0.9975) and val (0.6675)
# Lambda=0.005, best accuracy on train (0.9944) and val (0.6650)
# Lambda=0.007, best accuracy on train (0.9919) and val (0.6675)
# Lambda=0.01, best accuracy on train (1.0000) and val (0.6675)
# Lambda=0.02, best accuracy on train (0.9663) and val (0.6625)
# Lambda=0.05, best accuracy on train (0.9912) and val (0.6625)
# Lambda=0.07, best accuracy on train (1.0000) and val (0.6600)
# Lambda=0.1, best accuracy on train (0.9956) and val (0.6775)
# Lambda=0.2, best accuracy on train (0.9944) and val (0.6800)
# Lambda=0.5, best accuracy on train (0.9625) and val (0.6625)
# Lambda=0.7000000000000001, best accuracy on train (0.9206) and val (0.6725)
# Lambda=1.0, best accuracy on train (0.9950) and val (0.6750)
# Lambda=2.0, best accuracy on train (0.9194) and val (0.6525)
# Lambda=5.0, best accuracy on train (0.9394) and val (0.6700)
# Lambda=7.0, best accuracy on train (0.7756) and val (0.6225)
# Lambda=10.0, best accuracy on train (0.8081) and val (0.6100)
# Lambda=20.0, best accuracy on train (0.7887) and val (0.6175)
# Lambda=50.0, best accuracy on train (0.7350) and val (0.6075)
# Lambda=70.0, best accuracy on train (0.8781) and val (0.6125)
# Fold 3
# Lambda=1e-05, best accuracy on train (1.0000) and val (0.6625)
# Lambda=2e-05, best accuracy on train (1.0000) and val (0.6625)
# Lambda=5e-05, best accuracy on train (1.0000) and val (0.6600)
# Lambda=7.000000000000001e-05, best accuracy on train (1.0000) and val (0.6600)
# Lambda=0.0001, best accuracy on train (1.0000) and val (0.6600)
# Lambda=0.0002, best accuracy on train (1.0000) and val (0.6600)
# Lambda=0.0005, best accuracy on train (1.0000) and val (0.6600)
# Lambda=0.0007, best accuracy on train (1.0000) and val (0.6625)
# Lambda=0.001, best accuracy on train (1.0000) and val (0.6625)
# Lambda=0.002, best accuracy on train (1.0000) and val (0.6650)
# Lambda=0.005, best accuracy on train (1.0000) and val (0.6775)
# Lambda=0.007, best accuracy on train (0.9900) and val (0.6675)
# Lambda=0.01, best accuracy on train (0.9975) and val (0.6650)
# Lambda=0.02, best accuracy on train (1.0000) and val (0.6675)
# Lambda=0.05, best accuracy on train (1.0000) and val (0.6725)
# Lambda=0.07, best accuracy on train (0.9688) and val (0.6700)
# Lambda=0.1, best accuracy on train (0.9525) and val (0.6800)
# Lambda=0.2, best accuracy on train (0.9513) and val (0.6800)
# Lambda=0.5, best accuracy on train (0.9506) and val (0.6900)
# Lambda=0.7000000000000001, best accuracy on train (0.9537) and val (0.6825)
# Lambda=1.0, best accuracy on train (0.9594) and val (0.6725)
# Lambda=2.0, best accuracy on train (0.9463) and val (0.6650)
# Lambda=5.0, best accuracy on train (0.8337) and val (0.6100)
# Lambda=7.0, best accuracy on train (0.9269) and val (0.6275)
# Lambda=10.0, best accuracy on train (0.8694) and val (0.6275)
# Lambda=20.0, best accuracy on train (0.8631) and val (0.6200)
# Lambda=50.0, best accuracy on train (0.8050) and val (0.6150)
# Lambda=70.0, best accuracy on train (0.8656) and val (0.6325)
# Fold 4
# Lambda=1e-05, best accuracy on train (0.9881) and val (0.7225)
# Lambda=2e-05, best accuracy on train (0.9881) and val (0.7225)
# Lambda=5e-05, best accuracy on train (0.9881) and val (0.7225)
# Lambda=7.000000000000001e-05, best accuracy on train (0.9881) and val (0.7225)
# Lambda=0.0001, best accuracy on train (1.0000) and val (0.7225)
# Lambda=0.0002, best accuracy on train (0.9881) and val (0.7225)
# Lambda=0.0005, best accuracy on train (0.9881) and val (0.7225)
# Lambda=0.0007, best accuracy on train (0.9894) and val (0.7225)
# Lambda=0.001, best accuracy on train (0.9906) and val (0.7225)
# Lambda=0.002, best accuracy on train (0.9912) and val (0.7050)
# Lambda=0.005, best accuracy on train (0.9931) and val (0.7175)
# Lambda=0.007, best accuracy on train (0.9888) and val (0.7150)
# Lambda=0.01, best accuracy on train (0.9919) and val (0.7225)
# Lambda=0.02, best accuracy on train (1.0000) and val (0.7000)
# Lambda=0.05, best accuracy on train (0.9762) and val (0.7250)
# Lambda=0.07, best accuracy on train (0.9450) and val (0.7225)
# Lambda=0.1, best accuracy on train (0.9750) and val (0.7100)
# Lambda=0.2, best accuracy on train (0.9712) and val (0.7125)
# Lambda=0.5, best accuracy on train (0.9919) and val (0.7075)
# Lambda=0.7000000000000001, best accuracy on train (0.9769) and val (0.7150)
# Lambda=1.0, best accuracy on train (0.9925) and val (0.7100)
# Lambda=2.0, best accuracy on train (0.9431) and val (0.6725)
# Lambda=5.0, best accuracy on train (0.9387) and val (0.6325)
# Lambda=7.0, best accuracy on train (0.8944) and val (0.6075)
# Lambda=10.0, best accuracy on train (0.9025) and val (0.6525)
# Lambda=20.0, best accuracy on train (0.8894) and val (0.5975)
# Lambda=50.0, best accuracy on train (0.8794) and val (0.6000)
# Lambda=70.0, best accuracy on train (0.8850) and val (0.5975)
# Fold 5
# Lambda=1e-05, best accuracy on train (0.9950) and val (0.6500)
# Lambda=2e-05, best accuracy on train (0.9950) and val (0.6500)
# Lambda=5e-05, best accuracy on train (0.9938) and val (0.6450)
# Lambda=7.000000000000001e-05, best accuracy on train (0.9938) and val (0.6450)
# Lambda=0.0001, best accuracy on train (0.9950) and val (0.6475)
# Lambda=0.0002, best accuracy on train (0.9994) and val (0.6475)
# Lambda=0.0005, best accuracy on train (1.0000) and val (0.6350)
# Lambda=0.0007, best accuracy on train (1.0000) and val (0.6400)
# Lambda=0.001, best accuracy on train (1.0000) and val (0.6425)
# Lambda=0.002, best accuracy on train (1.0000) and val (0.6450)
# Lambda=0.005, best accuracy on train (0.9994) and val (0.6475)
# Lambda=0.007, best accuracy on train (0.9469) and val (0.6575)
# Lambda=0.01, best accuracy on train (1.0000) and val (0.6400)
# Lambda=0.02, best accuracy on train (0.9950) and val (0.6475)
# Lambda=0.05, best accuracy on train (1.0000) and val (0.6600)
# Lambda=0.07, best accuracy on train (0.9869) and val (0.6500)
# Lambda=0.1, best accuracy on train (1.0000) and val (0.6475)
# Lambda=0.2, best accuracy on train (0.9975) and val (0.6525)
# Lambda=0.5, best accuracy on train (1.0000) and val (0.6475)
# Lambda=0.7000000000000001, best accuracy on train (0.9875) and val (0.6525)
# Lambda=1.0, best accuracy on train (0.9881) and val (0.6500)
# Lambda=2.0, best accuracy on train (0.7825) and val (0.6300)
# Lambda=5.0, best accuracy on train (0.7800) and val (0.6325)
# Lambda=7.0, best accuracy on train (0.7913) and val (0.6150)
# Lambda=10.0, best accuracy on train (0.9669) and val (0.6300)
# Lambda=20.0, best accuracy on train (0.7850) and val (0.6125)
# Lambda=50.0, best accuracy on train (0.7887) and val (0.6125)
# Lambda=70.0, best accuracy on train (0.7881) and val (0.6125)
# Best constant C: 0.2, accuracy on val 0.6815
# /Users/bfiliot/Desktop/MVA/KERNEL/Kernel_methods_MVA/SVM2.py:156: ResourceWarning: unclosed file <_io.BufferedWriter name='./Data/cv_SVM2_WD5_k2_max_iter100_solver_BFGS_full.pkl'>
#   open(os.path.join('./Data', pickleName), 'wb'))

# %% [markdown]
# #### Data set 3

# %%
Ls_3 = Ls_1
data_3 = [X_train_3, y_train_3, X_val_3, y_val_3]
pickleName = 'cv_SVM2_WD5_k3_max_iter100_solver_BFGS_full.pkl'
kfolds = 5
l_opt_3, _, _, _, _ = SVM2.cv(Ls=Ls_3, data=data_3, kfolds=kfolds,
                             pickleName=pickleName, K=K, ID=ID, maxiter=100,
                             method='BFGS')
# Out:
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# Fold 1
# Lambda=1e-05, best accuracy on train (0.9944) and val (0.5700)
# Lambda=2e-05, best accuracy on train (0.9950) and val (0.5675)
# Lambda=5e-05, best accuracy on train (0.9938) and val (0.5675)
# Lambda=7.000000000000001e-05, best accuracy on train (1.0000) and val (0.5625)
# Lambda=0.0001, best accuracy on train (1.0000) and val (0.5650)
# Lambda=0.0002, best accuracy on train (0.9938) and val (0.5625)
# Lambda=0.0005, best accuracy on train (0.6900) and val (0.5650)
# Lambda=0.0007, best accuracy on train (0.9994) and val (0.5700)
# Lambda=0.001, best accuracy on train (0.6856) and val (0.5650)
# Lambda=0.002, best accuracy on train (0.6963) and val (0.5700)
# Lambda=0.005, best accuracy on train (0.6913) and val (0.5725)
# Lambda=0.007, best accuracy on train (0.9406) and val (0.5775)
# Lambda=0.01, best accuracy on train (0.7506) and val (0.5775)
# Lambda=0.02, best accuracy on train (0.9981) and val (0.5725)
# Lambda=0.05, best accuracy on train (0.9762) and val (0.5825)
# Lambda=0.07, best accuracy on train (0.9994) and val (0.5725)
# Lambda=0.1, best accuracy on train (0.9163) and val (0.5750)
# Lambda=0.2, best accuracy on train (0.9575) and val (0.5900)
# Lambda=0.5, best accuracy on train (0.7900) and val (0.5800)
# Lambda=0.7000000000000001, best accuracy on train (0.8100) and val (0.5850)
# Lambda=1.0, best accuracy on train (0.9244) and val (0.5750)
# Lambda=2.0, best accuracy on train (0.7694) and val (0.5775)
# Lambda=5.0, best accuracy on train (0.7931) and val (0.5725)
# Lambda=7.0, best accuracy on train (0.7894) and val (0.5750)
# Lambda=10.0, best accuracy on train (0.7887) and val (0.5700)
# Lambda=20.0, best accuracy on train (0.7956) and val (0.5725)
# Lambda=50.0, best accuracy on train (0.8125) and val (0.5750)
# Lambda=70.0, best accuracy on train (0.8025) and val (0.5725)
# Fold 2
# Lambda=1e-05, best accuracy on train (0.9850) and val (0.5725)
# Lambda=2e-05, best accuracy on train (0.9850) and val (0.5725)
# Lambda=5e-05, best accuracy on train (0.9850) and val (0.5725)
# Lambda=7.000000000000001e-05, best accuracy on train (0.9856) and val (0.5725)
# Lambda=0.0001, best accuracy on train (0.9850) and val (0.5700)
# Lambda=0.0002, best accuracy on train (0.9850) and val (0.5700)
# Lambda=0.0005, best accuracy on train (0.9838) and val (0.5975)
# Lambda=0.0007, best accuracy on train (1.0000) and val (0.5775)
# Lambda=0.001, best accuracy on train (0.9969) and val (0.6000)
# Lambda=0.002, best accuracy on train (0.6806) and val (0.6100)
# Lambda=0.005, best accuracy on train (0.6869) and val (0.6025)
# Lambda=0.007, best accuracy on train (0.6981) and val (0.6025)
# Lambda=0.01, best accuracy on train (1.0000) and val (0.5925)
# Lambda=0.02, best accuracy on train (1.0000) and val (0.5900)
# Lambda=0.05, best accuracy on train (0.9994) and val (0.5750)
# Lambda=0.07, best accuracy on train (0.9981) and val (0.5975)
# Lambda=0.1, best accuracy on train (0.8350) and val (0.5800)
# Lambda=0.2, best accuracy on train (0.9869) and val (0.5850)
# Lambda=0.5, best accuracy on train (0.8738) and val (0.5900)
# Lambda=0.7000000000000001, best accuracy on train (0.8644) and val (0.5800)
# Lambda=1.0, best accuracy on train (0.7937) and val (0.5950)
# Lambda=2.0, best accuracy on train (0.7881) and val (0.5975)
# Lambda=5.0, best accuracy on train (0.9519) and val (0.5900)
# Lambda=7.0, best accuracy on train (0.8600) and val (0.5950)
# Lambda=10.0, best accuracy on train (0.8013) and val (0.5925)
# Lambda=20.0, best accuracy on train (0.7688) and val (0.5875)
# Lambda=50.0, best accuracy on train (0.7744) and val (0.5900)
# Lambda=70.0, best accuracy on train (0.7688) and val (0.5875)
# Fold 3
# Lambda=1e-05, best accuracy on train (0.5863) and val (0.6150)
# Lambda=2e-05, best accuracy on train (0.5863) and val (0.6150)
# Lambda=5e-05, best accuracy on train (0.5875) and val (0.6150)
# Lambda=7.000000000000001e-05, best accuracy on train (0.5875) and val (0.6150)
# Lambda=0.0001, best accuracy on train (0.5887) and val (0.6150)
# Lambda=0.0002, best accuracy on train (0.5919) and val (0.6150)
# Lambda=0.0005, best accuracy on train (0.6019) and val (0.6225)
# Lambda=0.0007, best accuracy on train (0.6038) and val (0.6200)
# Lambda=0.001, best accuracy on train (0.6125) and val (0.6275)
# Lambda=0.002, best accuracy on train (0.6325) and val (0.6175)
# Lambda=0.005, best accuracy on train (0.6875) and val (0.5950)
# Lambda=0.007, best accuracy on train (0.7412) and val (0.5900)
# Lambda=0.01, best accuracy on train (0.8063) and val (0.5975)
# Lambda=0.02, best accuracy on train (0.7919) and val (0.5800)
# Lambda=0.05, best accuracy on train (1.0000) and val (0.5900)
# Lambda=0.07, best accuracy on train (0.9888) and val (0.5925)
# Lambda=0.1, best accuracy on train (1.0000) and val (0.5950)
# Lambda=0.2, best accuracy on train (0.9981) and val (0.5825)
# Lambda=0.5, best accuracy on train (0.8163) and val (0.5975)
# Lambda=0.7000000000000001, best accuracy on train (0.8119) and val (0.5875)
# Lambda=1.0, best accuracy on train (0.8275) and val (0.6150)
# Lambda=2.0, best accuracy on train (0.8175) and val (0.5850)
# Lambda=5.0, best accuracy on train (0.8294) and val (0.6025)
# Lambda=7.0, best accuracy on train (0.8181) and val (0.5775)
# Lambda=10.0, best accuracy on train (0.8206) and val (0.5850)
# Lambda=20.0, best accuracy on train (0.8325) and val (0.6025)
# Lambda=50.0, best accuracy on train (0.8294) and val (0.5950)
# Lambda=70.0, best accuracy on train (0.8300) and val (0.6000)
# Fold 4
# Lambda=1e-05, best accuracy on train (1.0000) and val (0.5550)
# Lambda=2e-05, best accuracy on train (0.6725) and val (0.5475)
# Lambda=5e-05, best accuracy on train (1.0000) and val (0.5550)
# Lambda=7.000000000000001e-05, best accuracy on train (0.9587) and val (0.5500)
# Lambda=0.0001, best accuracy on train (0.9594) and val (0.5550)
# Lambda=0.0002, best accuracy on train (0.9594) and val (0.5500)
# Lambda=0.0005, best accuracy on train (0.9556) and val (0.5500)
# Lambda=0.0007, best accuracy on train (0.9663) and val (0.5500)
# Lambda=0.001, best accuracy on train (0.9600) and val (0.5575)
# Lambda=0.002, best accuracy on train (0.9663) and val (0.5500)
# Lambda=0.005, best accuracy on train (0.9938) and val (0.5500)
# Lambda=0.007, best accuracy on train (0.7219) and val (0.5550)
# Lambda=0.01, best accuracy on train (0.9994) and val (0.5600)
# Lambda=0.02, best accuracy on train (0.9994) and val (0.5650)
# Lambda=0.05, best accuracy on train (0.7725) and val (0.5600)
# Lambda=0.07, best accuracy on train (0.9988) and val (0.5600)
# Lambda=0.1, best accuracy on train (0.7881) and val (0.5600)
# Lambda=0.2, best accuracy on train (0.8975) and val (0.5600)
# Lambda=0.5, best accuracy on train (0.8000) and val (0.5775)
# Lambda=0.7000000000000001, best accuracy on train (0.7969) and val (0.5775)
# Lambda=1.0, best accuracy on train (0.7369) and val (0.5550)
# Lambda=2.0, best accuracy on train (0.7975) and val (0.5625)
# Lambda=5.0, best accuracy on train (0.8137) and val (0.5675)
# Lambda=7.0, best accuracy on train (0.8156) and val (0.5725)
# Lambda=10.0, best accuracy on train (0.8006) and val (0.5650)
# Lambda=20.0, best accuracy on train (0.8175) and val (0.5675)
# Lambda=50.0, best accuracy on train (0.8063) and val (0.5675)
# Lambda=70.0, best accuracy on train (0.8181) and val (0.5725)
# Fold 5
# Lambda=1e-05, best accuracy on train (0.9838) and val (0.6000)
# Lambda=2e-05, best accuracy on train (0.9850) and val (0.5925)
# Lambda=5e-05, best accuracy on train (0.9894) and val (0.5725)
# Lambda=7.000000000000001e-05, best accuracy on train (0.9900) and val (0.5775)
# Lambda=0.0001, best accuracy on train (0.9912) and val (0.5800)
# Lambda=0.0002, best accuracy on train (0.9788) and val (0.5975)
# Lambda=0.0005, best accuracy on train (0.9769) and val (0.5800)
# Lambda=0.0007, best accuracy on train (0.9888) and val (0.5850)
# Lambda=0.001, best accuracy on train (0.9819) and val (0.5800)
# Lambda=0.002, best accuracy on train (0.9738) and val (0.5700)
# Lambda=0.005, best accuracy on train (0.9094) and val (0.5775)
# Lambda=0.007, best accuracy on train (0.9906) and val (0.5750)
# Lambda=0.01, best accuracy on train (0.9888) and val (0.5850)
# Lambda=0.02, best accuracy on train (0.9756) and val (0.5775)
# Lambda=0.05, best accuracy on train (0.9394) and val (0.5950)
# Lambda=0.07, best accuracy on train (0.8213) and val (0.5800)
# Lambda=0.1, best accuracy on train (0.7544) and val (0.5800)
# Lambda=0.2, best accuracy on train (0.9981) and val (0.5875)
# Lambda=0.5, best accuracy on train (0.9694) and val (0.5925)
# Lambda=0.7000000000000001, best accuracy on train (0.7825) and val (0.5850)
# Lambda=1.0, best accuracy on train (0.7538) and val (0.5800)
# Lambda=2.0, best accuracy on train (0.9900) and val (0.5925)
# Lambda=5.0, best accuracy on train (0.7544) and val (0.5800)
# Lambda=7.0, best accuracy on train (0.7581) and val (0.5850)
# Lambda=10.0, best accuracy on train (0.7544) and val (0.5800)
# Lambda=20.0, best accuracy on train (0.7638) and val (0.5900)
# Lambda=50.0, best accuracy on train (0.7856) and val (0.5875)
# Lambda=70.0, best accuracy on train (0.7837) and val (0.5850)
# Best constant C: 0.5, accuracy on val 0.5875
# /Users/bfiliot/Desktop/MVA/KERNEL/Kernel_methods_MVA/SVM2.py:156: ResourceWarning: unclosed file <_io.BufferedWriter name='./Data/cv_SVM2_WD5_k3_max_iter100_solver_BFGS_full.pkl'>
#   open(os.path.join('./Data', pickleName), 'wb'))

# %% [markdown]
# ### Predict with best constant $\lambda$

# %% [markdown]
# #### Data set 1

# %%
svm2_1 = SVM2.SVM2(K, ID, lbda=l_opt_1, maxiter=100, method='BFGS', print_callbacks=False)
res = svm2_1.fit(X_train_1, y_train_1, X_val_1, y_val_1)
pred_tr_1 = svm2_1.predict(X_train_1)
print('Accuracy on train set: {:0.4f}'.format(svm2_1.score(pred_tr_1, y_train_1)))
pred_val_1 = svm2_1.predict(X_val_1)
print('Accuracy on val set: {:0.4f}'.format(svm2_1.score(pred_val_1, y_val_1)))
# Out:
# Accuracy on train set: 0.9546
# Accuracy on val set: 0.6287

# %% [markdown]
# #### Data set 2

# %%
svm2_2 = SVM2.SVM2(K, ID, lbda=l_opt_2, maxiter=100, method='BFGS', print_callbacks=False)
res = svm2_2.fit(X_train_2, y_train_2, X_val_2, y_val_2)
pred_tr_2 = svm2_2.predict(X_train_2)
print('Accuracy on train set: {:0.4f}'.format(svm2_2.score(pred_tr_2, y_train_2)))
pred_val_2 = svm2_2.predict(X_val_2)
print('Accuracy on val set: {:0.4f}'.format(svm2_2.score(pred_val_2, y_val_2)))
# Out:
# Accuracy on train set: 1.0000
# Accuracy on val set: 0.6667

# %% [markdown]
# #### Data set 3

# %%
svm2_3 = SVM2.SVM2(K, ID, lbda=l_opt_3, maxiter=100, method='BFGS', print_callbacks=False)
res = svm2_3.fit(X_train_3, y_train_3, X_val_3, y_val_3)
pred_tr_3 = svm2_3.predict(X_train_3)
print('Accuracy on train set: {:0.4f}'.format(svm2_3.score(pred_tr_3, y_train_3)))
pred_val_3 = svm2_3.predict(X_val_3)
print('Accuracy on val set: {:0.4f}'.format(svm2_3.score(pred_val_3, y_val_3)))
# Out:
# Accuracy on train set: 0.9873
# Accuracy on val set: 0.5968

# %% [markdown]
# ### Export predictions

# %%
y_pred_test = utils.export_predictions([svm_1, svm_2, svm_3], [X_test_1, X_test_2, X_test_3])
# Out:
# 20:36:46.179189

# %% [markdown]
# ## Vrac
