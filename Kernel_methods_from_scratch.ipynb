# %% [markdown]
# # Kernel methods : Data Challenge (TF)

# %% [markdown]
# ## Packages import

# %%
import utils 
import numpy as np
import NLCKernels
from itertools import product
import pandas as pd
import pickle as pkl

# %%
utils.sort_accuracies().head(10)
# Out:
#          Kernel Method - k=1  Val accuracy - k=1  Constant C - k=1  \
# 0       SVM_NLCK_C1_d3_l5_p9            0.655000               1.9
# 1    SVM_NLCK_C0.1_d3_l10_p9            0.653000               1.7
# 2   SVM_NLCK_C100_d2_l0.1_p9            0.651000               1.2
# 3    SVM_NLCK_C1000_d3_l1_p7            0.650000               4.7
# 4    SVM_NLCK_C10_d2_l50_p20            0.649486               3.0
# 5    SVM_NLCK_C0.01_d3_l1_p9            0.649000               4.5
# 6  SVM_NLCK_C0.0001_d4_l5_p9            0.648500               1.9
# 7   SVM_NLCK_C0.01_d2_l10_p9            0.648500               1.5
# 8      SVM_NLCK_C1_d3_l10_p9            0.648500               1.3
# 9  SVM_NLCK_C1000_d3_l0.1_p9            0.648000               1.2
#
#           Kernel Method - k=2  Val accuracy - k=2  Constant C - k=2  \
# 0       SVM_NLCK_C10_d4_l5_p9              0.7790               2.1
# 1      SVM_NLCK_C100_d3_l5_p9              0.7735               1.8
# ...
