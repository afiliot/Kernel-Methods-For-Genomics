# %% [markdown]
# # Kernel methods : Data Challenge (TF)

# %% [markdown]
# Meilleures accuracy :
# - Mismatch (k=6, m=1)
# - Weight Degree (d=6)
# - Local Alignment (e=11, d=2)

# %% [markdown]
# ## Packages import

# %%
import os
import datetime
import utils  
import kernels
import SVM
import ALIGNF
import numpy as np
from itertools import product
import warnings

# %% [markdown]
# ## C-SVM

# %% [markdown]
# ### Accuracies obtained so far for each methods

# %%
utils.sort_accuracies()
# Out:
#    Kernel Method - k=1  Val accuracy - k=1  Constant C - k=1  \
# 0             SVM_WD10            0.636500             0.030
# 1             SVM_MM61            0.634500             2.000
# 2              SVM_SP5            0.633500             0.500
# 3        SVM_LA_e11_d2            0.628500             0.700
# 4             SVM_MM62            0.627000             9.000
# 5         SVM_LA_e8_d1            0.624000             0.600
# 6             SVM_MM51            0.620000             2.000
# 7              SVM_SP4            0.619500             0.400
# 8             SVM_MM41            0.611000             2.000
# 9              SVM_SP3            0.608000             0.600
# 10            SVM_MM31            0.593000             9.000
# 11             SVM_WD5            0.590000             0.005
# 12             SVM_WD3            0.575408             0.010
# 13             SVM_SP6            0.531000             0.006
#
#    Kernel Method - k=2  Val accuracy - k=2  Constant C - k=2  \
# 0              SVM_SP6            0.730000              0.60
# 1             SVM_MM62            0.728000              8.00
# 2             SVM_MM61            0.714500              6.00
# 3        SVM_LA_e11_d2            0.714500              0.50
# 4             SVM_MM51            0.703000              6.00
# 5              SVM_SP5            0.703000              0.30
# 6             SVM_WD10            0.677000              0.02
# 7              SVM_SP4            0.674500              0.50
# 8              SVM_WD5            0.670000              0.10
# 9             SVM_MM41            0.660000              5.00
# 10             SVM_SP3            0.647500              0.90
# 11            SVM_MM31            0.631500              6.00
# 12             SVM_WD3            0.582403              5.00
# 13                 NaN                 NaN               NaN
#
#    Kernel Method - k=3  Val accuracy - k=3  Constant C - k=3
# 0             SVM_MM61            0.656000             0.690
# 1              SVM_SP6            0.650000             5.000
# 2              SVM_SP5            0.647500             2.000
# 3             SVM_MM62            0.646500             8.000
# 4              SVM_SP4            0.644500             4.000
# 5             SVM_MM51            0.641000             5.000
# 6             SVM_MM41            0.635500             2.000
# 7              SVM_SP3            0.631000             5.000
# 8        SVM_LA_e11_d2            0.620000             0.500
# 9             SVM_MM31            0.618500             1.000
# 10             SVM_WD5            0.594500             0.007
# 11            SVM_WD10            0.594500             0.007
# 12             SVM_WD3            0.555468             0.005
# 13                 NaN                 NaN               NaN

# %% [markdown]
# ### Cross validation on constant C

# %% [markdown]
# Perform cross validation for C-SVM for a bunch of kernel methods whose formating is the following :
# - SPx : spectrum kernel with x = int
# - WDx : Weight degree kernel with x = int
# - WDS_dx,sy : Weight degree kernel with x = int (d), y = int (s)
# - MMxy: mismatch kernel with x = int (k) and y = int (m)
# - LA_ex_dy_bz_smithX_eigY with x = int (e), y = int (d), z = float (beta), X = 0/1 (smith), Y = 0/1 (eig)
#
# Cs can be customed. Otherwise it will be equal to:
# ``Cs = np.sort([i*10**j for (i,j) in product(range(1,10), range(-3,1))])``.

# %%
#methods = ['LA_e8_d1', 'MM31', 'MM41', 'MM51', 'MM61', 'MM62', 'SP3', 'SP4', 
#          'SP5', 'SP6', 'WD4', 'WD5', 'WD10']
methods = ['MM61']
#Cs = np.concatenate((np.linspace(0.01, 0.1, 19),
#                    np.linspace(0.1, 1, 91),
#                    np.linspace(1, 10, 91),
#                   np.linspace(10, 100, 19)))
C_opts = utils.run_expe(methods)#, Cs_1=Cs, Cs_2=Cs, Cs_3=Cs)
# Out:
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# Fold 1
# C=0.001, train_acc=0.5094, val_acc=0.5400
# C=0.002, train_acc=0.5094, val_acc=0.5400
# C=0.003, train_acc=0.5094, val_acc=0.5400
# C=0.004, train_acc=0.5094, val_acc=0.5400
# C=0.005, train_acc=0.5094, val_acc=0.5400
# C=0.006, train_acc=0.5094, val_acc=0.5400
# C=0.007, train_acc=0.5094, val_acc=0.5400
# C=0.008, train_acc=0.5094, val_acc=0.5400
# C=0.009000000000000001, train_acc=0.5094, val_acc=0.5400
# C=0.01, train_acc=0.5094, val_acc=0.5400
# C=0.02, train_acc=0.5094, val_acc=0.5400
# C=0.03, train_acc=0.5094, val_acc=0.5400
# C=0.04, train_acc=0.5094, val_acc=0.5400
# C=0.05, train_acc=0.5094, val_acc=0.5400
# C=0.06, train_acc=0.5119, val_acc=0.5425
# C=0.07, train_acc=0.5250, val_acc=0.5525
# C=0.08, train_acc=0.5431, val_acc=0.5800
# C=0.09, train_acc=0.5831, val_acc=0.6050
# C=0.1, train_acc=0.6156, val_acc=0.6225
# C=0.2, train_acc=0.6925, val_acc=0.6425
# C=0.30000000000000004, train_acc=0.7113, val_acc=0.6600
# C=0.4, train_acc=0.7338, val_acc=0.6825
# C=0.5, train_acc=0.7494, val_acc=0.6600
# C=0.6000000000000001, train_acc=0.7600, val_acc=0.6600
# C=0.7000000000000001, train_acc=0.7731, val_acc=0.6575
# C=0.8, train_acc=0.7837, val_acc=0.6600
# C=0.9, train_acc=0.7900, val_acc=0.6625
# C=1.0, train_acc=0.7987, val_acc=0.6550
# C=2.0, train_acc=0.8344, val_acc=0.6725
# C=3.0, train_acc=0.8681, val_acc=0.6750
# C=4.0, train_acc=0.8938, val_acc=0.6425
# C=5.0, train_acc=0.9044, val_acc=0.6375
# C=6.0, train_acc=0.9150, val_acc=0.6375
# C=7.0, train_acc=0.9275, val_acc=0.6300
# C=8.0, train_acc=0.9306, val_acc=0.6250
# C=9.0, train_acc=0.9356, val_acc=0.6225
# Fold 2
# C=0.001, train_acc=0.5194, val_acc=0.4800
# C=0.002, train_acc=0.5194, val_acc=0.4800
# C=0.003, train_acc=0.5194, val_acc=0.4800
# C=0.004, train_acc=0.5194, val_acc=0.4800
# C=0.005, train_acc=0.5194, val_acc=0.4800
# C=0.006, train_acc=0.5194, val_acc=0.4800
# C=0.007, train_acc=0.5194, val_acc=0.4800
# C=0.008, train_acc=0.5194, val_acc=0.4800
# C=0.009000000000000001, train_acc=0.5194, val_acc=0.4800
# C=0.01, train_acc=0.5194, val_acc=0.4800
# C=0.02, train_acc=0.5194, val_acc=0.4800
# C=0.03, train_acc=0.5194, val_acc=0.4800
# C=0.04, train_acc=0.5194, val_acc=0.4800
# C=0.05, train_acc=0.5200, val_acc=0.4800
# C=0.06, train_acc=0.5200, val_acc=0.4800
# C=0.07, train_acc=0.5281, val_acc=0.4825
# C=0.08, train_acc=0.5337, val_acc=0.4875
# C=0.09, train_acc=0.5425, val_acc=0.4925
# C=0.1, train_acc=0.5587, val_acc=0.4950
# C=0.2, train_acc=0.7063, val_acc=0.5725
# C=0.30000000000000004, train_acc=0.7262, val_acc=0.6000
# C=0.4, train_acc=0.7444, val_acc=0.6100
# C=0.5, train_acc=0.7619, val_acc=0.6225
# C=0.6000000000000001, train_acc=0.7694, val_acc=0.6250
# C=0.7000000000000001, train_acc=0.7831, val_acc=0.6150
# C=0.8, train_acc=0.7881, val_acc=0.6125
# C=0.9, train_acc=0.7969, val_acc=0.6125
# C=1.0, train_acc=0.8031, val_acc=0.6125
# C=2.0, train_acc=0.8525, val_acc=0.6025
# C=3.0, train_acc=0.8719, val_acc=0.6100
# C=4.0, train_acc=0.8888, val_acc=0.5950
# C=5.0, train_acc=0.9038, val_acc=0.5950
# C=6.0, train_acc=0.9194, val_acc=0.5875
# C=7.0, train_acc=0.9294, val_acc=0.5900
# C=8.0, train_acc=0.9394, val_acc=0.5925
# C=9.0, train_acc=0.9444, val_acc=0.5950
# Fold 3
# C=0.001, train_acc=0.5081, val_acc=0.5275
# C=0.002, train_acc=0.5081, val_acc=0.5275
# C=0.003, train_acc=0.5081, val_acc=0.5275
# C=0.004, train_acc=0.5081, val_acc=0.5275
# C=0.005, train_acc=0.5081, val_acc=0.5275
# C=0.006, train_acc=0.5081, val_acc=0.5275
# C=0.007, train_acc=0.5081, val_acc=0.5275
# C=0.008, train_acc=0.5081, val_acc=0.5275
# C=0.009000000000000001, train_acc=0.5081, val_acc=0.5275
# C=0.01, train_acc=0.5081, val_acc=0.5275
# C=0.02, train_acc=0.5081, val_acc=0.5275
# C=0.03, train_acc=0.5081, val_acc=0.5275
# C=0.04, train_acc=0.5081, val_acc=0.5275
# C=0.05, train_acc=0.5088, val_acc=0.5275
# C=0.06, train_acc=0.5144, val_acc=0.5325
# C=0.07, train_acc=0.5244, val_acc=0.5275
# C=0.08, train_acc=0.5525, val_acc=0.5350
# C=0.09, train_acc=0.5913, val_acc=0.5575
# C=0.1, train_acc=0.6206, val_acc=0.5825
# C=0.2, train_acc=0.7019, val_acc=0.6050
# C=0.30000000000000004, train_acc=0.7219, val_acc=0.6150
# C=0.4, train_acc=0.7419, val_acc=0.6025
# C=0.5, train_acc=0.7575, val_acc=0.5950
# C=0.6000000000000001, train_acc=0.7688, val_acc=0.6050
# C=0.7000000000000001, train_acc=0.7775, val_acc=0.6050
# C=0.8, train_acc=0.7913, val_acc=0.5975
# C=0.9, train_acc=0.8025, val_acc=0.6075
# C=1.0, train_acc=0.8081, val_acc=0.6100
# C=2.0, train_acc=0.8462, val_acc=0.6175
# C=3.0, train_acc=0.8781, val_acc=0.6050
# C=4.0, train_acc=0.8919, val_acc=0.6025
# C=5.0, train_acc=0.9044, val_acc=0.5950
# C=6.0, train_acc=0.9144, val_acc=0.5800
# C=7.0, train_acc=0.9231, val_acc=0.5750
# C=8.0, train_acc=0.9306, val_acc=0.5725
# C=9.0, train_acc=0.9369, val_acc=0.5700
# Fold 4
# C=0.001, train_acc=0.5094, val_acc=0.5200
# C=0.002, train_acc=0.5094, val_acc=0.5200
# C=0.003, train_acc=0.5094, val_acc=0.5200
# C=0.004, train_acc=0.5094, val_acc=0.5200
# C=0.005, train_acc=0.5094, val_acc=0.5200
# C=0.006, train_acc=0.5094, val_acc=0.5200
# C=0.007, train_acc=0.5094, val_acc=0.5200
# C=0.008, train_acc=0.5094, val_acc=0.5200
# C=0.009000000000000001, train_acc=0.5094, val_acc=0.5200
# C=0.01, train_acc=0.5094, val_acc=0.5200
# C=0.02, train_acc=0.5094, val_acc=0.5200
# C=0.03, train_acc=0.5094, val_acc=0.5200
# C=0.04, train_acc=0.5094, val_acc=0.5200
# C=0.05, train_acc=0.5119, val_acc=0.5225
# C=0.06, train_acc=0.5162, val_acc=0.5275
# C=0.07, train_acc=0.5300, val_acc=0.5300
# C=0.08, train_acc=0.5531, val_acc=0.5500
# C=0.09, train_acc=0.5781, val_acc=0.5500
# C=0.1, train_acc=0.6162, val_acc=0.5650
# C=0.2, train_acc=0.7056, val_acc=0.5750
# C=0.30000000000000004, train_acc=0.7256, val_acc=0.5775
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-5f7118938db9> in <module>
#       6 #                    np.linspace(1, 10, 91),
#       7 #                   np.linspace(10, 100, 19)))
# ----> 8 C_opts = utils.run_expe(methods)#, Cs_1=Cs, Cs_2=Cs, Cs_3=Cs)
#
# ~/Desktop/MVA/KERNEL/Kernel_methods_MVA/utils.py in run_expe(methods, k, kfolds, Cs_1, Cs_2, Cs_3)
#     274             exec("data_"+str(k_)+" = [X_train_"+str(k_)+", y_train_"+str(k_)+", X_val_"+str(k_)+", y_val_"+str(k_)+"]")
#     275             pickleName = 'cv_C_SVM_'+m+'_k'+str(k_)+'.pkl'
# --> 276             exec("C_opt_"+str(k_)+", _, _, _, _ = SVM.cv(Cs=Cs_"+str(k_)+", data=data_"+str(k_)+", kfolds=kfolds, pickleName=pickleName, K=K, ID=ID)")
#     277             exec("C[m][k_] = C_opt_"+str(k_))
#     278     return C
#
# ~/Desktop/MVA/KERNEL/Kernel_methods_MVA/utils.py in <module>
#
# ~/Desktop/MVA/KERNEL/Kernel_methods_MVA/SVM.py in cv(Cs, data, kfolds, pickleName, **kwargs)
#     144         for C in Cs:
#     145             svm = C_SVM(C=C, print_callbacks=False, **kwargs)
# --> 146             svm.fit(X_train, y_train)
#     147             pred_tr = svm.predict(X_train)
#     148             score_tr = svm.score(pred_tr, y_train)
#
# ~/Desktop/MVA/KERNEL/Kernel_methods_MVA/SVM.py in fit(self, X, y)
#      71         self.Id_fit = np.array(X.loc[:, 'Id'])
#      72         self.idx_fit = np.array([np.where(self.ID == self.Id_fit[i])[0] for i in range(len(self.Id_fit))]).squeeze()
# ---> 73         self.K_fit = self.K[self.idx_fit][:, self.idx_fit]
#      74         self.y_fit, self.X_fit, = np.array(y.loc[:, 'Bound']), X
#      75         n = self.K_fit.shape[0]
#
# KeyboardInterrupt:

# %% [markdown]
# ### Predict with best constant C

# %% [markdown]
# #### Load data and optimal constants

# %%
method = 'MM61'
X_train, y_train, X_val, y_val, X_test, K, ID = utils.get_training_datas(method=method, all=True, replace=False)
#K = kernels.normalize_K(K) # Do nothing if already normalized
for k in range(1, 4):
    exec("X_train_"+str(k)+", y_train_"+str(k)+", X_val_"+str(k)+", y_val_"+str(k)+", X_test_"+str(k)+", K_"+str(k)+", id_"+str(k)+" = utils.select_k(k, X_train, y_train, X_val, y_val, X_test, K, ID)")
C_opt_1, C_opt_2, C_opt_3 = [_ for _ in C_opts[method].values()]
#C_opt_1, C_opt_2, C_opt_3 = 1.5, 4.5, 0.69

# %% [markdown]
# #### Data set 1

# %%
svm_1 = SVM.C_SVM(K, ID, C=C_opt_1, print_callbacks=False)
res = svm_1.fit(X_train_1, y_train_1)
pred_tr_1 = svm_1.predict(X_train_1)
print('Accuracy on train set: {:0.4f}'.format(svm_1.score(pred_tr_1, y_train_1)))
pred_val_1 = svm_1.predict(X_val_1)
print('Accuracy on val set: {:0.4f}'.format(svm_1.score(pred_val_1, y_val_1)))
# Out:
# Accuracy on train set: 0.8512
# Accuracy on val set: 0.6128

# %% [markdown]
# #### Data set 2

# %%
svm_2 = SVM.C_SVM(K, ID, C=C_opt_2, print_callbacks=False)
res = svm_2.fit(X_train_2, y_train_2)
pred_tr_2 = svm_2.predict(X_train_2)
print('Accuracy on train set: {:0.4f}'.format(svm_2.score(pred_tr_2, y_train_2)))
pred_val_2 = svm_2.predict(X_val_2)
print('Accuracy on val set: {:0.4f}'.format(svm_2.score(pred_val_2, y_val_2)))
# Out:
# Accuracy on train set: 0.9566
# Accuracy on val set: 0.6986

# %% [markdown]
# #### Data set 3

# %%
svm_3 = SVM.C_SVM(K, ID, C=C_opt_3, print_callbacks=False)
res = svm_3.fit(X_train_3, y_train_3)
pred_tr_3 = svm_3.predict(X_train_3)
print('Accuracy on train set: {:0.4f}'.format(svm_3.score(pred_tr_3, y_train_3)))
pred_val_3 = svm_3.predict(X_val_3)
print('Accuracy on val set: {:0.4f}'.format(svm_3.score(pred_val_3, y_val_3)))
# Out:
# Accuracy on train set: 0.9059
# Accuracy on val set: 0.6068

# %% [markdown]
# ### Export predictions

# %% [markdown]
# These predictions are dumped into branch master without being pushed. They can be found in your local repo. Submit here : https://www.kaggle.com/c/kernel-methods-for-machine-learning-2018-2019/submit

# %%
y_pred_test = utils.export_predictions([svm_1, svm_2, svm_3], [X_test_1, X_test_2, X_test_3])

# %% [markdown]
# ## ALIGNF

# %% [markdown]
# This algorithm determines the optimal linear combination of kernels (specified by ``methods``) through a convex optimization problem (https://cs.nyu.edu/~mohri/pub/align.pdf).

# %%
methods = ['SP6', 'MM51', 'WD5', 'WD10']
data, data1, data2, data3, aligned_k, ID = ALIGNF.aligned_kernels(methods)
# Out:
# Centering kernels...
# Computing vector a...
# Computing matrix M...
# Gradient descent...
# Iteration  1 : loss=656476353.9974
# Iteration  2 : loss=-1387.9750, tol=656477741.9724
# Iteration  3 : loss=-1427.4204, tol= 39.4454
# Iteration  4 : loss=-1518.2254, tol= 90.8051
# Iteration  5 : loss=-1536.1343, tol= 17.9088
# Iteration  6 : loss=-1536.7800, tol=  0.6458
# Iteration  7 : loss=-1538.2621, tol=  1.4821
# Iteration  8 : loss=-1538.2649, tol=  0.0027
# Iteration  9 : loss=-1538.2649, tol=  0.0000
# Iteration 10 : loss=-1538.2649, tol=  0.0000
# Alignment vector :  [0.72024601 0.         0.         0.69371873]
# -------------------------------------------------------------
# Centering kernels...
# Computing vector a...
# Computing matrix M...
# Gradient descent...
# Iteration  1 : loss=8727006639.8299
# Iteration  2 : loss=-485.5832, tol=8727007125.4131
# Iteration  3 : loss=-1373.1311, tol=887.5479
# Iteration  4 : loss=-1901.6253, tol=528.4942
# Iteration  5 : loss=-2009.2067, tol=107.5814
# Iteration  6 : loss=-2632.0217, tol=622.8150
# Iteration  7 : loss=-2831.1290, tol=199.1073
# Iteration  8 : loss=-2884.2563, tol= 53.1273
# Iteration  9 : loss=-2884.9845, tol=  0.7283
# Iteration 10 : loss=-2885.0067, tol=  0.0222
# Iteration 11 : loss=-2885.0132, tol=  0.0065
# Iteration 12 : loss=-2885.0713, tol=  0.0581
# Iteration 13 : loss=-2885.1784, tol=  0.1071
# Iteration 14 : loss=-2885.4159, tol=  0.2375
# Iteration 15 : loss=-2885.7190, tol=  0.3031
# Iteration 16 : loss=-2885.9629, tol=  0.2439
# Iteration 17 : loss=-2886.0317, tol=  0.0688
# Iteration 18 : loss=-2886.0381, tol=  0.0065
# Iteration 19 : loss=-2886.0383, tol=  0.0002
# Iteration 20 : loss=-2886.0383, tol=  0.0000
# Alignment vector :  [0.85238129 0.         0.         0.52292078]
# -------------------------------------------------------------
# Centering kernels...
# Computing vector a...
# Computing matrix M...
# Gradient descent...
# Iteration  1 : loss=1490521691046.9553
# Iteration  2 : loss=-4966.9647, tol=1490521696013.9202
# Iteration  3 : loss=-5572.0032, tol=605.0385
# Iteration  4 : loss=-7249.1030, tol=1677.0998
# Iteration  5 : loss=-7274.9914, tol= 25.8884
# Iteration  6 : loss=-7282.7606, tol=  7.7692
# Iteration  7 : loss=-7283.3792, tol=  0.6186
# Iteration  8 : loss=-7283.3800, tol=  0.0008
# Iteration  9 : loss=-7283.3800, tol=  0.0000
# Alignment vector :  [0.85881887 0.00163277 0.         0.51227676]
# -------------------------------------------------------------

# %%
Cs= np.sort([i*10**j for (i,j) in product(range(1,10), range(-5,2))])
C_opt_1, _, _, _, _ = SVM.cv(Cs=Cs, data=data1, kfolds=5, pickleName='cv_C_SVM_k1_alignf', K=aligned_k[0], ID=ID)
C_opt_2, _, _, _, _ = SVM.cv(Cs=Cs, data=data2, kfolds=5, pickleName='cv_C_SVM_k2_alignf', K=aligned_k[1], ID=ID)
C_opt_3, _, _, _, _ = SVM.cv(Cs=Cs, data=data3, kfolds=5, pickleName='cv_C_SVM_k3_alignf', K=aligned_k[2], ID=ID)
# Out:
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# Fold 1
# C=1e-05, train_acc=0.0000, val_acc=0.0000
# C=2e-05, train_acc=0.5356, val_acc=0.4900
# C=3.0000000000000004e-05, train_acc=0.5356, val_acc=0.4900
# C=4e-05, train_acc=0.5356, val_acc=0.4900
# C=5e-05, train_acc=0.5356, val_acc=0.4900
# C=6.000000000000001e-05, train_acc=0.5356, val_acc=0.4900
# C=7.000000000000001e-05, train_acc=0.5356, val_acc=0.4900
# C=8e-05, train_acc=0.5356, val_acc=0.4900
# C=9e-05, train_acc=0.5356, val_acc=0.4900
# C=0.0001, train_acc=0.5356, val_acc=0.4900
# C=0.0002, train_acc=0.5356, val_acc=0.4900
# C=0.00030000000000000003, train_acc=0.5356, val_acc=0.4900
# C=0.0004, train_acc=0.5650, val_acc=0.4975
# C=0.0005, train_acc=0.6362, val_acc=0.5075
# C=0.0006000000000000001, train_acc=0.7294, val_acc=0.5400
# C=0.0007, train_acc=0.7944, val_acc=0.5825
# C=0.0008, train_acc=0.8287, val_acc=0.5800
# C=0.0009000000000000001, train_acc=0.8444, val_acc=0.5850
# C=0.001, train_acc=0.8506, val_acc=0.5925
# C=0.002, train_acc=0.7969, val_acc=0.5675
# C=0.003, train_acc=0.8681, val_acc=0.6100
# C=0.004, train_acc=0.9081, val_acc=0.6200
# C=0.005, train_acc=0.9313, val_acc=0.6350
# C=0.006, train_acc=0.9444, val_acc=0.6325
# C=0.007, train_acc=0.9550, val_acc=0.6225
# C=0.008, train_acc=0.9625, val_acc=0.6225
# C=0.009000000000000001, train_acc=0.9688, val_acc=0.6200
# C=0.01, train_acc=0.9744, val_acc=0.6175
# C=0.02, train_acc=0.9931, val_acc=0.6075
# C=0.03, train_acc=0.9981, val_acc=0.6100
# C=0.04, train_acc=0.9994, val_acc=0.6075
# C=0.05, train_acc=0.9994, val_acc=0.6000
# C=0.06, train_acc=0.9994, val_acc=0.6025
# C=0.07, train_acc=0.9994, val_acc=0.6000
# C=0.08, train_acc=1.0000, val_acc=0.5975
# C=0.09, train_acc=1.0000, val_acc=0.5950
# C=0.1, train_acc=1.0000, val_acc=0.5950
# C=0.2, train_acc=1.0000, val_acc=0.6025
# C=0.30000000000000004, train_acc=1.0000, val_acc=0.6025
# C=0.4, train_acc=1.0000, val_acc=0.6025
# C=0.5, train_acc=1.0000, val_acc=0.6025
# C=0.6000000000000001, train_acc=1.0000, val_acc=0.6025
# C=0.7000000000000001, train_acc=1.0000, val_acc=0.6025
# C=0.8, train_acc=1.0000, val_acc=0.6025
# C=0.9, train_acc=1.0000, val_acc=0.6025
# C=1.0, train_acc=1.0000, val_acc=0.6025
# C=2.0, train_acc=1.0000, val_acc=0.6025
# C=3.0, train_acc=1.0000, val_acc=0.6025
# C=4.0, train_acc=1.0000, val_acc=0.6025
# C=5.0, train_acc=1.0000, val_acc=0.6025
# C=6.0, train_acc=1.0000, val_acc=0.6025
# C=7.0, train_acc=1.0000, val_acc=0.6025
# C=8.0, train_acc=1.0000, val_acc=0.6025
# C=9.0, train_acc=1.0000, val_acc=0.6025
# C=10.0, train_acc=1.0000, val_acc=0.6025
# C=20.0, train_acc=1.0000, val_acc=0.6025
# C=30.0, train_acc=1.0000, val_acc=0.6025
# C=40.0, train_acc=1.0000, val_acc=0.6025
# C=50.0, train_acc=1.0000, val_acc=0.6025
# C=60.0, train_acc=1.0000, val_acc=0.6025
# C=70.0, train_acc=1.0000, val_acc=0.6025
# C=80.0, train_acc=1.0000, val_acc=0.6025
# C=90.0, train_acc=1.0000, val_acc=0.6025
# Fold 2
# C=1e-05, train_acc=0.0000, val_acc=0.0000
# C=2e-05, train_acc=0.8344, val_acc=0.6175
# C=3.0000000000000004e-05, train_acc=0.8344, val_acc=0.6175
# C=4e-05, train_acc=0.8344, val_acc=0.6175
# C=5e-05, train_acc=0.8344, val_acc=0.6175
# C=6.000000000000001e-05, train_acc=0.8344, val_acc=0.6175
# C=7.000000000000001e-05, train_acc=0.8344, val_acc=0.6175
# C=8e-05, train_acc=0.8344, val_acc=0.6175
# C=9e-05, train_acc=0.8344, val_acc=0.6175
# C=0.0001, train_acc=0.8344, val_acc=0.6175
# C=0.0002, train_acc=0.8344, val_acc=0.6175
# C=0.00030000000000000003, train_acc=0.8344, val_acc=0.6175
# C=0.0004, train_acc=0.8344, val_acc=0.6175
# C=0.0005, train_acc=0.8450, val_acc=0.6425
# C=0.0006000000000000001, train_acc=0.8381, val_acc=0.6400
# C=0.0007, train_acc=0.8287, val_acc=0.6200
# C=0.0008, train_acc=0.8044, val_acc=0.5800
# C=0.0009000000000000001, train_acc=0.7831, val_acc=0.5625
# C=0.001, train_acc=0.7594, val_acc=0.5525
# C=0.002, train_acc=0.7212, val_acc=0.5600
# C=0.003, train_acc=0.8387, val_acc=0.5700
# C=0.004, train_acc=0.8975, val_acc=0.6150
# C=0.005, train_acc=0.9244, val_acc=0.6325
# C=0.006, train_acc=0.9369, val_acc=0.6275
# C=0.007, train_acc=0.9487, val_acc=0.6300
# C=0.008, train_acc=0.9587, val_acc=0.6325
# C=0.009000000000000001, train_acc=0.9650, val_acc=0.6200
# C=0.01, train_acc=0.9688, val_acc=0.6200
# C=0.02, train_acc=0.9931, val_acc=0.6375
# C=0.03, train_acc=0.9956, val_acc=0.6250
# C=0.04, train_acc=0.9988, val_acc=0.6275
# C=0.05, train_acc=0.9988, val_acc=0.6275
# C=0.06, train_acc=0.9988, val_acc=0.6250
# C=0.07, train_acc=0.9994, val_acc=0.6175
# C=0.08, train_acc=0.9994, val_acc=0.6150
# C=0.09, train_acc=0.9994, val_acc=0.6125
# C=0.1, train_acc=0.9994, val_acc=0.6175
# C=0.2, train_acc=1.0000, val_acc=0.6175
# C=0.30000000000000004, train_acc=1.0000, val_acc=0.6175
# C=0.4, train_acc=1.0000, val_acc=0.6200
# C=0.5, train_acc=1.0000, val_acc=0.6175
# C=0.6000000000000001, train_acc=1.0000, val_acc=0.6175
# C=0.7000000000000001, train_acc=1.0000, val_acc=0.6200
# C=0.8, train_acc=1.0000, val_acc=0.6175
# C=0.9, train_acc=1.0000, val_acc=0.6175
# C=1.0, train_acc=1.0000, val_acc=0.6175
# C=2.0, train_acc=1.0000, val_acc=0.6200
# C=3.0, train_acc=1.0000, val_acc=0.6175
# C=4.0, train_acc=1.0000, val_acc=0.6175
# C=5.0, train_acc=1.0000, val_acc=0.6175
# C=6.0, train_acc=1.0000, val_acc=0.6175
# C=7.0, train_acc=1.0000, val_acc=0.6200
# C=8.0, train_acc=1.0000, val_acc=0.6175
# C=9.0, train_acc=1.0000, val_acc=0.6200
# C=10.0, train_acc=1.0000, val_acc=0.6175
# C=20.0, train_acc=1.0000, val_acc=0.6175
# C=30.0, train_acc=1.0000, val_acc=0.6175
# C=40.0, train_acc=1.0000, val_acc=0.6175
# C=50.0, train_acc=1.0000, val_acc=0.6175
# C=60.0, train_acc=1.0000, val_acc=0.6150
# C=70.0, train_acc=1.0000, val_acc=0.6175
# C=80.0, train_acc=1.0000, val_acc=0.6175
# C=90.0, train_acc=1.0000, val_acc=0.6175
# Fold 3
# C=1e-05, train_acc=0.0000, val_acc=0.0000
# C=2e-05, train_acc=0.5400, val_acc=0.4975
# C=3.0000000000000004e-05, train_acc=0.5400, val_acc=0.4975
# C=4e-05, train_acc=0.5400, val_acc=0.4975
# C=5e-05, train_acc=0.5400, val_acc=0.4975
# C=6.000000000000001e-05, train_acc=0.5400, val_acc=0.4975
# C=7.000000000000001e-05, train_acc=0.5400, val_acc=0.4975
# C=8e-05, train_acc=0.5400, val_acc=0.4975
# C=9e-05, train_acc=0.5400, val_acc=0.4975
# C=0.0001, train_acc=0.5400, val_acc=0.4975
# C=0.0002, train_acc=0.5400, val_acc=0.4975
# C=0.00030000000000000003, train_acc=0.5400, val_acc=0.4975
# C=0.0004, train_acc=0.5425, val_acc=0.4975
# C=0.0005, train_acc=0.5819, val_acc=0.5025
# C=0.0006000000000000001, train_acc=0.6506, val_acc=0.5100
# C=0.0007, train_acc=0.7113, val_acc=0.5425
# C=0.0008, train_acc=0.7675, val_acc=0.5675
# C=0.0009000000000000001, train_acc=0.8131, val_acc=0.5950
# C=0.001, train_acc=0.8369, val_acc=0.6125
# C=0.002, train_acc=0.8231, val_acc=0.6050
# C=0.003, train_acc=0.8731, val_acc=0.6200
# C=0.004, train_acc=0.9100, val_acc=0.6200
# C=0.005, train_acc=0.9269, val_acc=0.6350
# C=0.006, train_acc=0.9431, val_acc=0.6375
# C=0.007, train_acc=0.9563, val_acc=0.6350
# C=0.008, train_acc=0.9669, val_acc=0.6375
# C=0.009000000000000001, train_acc=0.9712, val_acc=0.6375
# C=0.01, train_acc=0.9775, val_acc=0.6350
# C=0.02, train_acc=0.9944, val_acc=0.6150
# C=0.03, train_acc=0.9975, val_acc=0.6275
# C=0.04, train_acc=0.9981, val_acc=0.6350
# C=0.05, train_acc=0.9988, val_acc=0.6175
# C=0.06, train_acc=0.9988, val_acc=0.6225
# C=0.07, train_acc=0.9988, val_acc=0.6275
# C=0.08, train_acc=0.9994, val_acc=0.6175
# C=0.09, train_acc=0.9994, val_acc=0.6200
# C=0.1, train_acc=0.9994, val_acc=0.6175
# C=0.2, train_acc=1.0000, val_acc=0.6075
# C=0.30000000000000004, train_acc=1.0000, val_acc=0.6075
# C=0.4, train_acc=1.0000, val_acc=0.6100
# C=0.5, train_acc=1.0000, val_acc=0.6075
# C=0.6000000000000001, train_acc=1.0000, val_acc=0.6075
# C=0.7000000000000001, train_acc=1.0000, val_acc=0.6100
# C=0.8, train_acc=1.0000, val_acc=0.6075
# C=0.9, train_acc=1.0000, val_acc=0.6100
# C=1.0, train_acc=1.0000, val_acc=0.6100
# C=2.0, train_acc=1.0000, val_acc=0.6100
# C=3.0, train_acc=1.0000, val_acc=0.6100
# C=4.0, train_acc=1.0000, val_acc=0.6075
# C=5.0, train_acc=1.0000, val_acc=0.6075
# C=6.0, train_acc=1.0000, val_acc=0.6100
# C=7.0, train_acc=1.0000, val_acc=0.6075
# C=8.0, train_acc=1.0000, val_acc=0.6100
# C=9.0, train_acc=1.0000, val_acc=0.6100
# C=10.0, train_acc=1.0000, val_acc=0.6075
# C=20.0, train_acc=1.0000, val_acc=0.6075
# C=30.0, train_acc=1.0000, val_acc=0.6075
# C=40.0, train_acc=1.0000, val_acc=0.6075
# C=50.0, train_acc=1.0000, val_acc=0.6075
# C=60.0, train_acc=1.0000, val_acc=0.6075
# C=70.0, train_acc=1.0000, val_acc=0.6100
# C=80.0, train_acc=1.0000, val_acc=0.6075
# C=90.0, train_acc=1.0000, val_acc=0.6075
# Fold 4
# C=1e-05, train_acc=0.0000, val_acc=0.0000
# C=2e-05, train_acc=0.7544, val_acc=0.5725
# C=3.0000000000000004e-05, train_acc=0.7544, val_acc=0.5725
# C=4e-05, train_acc=0.7544, val_acc=0.5725
# C=5e-05, train_acc=0.7544, val_acc=0.5725
# C=6.000000000000001e-05, train_acc=0.7544, val_acc=0.5725
# C=7.000000000000001e-05, train_acc=0.7544, val_acc=0.5725
# C=8e-05, train_acc=0.7544, val_acc=0.5725
# C=9e-05, train_acc=0.7544, val_acc=0.5725
# C=0.0001, train_acc=0.7544, val_acc=0.5725
# C=0.0002, train_acc=0.7544, val_acc=0.5725
# C=0.00030000000000000003, train_acc=0.7544, val_acc=0.5725
# C=0.0004, train_acc=0.7544, val_acc=0.5725
# C=0.0005, train_acc=0.7887, val_acc=0.5725
# C=0.0006000000000000001, train_acc=0.8263, val_acc=0.5775
# C=0.0007, train_acc=0.8450, val_acc=0.5875
# C=0.0008, train_acc=0.8344, val_acc=0.5950
# C=0.0009000000000000001, train_acc=0.8244, val_acc=0.6025
# C=0.001, train_acc=0.8050, val_acc=0.5925
# C=0.002, train_acc=0.7419, val_acc=0.5775
# C=0.003, train_acc=0.8644, val_acc=0.6050
# C=0.004, train_acc=0.9031, val_acc=0.6375
# C=0.005, train_acc=0.9256, val_acc=0.6250
# C=0.006, train_acc=0.9431, val_acc=0.6100
# C=0.007, train_acc=0.9581, val_acc=0.6125
# C=0.008, train_acc=0.9656, val_acc=0.6050
# C=0.009000000000000001, train_acc=0.9744, val_acc=0.5950
# C=0.01, train_acc=0.9769, val_acc=0.5950
# C=0.02, train_acc=0.9931, val_acc=0.6100
# C=0.03, train_acc=0.9975, val_acc=0.6000
# C=0.04, train_acc=0.9981, val_acc=0.5975
# C=0.05, train_acc=0.9981, val_acc=0.5825
# C=0.06, train_acc=0.9994, val_acc=0.5850
# C=0.07, train_acc=1.0000, val_acc=0.5800
# C=0.08, train_acc=1.0000, val_acc=0.5800
# C=0.09, train_acc=1.0000, val_acc=0.5775
# C=0.1, train_acc=1.0000, val_acc=0.5800
# C=0.2, train_acc=1.0000, val_acc=0.5800
# C=0.30000000000000004, train_acc=1.0000, val_acc=0.5800
# C=0.4, train_acc=1.0000, val_acc=0.5800
# C=0.5, train_acc=1.0000, val_acc=0.5800
# C=0.6000000000000001, train_acc=1.0000, val_acc=0.5800
# C=0.7000000000000001, train_acc=1.0000, val_acc=0.5800
# C=0.8, train_acc=1.0000, val_acc=0.5800
# C=0.9, train_acc=1.0000, val_acc=0.5800
# C=1.0, train_acc=1.0000, val_acc=0.5800
# C=2.0, train_acc=1.0000, val_acc=0.5800
# C=3.0, train_acc=1.0000, val_acc=0.5800
# C=4.0, train_acc=1.0000, val_acc=0.5800
# C=5.0, train_acc=1.0000, val_acc=0.5800
# C=6.0, train_acc=1.0000, val_acc=0.5800
# C=7.0, train_acc=1.0000, val_acc=0.5800
# C=8.0, train_acc=1.0000, val_acc=0.5800
# C=9.0, train_acc=1.0000, val_acc=0.5800
# C=10.0, train_acc=1.0000, val_acc=0.5800
# C=20.0, train_acc=1.0000, val_acc=0.5800
# C=30.0, train_acc=1.0000, val_acc=0.5800
# C=40.0, train_acc=1.0000, val_acc=0.5800
# C=50.0, train_acc=1.0000, val_acc=0.5800
# C=60.0, train_acc=1.0000, val_acc=0.5800
# C=70.0, train_acc=1.0000, val_acc=0.5800
# C=80.0, train_acc=1.0000, val_acc=0.5800
# C=90.0, train_acc=1.0000, val_acc=0.5800
# Fold 5
# C=1e-05, train_acc=0.0000, val_acc=0.0000
# C=2e-05, train_acc=0.5275, val_acc=0.4825
# C=3.0000000000000004e-05, train_acc=0.5275, val_acc=0.4825
# C=4e-05, train_acc=0.5275, val_acc=0.4825
# C=5e-05, train_acc=0.5275, val_acc=0.4825
# C=6.000000000000001e-05, train_acc=0.5275, val_acc=0.4825
# C=7.000000000000001e-05, train_acc=0.5275, val_acc=0.4825
# C=8e-05, train_acc=0.5275, val_acc=0.4825
# C=9e-05, train_acc=0.5275, val_acc=0.4825
# C=0.0001, train_acc=0.5275, val_acc=0.4825
# C=0.0002, train_acc=0.5275, val_acc=0.4825
# C=0.00030000000000000003, train_acc=0.5275, val_acc=0.4825
# C=0.0004, train_acc=0.5294, val_acc=0.4825
# C=0.0005, train_acc=0.5375, val_acc=0.4850
# C=0.0006000000000000001, train_acc=0.5706, val_acc=0.5000
# C=0.0007, train_acc=0.6175, val_acc=0.5100
# C=0.0008, train_acc=0.6619, val_acc=0.5150
# C=0.0009000000000000001, train_acc=0.7087, val_acc=0.5250
# C=0.001, train_acc=0.7569, val_acc=0.5550
# C=0.002, train_acc=0.8725, val_acc=0.6525
# C=0.003, train_acc=0.8900, val_acc=0.6500
# C=0.004, train_acc=0.9113, val_acc=0.6575
# C=0.005, train_acc=0.9256, val_acc=0.6525
# C=0.006, train_acc=0.9444, val_acc=0.6475
# C=0.007, train_acc=0.9544, val_acc=0.6425
# C=0.008, train_acc=0.9631, val_acc=0.6350
# C=0.009000000000000001, train_acc=0.9706, val_acc=0.6325
# C=0.01, train_acc=0.9794, val_acc=0.6300
# C=0.02, train_acc=0.9956, val_acc=0.6100
# C=0.03, train_acc=0.9988, val_acc=0.6075
# C=0.04, train_acc=1.0000, val_acc=0.6000
# C=0.05, train_acc=1.0000, val_acc=0.5950
# C=0.06, train_acc=1.0000, val_acc=0.5975
# C=0.07, train_acc=1.0000, val_acc=0.6000
# C=0.08, train_acc=1.0000, val_acc=0.6000
# C=0.09, train_acc=1.0000, val_acc=0.6000
# C=0.1, train_acc=1.0000, val_acc=0.6000
# C=0.2, train_acc=1.0000, val_acc=0.5975
# C=0.30000000000000004, train_acc=1.0000, val_acc=0.6000
# C=0.4, train_acc=1.0000, val_acc=0.5975
# C=0.5, train_acc=1.0000, val_acc=0.6000
# C=0.6000000000000001, train_acc=1.0000, val_acc=0.5975
# C=0.7000000000000001, train_acc=1.0000, val_acc=0.5975
# C=0.8, train_acc=1.0000, val_acc=0.5975
# C=0.9, train_acc=1.0000, val_acc=0.5975
# C=1.0, train_acc=1.0000, val_acc=0.5975
# C=2.0, train_acc=1.0000, val_acc=0.6000
# C=3.0, train_acc=1.0000, val_acc=0.5975
# C=4.0, train_acc=1.0000, val_acc=0.5975
# C=5.0, train_acc=1.0000, val_acc=0.5975
# C=6.0, train_acc=1.0000, val_acc=0.5975
# C=7.0, train_acc=1.0000, val_acc=0.6000
# C=8.0, train_acc=1.0000, val_acc=0.6000
# C=9.0, train_acc=1.0000, val_acc=0.6000
# C=10.0, train_acc=1.0000, val_acc=0.5975
# C=20.0, train_acc=1.0000, val_acc=0.5975
# C=30.0, train_acc=1.0000, val_acc=0.6000
# C=40.0, train_acc=1.0000, val_acc=0.5975
# C=50.0, train_acc=1.0000, val_acc=0.5975
# C=60.0, train_acc=1.0000, val_acc=0.6000
# C=70.0, train_acc=1.0000, val_acc=0.6000
# C=80.0, train_acc=1.0000, val_acc=0.5975
# C=90.0, train_acc=1.0000, val_acc=0.6000
# Best constant C: 0.005, accuracy on val 0.6360
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# Fold 1
# C=1e-05, train_acc=0.0000, val_acc=0.0000
# C=2e-05, train_acc=0.8806, val_acc=0.7100
# C=3.0000000000000004e-05, train_acc=0.8806, val_acc=0.7100
# C=4e-05, train_acc=0.8806, val_acc=0.7100
# C=5e-05, train_acc=0.8806, val_acc=0.7100
# C=6.000000000000001e-05, train_acc=0.8806, val_acc=0.7100
# C=7.000000000000001e-05, train_acc=0.8806, val_acc=0.7100
# C=8e-05, train_acc=0.8806, val_acc=0.7100
# C=9e-05, train_acc=0.8806, val_acc=0.7100
# C=0.0001, train_acc=0.8806, val_acc=0.7100
# C=0.0002, train_acc=0.8806, val_acc=0.7100
# C=0.00030000000000000003, train_acc=0.8806, val_acc=0.7100
# C=0.0004, train_acc=0.8806, val_acc=0.7100
# C=0.0005, train_acc=0.8806, val_acc=0.7100
# C=0.0006000000000000001, train_acc=0.8806, val_acc=0.7100
# C=0.0007, train_acc=0.8806, val_acc=0.7100
# C=0.0008, train_acc=0.8806, val_acc=0.7100
# C=0.0009000000000000001, train_acc=0.8806, val_acc=0.7100
# C=0.001, train_acc=0.8806, val_acc=0.7100
# C=0.002, train_acc=0.8925, val_acc=0.7175
# C=0.003, train_acc=0.9287, val_acc=0.7225
# C=0.004, train_acc=0.9469, val_acc=0.7175
# C=0.005, train_acc=0.9581, val_acc=0.7050
# C=0.006, train_acc=0.9656, val_acc=0.6900
# C=0.007, train_acc=0.9731, val_acc=0.6950
# C=0.008, train_acc=0.9781, val_acc=0.6975
# C=0.009000000000000001, train_acc=0.9831, val_acc=0.6975
# C=0.01, train_acc=0.9844, val_acc=0.6975
# C=0.02, train_acc=0.9994, val_acc=0.7225
# C=0.03, train_acc=1.0000, val_acc=0.7175
# C=0.04, train_acc=1.0000, val_acc=0.7175
# C=0.05, train_acc=1.0000, val_acc=0.7175
# C=0.06, train_acc=1.0000, val_acc=0.7175
# C=0.07, train_acc=1.0000, val_acc=0.7175
# C=0.08, train_acc=1.0000, val_acc=0.7175
# C=0.09, train_acc=1.0000, val_acc=0.7175
# C=0.1, train_acc=1.0000, val_acc=0.7175
# C=0.2, train_acc=1.0000, val_acc=0.7175
# C=0.30000000000000004, train_acc=1.0000, val_acc=0.7175
# C=0.4, train_acc=1.0000, val_acc=0.7175
# C=0.5, train_acc=1.0000, val_acc=0.7175
# C=0.6000000000000001, train_acc=1.0000, val_acc=0.7175
# C=0.7000000000000001, train_acc=1.0000, val_acc=0.7175
# C=0.8, train_acc=1.0000, val_acc=0.7175
# C=0.9, train_acc=1.0000, val_acc=0.7175
# C=1.0, train_acc=1.0000, val_acc=0.7175
# C=2.0, train_acc=1.0000, val_acc=0.7175
# C=3.0, train_acc=1.0000, val_acc=0.7175
# C=4.0, train_acc=1.0000, val_acc=0.7175
# C=5.0, train_acc=1.0000, val_acc=0.7175
# C=6.0, train_acc=1.0000, val_acc=0.7175
# C=7.0, train_acc=1.0000, val_acc=0.7175
# C=8.0, train_acc=1.0000, val_acc=0.7175
# C=9.0, train_acc=1.0000, val_acc=0.7175
# C=10.0, train_acc=1.0000, val_acc=0.7175
# C=20.0, train_acc=1.0000, val_acc=0.7175
# C=30.0, train_acc=1.0000, val_acc=0.7175
# C=40.0, train_acc=1.0000, val_acc=0.7175
# C=50.0, train_acc=1.0000, val_acc=0.7175
# C=60.0, train_acc=1.0000, val_acc=0.7175
# C=70.0, train_acc=1.0000, val_acc=0.7175
# C=80.0, train_acc=1.0000, val_acc=0.7175
# C=90.0, train_acc=1.0000, val_acc=0.7175
# Fold 2
# C=1e-05, train_acc=0.0000, val_acc=0.0000
# C=2e-05, train_acc=0.7350, val_acc=0.5900
# C=3.0000000000000004e-05, train_acc=0.7350, val_acc=0.5900
# C=4e-05, train_acc=0.7350, val_acc=0.5900
# C=5e-05, train_acc=0.7350, val_acc=0.5900
# C=6.000000000000001e-05, train_acc=0.7350, val_acc=0.5900
# C=7.000000000000001e-05, train_acc=0.7350, val_acc=0.5900
# C=8e-05, train_acc=0.7350, val_acc=0.5900
# C=9e-05, train_acc=0.7350, val_acc=0.5900
# C=0.0001, train_acc=0.7350, val_acc=0.5900
# C=0.0002, train_acc=0.7350, val_acc=0.5900
# C=0.00030000000000000003, train_acc=0.7350, val_acc=0.5900
# C=0.0004, train_acc=0.7350, val_acc=0.5900
# C=0.0005, train_acc=0.7350, val_acc=0.5900
# C=0.0006000000000000001, train_acc=0.7350, val_acc=0.5900
# C=0.0007, train_acc=0.7350, val_acc=0.5900
# C=0.0008, train_acc=0.7450, val_acc=0.5925
# C=0.0009000000000000001, train_acc=0.7588, val_acc=0.5975
# C=0.001, train_acc=0.7731, val_acc=0.6125
# C=0.002, train_acc=0.8656, val_acc=0.7000
# C=0.003, train_acc=0.9131, val_acc=0.7100
# C=0.004, train_acc=0.9350, val_acc=0.7175
# C=0.005, train_acc=0.9481, val_acc=0.7275
# C=0.006, train_acc=0.9594, val_acc=0.7175
# C=0.007, train_acc=0.9700, val_acc=0.7150
# C=0.008, train_acc=0.9762, val_acc=0.7100
# C=0.009000000000000001, train_acc=0.9800, val_acc=0.7075
# C=0.01, train_acc=0.9838, val_acc=0.7075
# C=0.02, train_acc=0.9994, val_acc=0.6800
# C=0.03, train_acc=1.0000, val_acc=0.6825
# C=0.04, train_acc=1.0000, val_acc=0.6800
# C=0.05, train_acc=1.0000, val_acc=0.6800
# C=0.06, train_acc=1.0000, val_acc=0.6800
# C=0.07, train_acc=1.0000, val_acc=0.6800
# C=0.08, train_acc=1.0000, val_acc=0.6800
# C=0.09, train_acc=1.0000, val_acc=0.6800
# C=0.1, train_acc=1.0000, val_acc=0.6800
# C=0.2, train_acc=1.0000, val_acc=0.6800
# C=0.30000000000000004, train_acc=1.0000, val_acc=0.6800
# C=0.4, train_acc=1.0000, val_acc=0.6800
# C=0.5, train_acc=1.0000, val_acc=0.6800
# C=0.6000000000000001, train_acc=1.0000, val_acc=0.6800
# C=0.7000000000000001, train_acc=1.0000, val_acc=0.6800
# C=0.8, train_acc=1.0000, val_acc=0.6800
# C=0.9, train_acc=1.0000, val_acc=0.6800
# C=1.0, train_acc=1.0000, val_acc=0.6800
# C=2.0, train_acc=1.0000, val_acc=0.6800
# C=3.0, train_acc=1.0000, val_acc=0.6800
# C=4.0, train_acc=1.0000, val_acc=0.6800
# C=5.0, train_acc=1.0000, val_acc=0.6800
# C=6.0, train_acc=1.0000, val_acc=0.6800
# C=7.0, train_acc=1.0000, val_acc=0.6800
# C=8.0, train_acc=1.0000, val_acc=0.6800
# C=9.0, train_acc=1.0000, val_acc=0.6800
# C=10.0, train_acc=1.0000, val_acc=0.6800
# C=20.0, train_acc=1.0000, val_acc=0.6800
# C=30.0, train_acc=1.0000, val_acc=0.6800
# C=40.0, train_acc=1.0000, val_acc=0.6800
# C=50.0, train_acc=1.0000, val_acc=0.6800
# C=60.0, train_acc=1.0000, val_acc=0.6800
# C=70.0, train_acc=1.0000, val_acc=0.6800
# C=80.0, train_acc=1.0000, val_acc=0.6800
# C=90.0, train_acc=1.0000, val_acc=0.6800
# Fold 3
# C=1e-05, train_acc=0.0000, val_acc=0.0000
# C=2e-05, train_acc=0.8525, val_acc=0.7200
# C=3.0000000000000004e-05, train_acc=0.8525, val_acc=0.7200
# C=4e-05, train_acc=0.8525, val_acc=0.7200
# C=5e-05, train_acc=0.8525, val_acc=0.7200
# C=6.000000000000001e-05, train_acc=0.8525, val_acc=0.7200
# C=7.000000000000001e-05, train_acc=0.8525, val_acc=0.7200
# C=8e-05, train_acc=0.8525, val_acc=0.7200
# C=9e-05, train_acc=0.8525, val_acc=0.7200
# C=0.0001, train_acc=0.8525, val_acc=0.7200
# C=0.0002, train_acc=0.8525, val_acc=0.7200
# C=0.00030000000000000003, train_acc=0.8525, val_acc=0.7200
# C=0.0004, train_acc=0.8525, val_acc=0.7200
# C=0.0005, train_acc=0.8525, val_acc=0.7200
# C=0.0006000000000000001, train_acc=0.8525, val_acc=0.7200
# C=0.0007, train_acc=0.8525, val_acc=0.7200
# C=0.0008, train_acc=0.8525, val_acc=0.7200
# C=0.0009000000000000001, train_acc=0.8525, val_acc=0.7200
# C=0.001, train_acc=0.8556, val_acc=0.7175
# C=0.002, train_acc=0.8894, val_acc=0.7175
# C=0.003, train_acc=0.9150, val_acc=0.7175
# C=0.004, train_acc=0.9294, val_acc=0.7150
# C=0.005, train_acc=0.9469, val_acc=0.7300
# C=0.006, train_acc=0.9619, val_acc=0.7450
# C=0.007, train_acc=0.9700, val_acc=0.7425
# C=0.008, train_acc=0.9750, val_acc=0.7500
# C=0.009000000000000001, train_acc=0.9831, val_acc=0.7525
# C=0.01, train_acc=0.9856, val_acc=0.7575
# C=0.02, train_acc=0.9994, val_acc=0.7400
# C=0.03, train_acc=1.0000, val_acc=0.7375
# C=0.04, train_acc=1.0000, val_acc=0.7425
# C=0.05, train_acc=1.0000, val_acc=0.7425
# C=0.06, train_acc=1.0000, val_acc=0.7425
# C=0.07, train_acc=1.0000, val_acc=0.7425
# C=0.08, train_acc=1.0000, val_acc=0.7425
# C=0.09, train_acc=1.0000, val_acc=0.7425
# C=0.1, train_acc=1.0000, val_acc=0.7425
# C=0.2, train_acc=1.0000, val_acc=0.7425
# C=0.30000000000000004, train_acc=1.0000, val_acc=0.7425
# C=0.4, train_acc=1.0000, val_acc=0.7425
# C=0.5, train_acc=1.0000, val_acc=0.7425
# C=0.6000000000000001, train_acc=1.0000, val_acc=0.7425
# C=0.7000000000000001, train_acc=1.0000, val_acc=0.7425
# C=0.8, train_acc=1.0000, val_acc=0.7425
# C=0.9, train_acc=1.0000, val_acc=0.7425
# C=1.0, train_acc=1.0000, val_acc=0.7375
# C=2.0, train_acc=1.0000, val_acc=0.7425
# C=3.0, train_acc=1.0000, val_acc=0.7425
# C=4.0, train_acc=1.0000, val_acc=0.7425
# C=5.0, train_acc=1.0000, val_acc=0.7425
# C=6.0, train_acc=1.0000, val_acc=0.7425
# C=7.0, train_acc=1.0000, val_acc=0.7425
# C=8.0, train_acc=1.0000, val_acc=0.7425
# C=9.0, train_acc=1.0000, val_acc=0.7425
# C=10.0, train_acc=1.0000, val_acc=0.7425
# C=20.0, train_acc=1.0000, val_acc=0.7425
# C=30.0, train_acc=1.0000, val_acc=0.7425
# C=40.0, train_acc=1.0000, val_acc=0.7425
# C=50.0, train_acc=1.0000, val_acc=0.7425
# C=60.0, train_acc=1.0000, val_acc=0.7425
# C=70.0, train_acc=1.0000, val_acc=0.7425
# C=80.0, train_acc=1.0000, val_acc=0.7425
# C=90.0, train_acc=1.0000, val_acc=0.7425
# Fold 4
# C=1e-05, train_acc=0.0000, val_acc=0.0000
# C=2e-05, train_acc=0.8700, val_acc=0.7125
# C=3.0000000000000004e-05, train_acc=0.8700, val_acc=0.7125
# C=4e-05, train_acc=0.8700, val_acc=0.7125
# C=5e-05, train_acc=0.8700, val_acc=0.7125
# C=6.000000000000001e-05, train_acc=0.8700, val_acc=0.7125
# C=7.000000000000001e-05, train_acc=0.8700, val_acc=0.7125
# C=8e-05, train_acc=0.8700, val_acc=0.7125
# C=9e-05, train_acc=0.8700, val_acc=0.7125
# C=0.0001, train_acc=0.8700, val_acc=0.7125
# C=0.0002, train_acc=0.8700, val_acc=0.7125
# C=0.00030000000000000003, train_acc=0.8700, val_acc=0.7125
# C=0.0004, train_acc=0.8700, val_acc=0.7125
# C=0.0005, train_acc=0.8700, val_acc=0.7125
# C=0.0006000000000000001, train_acc=0.8700, val_acc=0.7125
# C=0.0007, train_acc=0.8700, val_acc=0.7125
# C=0.0008, train_acc=0.8700, val_acc=0.7125
# C=0.0009000000000000001, train_acc=0.8706, val_acc=0.7150
# C=0.001, train_acc=0.8706, val_acc=0.7150
# C=0.002, train_acc=0.8938, val_acc=0.7425
# C=0.003, train_acc=0.9206, val_acc=0.7525
# C=0.004, train_acc=0.9456, val_acc=0.7600
# C=0.005, train_acc=0.9594, val_acc=0.7525
# C=0.006, train_acc=0.9631, val_acc=0.7550
# C=0.007, train_acc=0.9738, val_acc=0.7600
# C=0.008, train_acc=0.9781, val_acc=0.7650
# C=0.009000000000000001, train_acc=0.9825, val_acc=0.7625
# C=0.01, train_acc=0.9862, val_acc=0.7550
# C=0.02, train_acc=0.9994, val_acc=0.7450
# C=0.03, train_acc=1.0000, val_acc=0.7425
# C=0.04, train_acc=1.0000, val_acc=0.7450
# C=0.05, train_acc=1.0000, val_acc=0.7450
# C=0.06, train_acc=1.0000, val_acc=0.7450
# C=0.07, train_acc=1.0000, val_acc=0.7450
# C=0.08, train_acc=1.0000, val_acc=0.7450
# C=0.09, train_acc=1.0000, val_acc=0.7450
# C=0.1, train_acc=1.0000, val_acc=0.7450
# C=0.2, train_acc=1.0000, val_acc=0.7450
# C=0.30000000000000004, train_acc=1.0000, val_acc=0.7450
# C=0.4, train_acc=1.0000, val_acc=0.7450
# C=0.5, train_acc=1.0000, val_acc=0.7450
# C=0.6000000000000001, train_acc=1.0000, val_acc=0.7450
# C=0.7000000000000001, train_acc=1.0000, val_acc=0.7450
# C=0.8, train_acc=1.0000, val_acc=0.7450
# C=0.9, train_acc=1.0000, val_acc=0.7450
# C=1.0, train_acc=1.0000, val_acc=0.7450
# C=2.0, train_acc=1.0000, val_acc=0.7450
# C=3.0, train_acc=1.0000, val_acc=0.7450
# C=4.0, train_acc=1.0000, val_acc=0.7450
# C=5.0, train_acc=1.0000, val_acc=0.7450
# C=6.0, train_acc=1.0000, val_acc=0.7450
# C=7.0, train_acc=1.0000, val_acc=0.7450
# C=8.0, train_acc=1.0000, val_acc=0.7450
# C=9.0, train_acc=1.0000, val_acc=0.7450
# C=10.0, train_acc=1.0000, val_acc=0.7450
# C=20.0, train_acc=1.0000, val_acc=0.7450
# C=30.0, train_acc=1.0000, val_acc=0.7450
# C=40.0, train_acc=1.0000, val_acc=0.7450
# C=50.0, train_acc=1.0000, val_acc=0.7450
# C=60.0, train_acc=1.0000, val_acc=0.7450
# C=70.0, train_acc=1.0000, val_acc=0.7450
# C=80.0, train_acc=1.0000, val_acc=0.7450
# C=90.0, train_acc=1.0000, val_acc=0.7450
# Fold 5
# C=1e-05, train_acc=0.0000, val_acc=0.0000
# C=2e-05, train_acc=0.8681, val_acc=0.6600
# C=3.0000000000000004e-05, train_acc=0.8681, val_acc=0.6600
# C=4e-05, train_acc=0.8681, val_acc=0.6600
# C=5e-05, train_acc=0.8681, val_acc=0.6600
# C=6.000000000000001e-05, train_acc=0.8681, val_acc=0.6600
# C=7.000000000000001e-05, train_acc=0.8681, val_acc=0.6600
# C=8e-05, train_acc=0.8681, val_acc=0.6600
# C=9e-05, train_acc=0.8681, val_acc=0.6600
# C=0.0001, train_acc=0.8681, val_acc=0.6600
# C=0.0002, train_acc=0.8681, val_acc=0.6600
# C=0.00030000000000000003, train_acc=0.8681, val_acc=0.6600
# C=0.0004, train_acc=0.8681, val_acc=0.6600
# C=0.0005, train_acc=0.8681, val_acc=0.6600
# C=0.0006000000000000001, train_acc=0.8681, val_acc=0.6600
# C=0.0007, train_acc=0.8681, val_acc=0.6600
# C=0.0008, train_acc=0.8681, val_acc=0.6600
# C=0.0009000000000000001, train_acc=0.8681, val_acc=0.6675
# C=0.001, train_acc=0.8700, val_acc=0.6675
# C=0.002, train_acc=0.8912, val_acc=0.6850
# C=0.003, train_acc=0.9250, val_acc=0.7000
# C=0.004, train_acc=0.9431, val_acc=0.7100
# C=0.005, train_acc=0.9537, val_acc=0.7050
# C=0.006, train_acc=0.9650, val_acc=0.7000
# C=0.007, train_acc=0.9712, val_acc=0.7050
# C=0.008, train_acc=0.9744, val_acc=0.7125
# C=0.009000000000000001, train_acc=0.9781, val_acc=0.7125
# C=0.01, train_acc=0.9844, val_acc=0.7200
# C=0.02, train_acc=1.0000, val_acc=0.7050
# C=0.03, train_acc=1.0000, val_acc=0.7125
# C=0.04, train_acc=1.0000, val_acc=0.7100
# C=0.05, train_acc=1.0000, val_acc=0.7100
# C=0.06, train_acc=1.0000, val_acc=0.7100
# C=0.07, train_acc=1.0000, val_acc=0.7100
# C=0.08, train_acc=1.0000, val_acc=0.7100
# C=0.09, train_acc=1.0000, val_acc=0.7100
# C=0.1, train_acc=1.0000, val_acc=0.7100
# C=0.2, train_acc=1.0000, val_acc=0.7100
# C=0.30000000000000004, train_acc=1.0000, val_acc=0.7100
# C=0.4, train_acc=1.0000, val_acc=0.7100
# C=0.5, train_acc=1.0000, val_acc=0.7100
# C=0.6000000000000001, train_acc=1.0000, val_acc=0.7100
# C=0.7000000000000001, train_acc=1.0000, val_acc=0.7100
# C=0.8, train_acc=1.0000, val_acc=0.7100
# C=0.9, train_acc=1.0000, val_acc=0.7100
# C=1.0, train_acc=1.0000, val_acc=0.7100
# C=2.0, train_acc=1.0000, val_acc=0.7100
# C=3.0, train_acc=1.0000, val_acc=0.7100
# C=4.0, train_acc=1.0000, val_acc=0.7100
# C=5.0, train_acc=1.0000, val_acc=0.7100
# C=6.0, train_acc=1.0000, val_acc=0.7100
# C=7.0, train_acc=1.0000, val_acc=0.7100
# C=8.0, train_acc=1.0000, val_acc=0.7100
# C=9.0, train_acc=1.0000, val_acc=0.7100
# C=10.0, train_acc=1.0000, val_acc=0.7100
# C=20.0, train_acc=1.0000, val_acc=0.7100
# C=30.0, train_acc=1.0000, val_acc=0.7100
# C=40.0, train_acc=1.0000, val_acc=0.7100
# C=50.0, train_acc=1.0000, val_acc=0.7100
# C=60.0, train_acc=1.0000, val_acc=0.7100
# C=70.0, train_acc=1.0000, val_acc=0.7100
# C=80.0, train_acc=1.0000, val_acc=0.7100
# C=90.0, train_acc=1.0000, val_acc=0.7100
# Best constant C: 0.01, accuracy on val 0.7275
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# Fold 1
# C=1e-05, train_acc=0.0000, val_acc=0.0000
# C=2e-05, train_acc=0.6787, val_acc=0.5750
# C=3.0000000000000004e-05, train_acc=0.6787, val_acc=0.5750
# C=4e-05, train_acc=0.6787, val_acc=0.5750
# C=5e-05, train_acc=0.6763, val_acc=0.5750
# C=6.000000000000001e-05, train_acc=0.6737, val_acc=0.5800
# C=7.000000000000001e-05, train_acc=0.6725, val_acc=0.5825
# C=8e-05, train_acc=0.6663, val_acc=0.5875
# C=9e-05, train_acc=0.6625, val_acc=0.5975
# C=0.0001, train_acc=0.6613, val_acc=0.5975
# C=0.0002, train_acc=0.6325, val_acc=0.6175
# C=0.00030000000000000003, train_acc=0.6125, val_acc=0.6250
# C=0.0004, train_acc=0.6062, val_acc=0.6100
# C=0.0005, train_acc=0.6006, val_acc=0.6025
# C=0.0006000000000000001, train_acc=0.5975, val_acc=0.6025
# C=0.0007, train_acc=0.5988, val_acc=0.6025
# C=0.0008, train_acc=0.6000, val_acc=0.6025
# C=0.0009000000000000001, train_acc=0.6012, val_acc=0.6000
# C=0.001, train_acc=0.6044, val_acc=0.6000
# C=0.002, train_acc=0.6781, val_acc=0.6275
# C=0.003, train_acc=0.8131, val_acc=0.6300
# C=0.004, train_acc=0.8856, val_acc=0.6250
# C=0.005, train_acc=0.9250, val_acc=0.6275
# C=0.006, train_acc=0.9437, val_acc=0.6325
# C=0.007, train_acc=0.9537, val_acc=0.6375
# C=0.008, train_acc=0.9644, val_acc=0.6400
# C=0.009000000000000001, train_acc=0.9675, val_acc=0.6400
# C=0.01, train_acc=0.9725, val_acc=0.6425
# C=0.02, train_acc=0.9975, val_acc=0.6525
# C=0.03, train_acc=1.0000, val_acc=0.6425
# C=0.04, train_acc=1.0000, val_acc=0.6550
# C=0.05, train_acc=1.0000, val_acc=0.6575
# C=0.06, train_acc=1.0000, val_acc=0.6550
# C=0.07, train_acc=1.0000, val_acc=0.6550
# C=0.08, train_acc=1.0000, val_acc=0.6550
# C=0.09, train_acc=1.0000, val_acc=0.6575
# C=0.1, train_acc=1.0000, val_acc=0.6575
# C=0.2, train_acc=1.0000, val_acc=0.6550
# C=0.30000000000000004, train_acc=1.0000, val_acc=0.6550
# C=0.4, train_acc=1.0000, val_acc=0.6575
# C=0.5, train_acc=1.0000, val_acc=0.6550
# C=0.6000000000000001, train_acc=1.0000, val_acc=0.6550
# C=0.7000000000000001, train_acc=1.0000, val_acc=0.6550
# C=0.8, train_acc=1.0000, val_acc=0.6575
# C=0.9, train_acc=1.0000, val_acc=0.6550
# C=1.0, train_acc=1.0000, val_acc=0.6550
# C=2.0, train_acc=1.0000, val_acc=0.6550
# C=3.0, train_acc=1.0000, val_acc=0.6550
# C=4.0, train_acc=1.0000, val_acc=0.6550
# C=5.0, train_acc=1.0000, val_acc=0.6550
# C=6.0, train_acc=1.0000, val_acc=0.6550
# C=7.0, train_acc=1.0000, val_acc=0.6550
# C=8.0, train_acc=1.0000, val_acc=0.6550
# C=9.0, train_acc=1.0000, val_acc=0.6575
# C=10.0, train_acc=1.0000, val_acc=0.6550
# C=20.0, train_acc=1.0000, val_acc=0.6575
# C=30.0, train_acc=1.0000, val_acc=0.6550
# C=40.0, train_acc=1.0000, val_acc=0.6550
# C=50.0, train_acc=1.0000, val_acc=0.6550
# C=60.0, train_acc=1.0000, val_acc=0.6550
# C=70.0, train_acc=1.0000, val_acc=0.6550
# C=80.0, train_acc=1.0000, val_acc=0.6550
# C=90.0, train_acc=1.0000, val_acc=0.6550
# Fold 2
# C=1e-05, train_acc=0.0000, val_acc=0.0000
# C=2e-05, train_acc=0.6744, val_acc=0.5425
# C=3.0000000000000004e-05, train_acc=0.6744, val_acc=0.5425
# C=4e-05, train_acc=0.6744, val_acc=0.5425
# C=5e-05, train_acc=0.6700, val_acc=0.5450
# C=6.000000000000001e-05, train_acc=0.6719, val_acc=0.5475
# C=7.000000000000001e-05, train_acc=0.6644, val_acc=0.5350
# C=8e-05, train_acc=0.6669, val_acc=0.5575
# C=9e-05, train_acc=0.6575, val_acc=0.5600
# C=0.0001, train_acc=0.6556, val_acc=0.5675
# C=0.0002, train_acc=0.6231, val_acc=0.5900
# C=0.00030000000000000003, train_acc=0.6162, val_acc=0.5875
# C=0.0004, train_acc=0.6062, val_acc=0.5800
# C=0.0005, train_acc=0.6025, val_acc=0.5775
# C=0.0006000000000000001, train_acc=0.6038, val_acc=0.5775
# C=0.0007, train_acc=0.6069, val_acc=0.5775
# C=0.0008, train_acc=0.6081, val_acc=0.5775
# C=0.0009000000000000001, train_acc=0.6094, val_acc=0.5775
# C=0.001, train_acc=0.6112, val_acc=0.5775
# C=0.002, train_acc=0.6800, val_acc=0.5875
# C=0.003, train_acc=0.8087, val_acc=0.6050
# C=0.004, train_acc=0.8862, val_acc=0.6350
# C=0.005, train_acc=0.9163, val_acc=0.6350
# C=0.006, train_acc=0.9387, val_acc=0.6475
# C=0.007, train_acc=0.9556, val_acc=0.6525
# C=0.008, train_acc=0.9625, val_acc=0.6450
# C=0.009000000000000001, train_acc=0.9700, val_acc=0.6400
# C=0.01, train_acc=0.9800, val_acc=0.6450
# C=0.02, train_acc=0.9962, val_acc=0.6325
# C=0.03, train_acc=0.9988, val_acc=0.6275
# C=0.04, train_acc=0.9994, val_acc=0.6225
# C=0.05, train_acc=1.0000, val_acc=0.6200
# C=0.06, train_acc=1.0000, val_acc=0.6225
# C=0.07, train_acc=1.0000, val_acc=0.6225
# C=0.08, train_acc=1.0000, val_acc=0.6225
# C=0.09, train_acc=1.0000, val_acc=0.6250
# C=0.1, train_acc=1.0000, val_acc=0.6225
# C=0.2, train_acc=1.0000, val_acc=0.6225
# C=0.30000000000000004, train_acc=1.0000, val_acc=0.6225
# C=0.4, train_acc=1.0000, val_acc=0.6225
# C=0.5, train_acc=1.0000, val_acc=0.6225
# C=0.6000000000000001, train_acc=1.0000, val_acc=0.6225
# C=0.7000000000000001, train_acc=1.0000, val_acc=0.6225
# C=0.8, train_acc=1.0000, val_acc=0.6225
# C=0.9, train_acc=1.0000, val_acc=0.6225
# C=1.0, train_acc=1.0000, val_acc=0.6225
# C=2.0, train_acc=1.0000, val_acc=0.6225
# C=3.0, train_acc=1.0000, val_acc=0.6225
# C=4.0, train_acc=1.0000, val_acc=0.6200
# C=5.0, train_acc=1.0000, val_acc=0.6225
# C=6.0, train_acc=1.0000, val_acc=0.6225
# C=7.0, train_acc=1.0000, val_acc=0.6225
# C=8.0, train_acc=1.0000, val_acc=0.6225
# C=9.0, train_acc=1.0000, val_acc=0.6225
# C=10.0, train_acc=1.0000, val_acc=0.6225
# C=20.0, train_acc=1.0000, val_acc=0.6225
# C=30.0, train_acc=1.0000, val_acc=0.6225
# C=40.0, train_acc=1.0000, val_acc=0.6225
# C=50.0, train_acc=1.0000, val_acc=0.6250
# C=60.0, train_acc=1.0000, val_acc=0.6225
# C=70.0, train_acc=1.0000, val_acc=0.6225
# C=80.0, train_acc=1.0000, val_acc=0.6225
# C=90.0, train_acc=1.0000, val_acc=0.6225
# Fold 3
# C=1e-05, train_acc=0.0000, val_acc=0.0000
# C=2e-05, train_acc=0.6837, val_acc=0.6200
# C=3.0000000000000004e-05, train_acc=0.6837, val_acc=0.6200
# C=4e-05, train_acc=0.6837, val_acc=0.6200
# C=5e-05, train_acc=0.6825, val_acc=0.6225
# C=6.000000000000001e-05, train_acc=0.6863, val_acc=0.6075
# C=7.000000000000001e-05, train_acc=0.6844, val_acc=0.6225
# C=8e-05, train_acc=0.6856, val_acc=0.6225
# C=9e-05, train_acc=0.6850, val_acc=0.6100
# C=0.0001, train_acc=0.6844, val_acc=0.6050
# C=0.0002, train_acc=0.6531, val_acc=0.6350
# C=0.00030000000000000003, train_acc=0.6188, val_acc=0.6375
# C=0.0004, train_acc=0.6112, val_acc=0.6250
# C=0.0005, train_acc=0.6044, val_acc=0.6300
# C=0.0006000000000000001, train_acc=0.6000, val_acc=0.6275
# C=0.0007, train_acc=0.6019, val_acc=0.6250
# C=0.0008, train_acc=0.6050, val_acc=0.6250
# C=0.0009000000000000001, train_acc=0.6056, val_acc=0.6275
# C=0.001, train_acc=0.6106, val_acc=0.6300
# C=0.002, train_acc=0.7231, val_acc=0.6475
# C=0.003, train_acc=0.8375, val_acc=0.6350
# C=0.004, train_acc=0.8825, val_acc=0.6325
# C=0.005, train_acc=0.9100, val_acc=0.6500
# C=0.006, train_acc=0.9281, val_acc=0.6550
# C=0.007, train_acc=0.9419, val_acc=0.6625
# C=0.008, train_acc=0.9587, val_acc=0.6625
# C=0.009000000000000001, train_acc=0.9669, val_acc=0.6650
# C=0.01, train_acc=0.9750, val_acc=0.6700
# C=0.02, train_acc=0.9962, val_acc=0.6700
# C=0.03, train_acc=0.9988, val_acc=0.6750
# C=0.04, train_acc=0.9994, val_acc=0.6650
# C=0.05, train_acc=1.0000, val_acc=0.6650
# C=0.06, train_acc=1.0000, val_acc=0.6675
# C=0.07, train_acc=1.0000, val_acc=0.6725
# C=0.08, train_acc=1.0000, val_acc=0.6750
# C=0.09, train_acc=1.0000, val_acc=0.6750
# C=0.1, train_acc=1.0000, val_acc=0.6750
# C=0.2, train_acc=1.0000, val_acc=0.6750
# C=0.30000000000000004, train_acc=1.0000, val_acc=0.6750
# C=0.4, train_acc=1.0000, val_acc=0.6750
# C=0.5, train_acc=1.0000, val_acc=0.6750
# C=0.6000000000000001, train_acc=1.0000, val_acc=0.6750
# C=0.7000000000000001, train_acc=1.0000, val_acc=0.6750
# C=0.8, train_acc=1.0000, val_acc=0.6750
# C=0.9, train_acc=1.0000, val_acc=0.6750
# C=1.0, train_acc=1.0000, val_acc=0.6750
# C=2.0, train_acc=1.0000, val_acc=0.6750
# C=3.0, train_acc=1.0000, val_acc=0.6750
# C=4.0, train_acc=1.0000, val_acc=0.6750
# C=5.0, train_acc=1.0000, val_acc=0.6750
# C=6.0, train_acc=1.0000, val_acc=0.6750
# C=7.0, train_acc=1.0000, val_acc=0.6750
# C=8.0, train_acc=1.0000, val_acc=0.6750
# C=9.0, train_acc=1.0000, val_acc=0.6750
# C=10.0, train_acc=1.0000, val_acc=0.6750
# C=20.0, train_acc=1.0000, val_acc=0.6750
# C=30.0, train_acc=1.0000, val_acc=0.6750
# C=40.0, train_acc=1.0000, val_acc=0.6750
# C=50.0, train_acc=1.0000, val_acc=0.6750
# C=60.0, train_acc=1.0000, val_acc=0.6750
# C=70.0, train_acc=1.0000, val_acc=0.6750
# C=80.0, train_acc=1.0000, val_acc=0.6750
# C=90.0, train_acc=1.0000, val_acc=0.6750
# Fold 4
# C=1e-05, train_acc=0.0000, val_acc=0.0000
# C=2e-05, train_acc=0.6713, val_acc=0.5625
# C=3.0000000000000004e-05, train_acc=0.6713, val_acc=0.5625
# C=4e-05, train_acc=0.6713, val_acc=0.5625
# C=5e-05, train_acc=0.6713, val_acc=0.5725
# C=6.000000000000001e-05, train_acc=0.6706, val_acc=0.5825
# C=7.000000000000001e-05, train_acc=0.6644, val_acc=0.5950
# C=8e-05, train_acc=0.6650, val_acc=0.5950
# C=9e-05, train_acc=0.6644, val_acc=0.6050
# C=0.0001, train_acc=0.6562, val_acc=0.6025
# C=0.0002, train_acc=0.6362, val_acc=0.5825
# C=0.00030000000000000003, train_acc=0.6175, val_acc=0.5775
# C=0.0004, train_acc=0.6144, val_acc=0.5875
# C=0.0005, train_acc=0.6038, val_acc=0.5850
# C=0.0006000000000000001, train_acc=0.6031, val_acc=0.5875
# C=0.0007, train_acc=0.6056, val_acc=0.5850
# C=0.0008, train_acc=0.6094, val_acc=0.5850
# C=0.0009000000000000001, train_acc=0.6100, val_acc=0.5850
# C=0.001, train_acc=0.6144, val_acc=0.5850
# C=0.002, train_acc=0.6887, val_acc=0.6050
# C=0.003, train_acc=0.8219, val_acc=0.6500
# C=0.004, train_acc=0.8931, val_acc=0.6400
# C=0.005, train_acc=0.9175, val_acc=0.6550
# C=0.006, train_acc=0.9331, val_acc=0.6400
# C=0.007, train_acc=0.9450, val_acc=0.6425
# C=0.008, train_acc=0.9544, val_acc=0.6350
# C=0.009000000000000001, train_acc=0.9637, val_acc=0.6250
# C=0.01, train_acc=0.9731, val_acc=0.6325
# C=0.02, train_acc=0.9962, val_acc=0.6175
# C=0.03, train_acc=0.9988, val_acc=0.6225
# C=0.04, train_acc=0.9994, val_acc=0.6250
# C=0.05, train_acc=1.0000, val_acc=0.6250
# C=0.06, train_acc=1.0000, val_acc=0.6250
# C=0.07, train_acc=1.0000, val_acc=0.6225
# C=0.08, train_acc=1.0000, val_acc=0.6250
# C=0.09, train_acc=1.0000, val_acc=0.6250
# C=0.1, train_acc=1.0000, val_acc=0.6250
# C=0.2, train_acc=1.0000, val_acc=0.6250
# C=0.30000000000000004, train_acc=1.0000, val_acc=0.6250
# C=0.4, train_acc=1.0000, val_acc=0.6250
# C=0.5, train_acc=1.0000, val_acc=0.6250
# C=0.6000000000000001, train_acc=1.0000, val_acc=0.6250
# C=0.7000000000000001, train_acc=1.0000, val_acc=0.6250
# C=0.8, train_acc=1.0000, val_acc=0.6250
# C=0.9, train_acc=1.0000, val_acc=0.6250
# C=1.0, train_acc=1.0000, val_acc=0.6250
# C=2.0, train_acc=1.0000, val_acc=0.6250
# C=3.0, train_acc=1.0000, val_acc=0.6250
# C=4.0, train_acc=1.0000, val_acc=0.6250
# C=5.0, train_acc=1.0000, val_acc=0.6250
# C=6.0, train_acc=1.0000, val_acc=0.6250
# C=7.0, train_acc=1.0000, val_acc=0.6250
# C=8.0, train_acc=1.0000, val_acc=0.6250
# C=9.0, train_acc=1.0000, val_acc=0.6250
# C=10.0, train_acc=1.0000, val_acc=0.6250
# C=20.0, train_acc=1.0000, val_acc=0.6250
# C=30.0, train_acc=1.0000, val_acc=0.6250
# C=40.0, train_acc=1.0000, val_acc=0.6250
# C=50.0, train_acc=1.0000, val_acc=0.6250
# C=60.0, train_acc=1.0000, val_acc=0.6250
# C=70.0, train_acc=1.0000, val_acc=0.6250
# C=80.0, train_acc=1.0000, val_acc=0.6250
# C=90.0, train_acc=1.0000, val_acc=0.6250
# Fold 5
# C=1e-05, train_acc=0.0000, val_acc=0.0000
# C=2e-05, train_acc=0.6519, val_acc=0.5850
# C=3.0000000000000004e-05, train_acc=0.6519, val_acc=0.5850
# C=4e-05, train_acc=0.6519, val_acc=0.5850
# C=5e-05, train_acc=0.6519, val_acc=0.5800
# C=6.000000000000001e-05, train_acc=0.6531, val_acc=0.5750
# C=7.000000000000001e-05, train_acc=0.6506, val_acc=0.5775
# C=8e-05, train_acc=0.6450, val_acc=0.5825
# C=9e-05, train_acc=0.6456, val_acc=0.5775
# C=0.0001, train_acc=0.6450, val_acc=0.5775
# C=0.0002, train_acc=0.6231, val_acc=0.5900
# C=0.00030000000000000003, train_acc=0.6138, val_acc=0.5825
# C=0.0004, train_acc=0.6025, val_acc=0.5800
# C=0.0005, train_acc=0.6019, val_acc=0.5775
# C=0.0006000000000000001, train_acc=0.6019, val_acc=0.5775
# C=0.0007, train_acc=0.6031, val_acc=0.5825
# C=0.0008, train_acc=0.6062, val_acc=0.5825
# C=0.0009000000000000001, train_acc=0.6088, val_acc=0.5850
# C=0.001, train_acc=0.6125, val_acc=0.5850
# C=0.002, train_acc=0.7094, val_acc=0.5825
# C=0.003, train_acc=0.8294, val_acc=0.5900
# C=0.004, train_acc=0.8812, val_acc=0.5950
# C=0.005, train_acc=0.9087, val_acc=0.5950
# C=0.006, train_acc=0.9325, val_acc=0.5950
# C=0.007, train_acc=0.9444, val_acc=0.6025
# C=0.008, train_acc=0.9544, val_acc=0.5950
# C=0.009000000000000001, train_acc=0.9669, val_acc=0.5900
# C=0.01, train_acc=0.9712, val_acc=0.5925
# C=0.02, train_acc=0.9956, val_acc=0.6075
# C=0.03, train_acc=0.9988, val_acc=0.6075
# C=0.04, train_acc=1.0000, val_acc=0.6100
# C=0.05, train_acc=1.0000, val_acc=0.6075
# C=0.06, train_acc=1.0000, val_acc=0.6050
# C=0.07, train_acc=1.0000, val_acc=0.6050
# C=0.08, train_acc=1.0000, val_acc=0.6050
# C=0.09, train_acc=1.0000, val_acc=0.6050
# C=0.1, train_acc=1.0000, val_acc=0.6050
# C=0.2, train_acc=1.0000, val_acc=0.6050
# C=0.30000000000000004, train_acc=1.0000, val_acc=0.6050
# C=0.4, train_acc=1.0000, val_acc=0.6050
# C=0.5, train_acc=1.0000, val_acc=0.6050
# C=0.6000000000000001, train_acc=1.0000, val_acc=0.6050
# C=0.7000000000000001, train_acc=1.0000, val_acc=0.6050
# C=0.8, train_acc=1.0000, val_acc=0.6050
# C=0.9, train_acc=1.0000, val_acc=0.6050
# C=1.0, train_acc=1.0000, val_acc=0.6050
# C=2.0, train_acc=1.0000, val_acc=0.6050
# C=3.0, train_acc=1.0000, val_acc=0.6050
# C=4.0, train_acc=1.0000, val_acc=0.6050
# C=5.0, train_acc=1.0000, val_acc=0.6050
# C=6.0, train_acc=1.0000, val_acc=0.6050
# C=7.0, train_acc=1.0000, val_acc=0.6050
# C=8.0, train_acc=1.0000, val_acc=0.6050
# C=9.0, train_acc=1.0000, val_acc=0.6050
# C=10.0, train_acc=1.0000, val_acc=0.6050
# C=20.0, train_acc=1.0000, val_acc=0.6050
# C=30.0, train_acc=1.0000, val_acc=0.6050
# C=40.0, train_acc=1.0000, val_acc=0.6050
# C=50.0, train_acc=1.0000, val_acc=0.6050
# C=60.0, train_acc=1.0000, val_acc=0.6050
# C=70.0, train_acc=1.0000, val_acc=0.6050
# C=80.0, train_acc=1.0000, val_acc=0.6050
# C=90.0, train_acc=1.0000, val_acc=0.6050
# Best constant C: 0.007, accuracy on val 0.6395

# %%
X_train, y_train, X_val, y_val, X_test, = data
X_train_1, y_train_1, X_val_1, y_val_1 = data1
X_train_2, y_train_2, X_val_2, y_val_2 = data2
X_train_3, y_train_3, X_val_3, y_val_3 = data3
_, _, _, _, X_test_1, _, _ = utils.select_k(1, X_train, y_train, X_val, y_val, X_test, aligned_k[0], ID)
_, _, _, _, X_test_2, _, _ = utils.select_k(2, X_train, y_train, X_val, y_val, X_test, aligned_k[1], ID)
_, _, _, _, X_test_3, _, _ = utils.select_k(3, X_train, y_train, X_val, y_val, X_test, aligned_k[2], ID)
svm_1 = SVM.C_SVM(aligned_k[0], ID, C=C_opt_1, print_callbacks=False)
res = svm_1.fit(X_train_1, y_train_1)
pred_tr_1 = svm_1.predict(X_train_1)
print('Accuracy on train set: {:0.4f}'.format(svm_1.score(pred_tr_1, y_train_1)))
pred_val_1 = svm_1.predict(X_val_1)
print('Accuracy on val set: {:0.4f}'.format(svm_1.score(pred_val_1, y_val_1)))
svm_2 = SVM.C_SVM(aligned_k[1], ID, C=C_opt_2, print_callbacks=False)
res = svm_2.fit(X_train_2, y_train_2)
pred_tr_2 = svm_2.predict(X_train_2)
print('Accuracy on train set: {:0.4f}'.format(svm_2.score(pred_tr_2, y_train_2)))
pred_val_2 = svm_2.predict(X_val_2)
print('Accuracy on val set: {:0.4f}'.format(svm_2.score(pred_val_2, y_val_2)))
svm_3 = SVM.C_SVM(aligned_k[2], ID, C=C_opt_3, print_callbacks=False)
res = svm_3.fit(X_train_3, y_train_3)
pred_tr_3 = svm_3.predict(X_train_3)
print('Accuracy on train set: {:0.4f}'.format(svm_3.score(pred_tr_3, y_train_3)))
pred_val_3 = svm_3.predict(X_val_3)
print('Accuracy on val set: {:0.4f}'.format(svm_3.score(pred_val_3, y_val_3)))
y_pred_test = utils.export_predictions([svm_1, svm_2, svm_3], [X_test_1, X_test_2, X_test_3])
# Out:
# Accuracy on train set: 0.9300
# Accuracy on val set: 0.6393
# Accuracy on train set: 0.9873
# Accuracy on val set: 0.7415
# Accuracy on train set: 0.9494
# Accuracy on val set: 0.6232
